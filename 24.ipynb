# %% [markdown]
# <a href="https://colab.research.google.com/github/yangha7/24/blob/master/24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### The following code is to solve the game 24,
# ### 24 is the game I played when I was a kid. By randomly drawing 4 cards from a deck, one can apply +, -, *, / among these numbers to make them 24. Each card (number) must be used and only used once.
# ### A function Is24(a, b, c, d) is written. If the 4 numbers a, b, c, and d can make 24 based on the rules above, a hint is going to given. If they cannot make 24, it will simply print impossible.
# ### There are in general only 2 ways to combine the 4 numbers: (a,b),(c,d) pattern and ((a,b),c),d pattern. I have tried to consider all the possible combinations so the order of the 4 input numbers does not matter.

# %%
#This is set for further test cases other than 24
#a range is set to deal with possible errors for float calculations, say 23.999 < x < 24.001 are all good
goal = 24
lowBound = goal - .001
highBound = goal + .001

# %%
# Subfunction, TwoAndTwo(a, b, c, d)
# Test if 24 can be solved by (a,b),(c,d) manner, Try all possible combinations
# Return 1 if possible and give a Hint; Return 0 if not possible.

def TwoAndTwo(a, b, c, d):

    h1 = a + b
    h2 = a - b
    h3 = b - a
    h4 = a * b
    if b != 0:
        h5 = a / b
    if a != 0:
        h6 = b / a

    y1 = c + d
    y2 = c - d
    y3 = d - c
    y4 = c * d
    if d != 0:
        y5 = c / d
    if c != 0:
        y6 = d / c

    for h in [h1, h2, h3, h4, h5, h6]:
        for y in [y1, y2, y3, y4, y5, y6]:
            if lowBound < h + y < highBound:
                print ('Hint: (', a, b, ') ->', h, 'and (', c, d, ') - >', y, 'then ', h, '+', y, "=", goal)
                return 1
            if lowBound < h - y < highBound:
                print ('Hint: (', a, b, ') ->', h, 'and (', c, d, ') - >', y, 'then ', h, '-', y, "=", goal)
                return 1
            if lowBound < y - h < highBound:
                print ('Hint: (', a, b, ') ->', h, 'and (', c, d, ') - >', y, 'then ', y, '-', h, "=", goal)
                return 1
            if lowBound < h * y < highBound:
                print ('Hint: (', a, b, ') ->', h, 'and (', c, d, ') - >', y, 'then ', h, '*', y, "=", goal)
                return 1
            if y != 0 and lowBound < h / y < highBound:
                print ('Hint: (', a, b, ') ->', h, 'and (', c, d, ') - >', y, 'then ', h, '/', y, "=", goal)
                return 1
            if h != 0 and lowBound < y / h < highBound:
                print ('Hint: (', a, b, ') ->', h, 'and (', c, d, ') - >', y, 'then ', y, '/', h, "=", goal)
                return 1
    return 0

# %%
# Subfunction, ThreeAndOne(a, b, c, d)
# Test if 24 can be solved by ((a,b),c),d) manner, Try all possible combinations
# Return 1 if possible and give a Hint; Return 0 if not possible.

def ThreeAndOne(a, b, c, d):
    
    h1 = a + b
    h2 = a - b
    h3 = b - a
    h4 = a * b
    if b != 0:
        h5 = a / b
    if a != 0:
        h6 = b / a
        
    # find all combination of (h, c)
    for h in [h1, h2, h3, h4, h5, h6]:
        z1 = h + c
        z2 = h - c
        z3 = c - h
        z4 = h * c
        if c != 0:
            z5 = h / c
        if h != 0:
            z6 = c / h
        
        for z in [z1, z2, z3, z4, z5, z6]:
            if lowBound < z + d < highBound:
                print ('Hint: (', a, b, ') ->', h, 'then (', h, c, ') - >', z, 'then ', z, '+', d, "=", goal)
                return 1
            if lowBound < z - d < highBound:
                print ('Hint: (', a, b, ') ->', h, 'then (', h, c, ') - >', z, 'then ', z, '-', d, "=", goal)
                return 1
            if lowBound < d - z < highBound:
                print ('Hint: (', a, b, ') ->', h, 'then (', h, c, ') - >', z, 'then ', d, '-', z, "=", goal)
                return 1
            if lowBound < z * d < highBound:
                print ('Hint: (', a, b, ') ->', h, 'then (', h, c, ') - >', z, 'then ', z, '*', d, "=", goal)
                return 1
            if d != 0 and lowBound < z / d < highBound:
                print ('Hint: (', a, b, ') ->', h, 'then (', h, c, ') - >', z, 'then ', z, '/', d, "=", goal)
                return 1
            if z != 0 and lowBound < d / z < highBound:
                print ('Hint: (', a, b, ') ->', h, 'then (', h, c, ') - >', z, 'then ', d, '/', z, "=", goal)
                return 1
    return 0

# %%
# Now combine the above two cases, and try all the possible orders of the input numbers.
# Notice in some cases, two numbers are commutable.

def Is24(a, b, c, d):
    
    r = TwoAndTwo(a, b, c, d)
    
    if r==0:
        r = TwoAndTwo(a, c, b, d)
    
    if r==0:
        r = TwoAndTwo(a, d, b, c)

# Done with all possible TwoAndTwo, Now move to test ALL possible ThreeAndOne, should have 12
    if r==0:
        r = ThreeAndOne(a, b, c, d)
    
    if r==0:
        r = ThreeAndOne(a, b, d, c)
        
    if r==0:
        r = ThreeAndOne(a, c, b, d)
    
    if r==0:
        r = ThreeAndOne(a, c, d, b)
    
    if r==0:
        r = ThreeAndOne(a, d, b, c)
    
    if r==0:
        r = ThreeAndOne(a, d, c, b)
    
    if r==0:
        r = ThreeAndOne(b, c, a, d)
    
    if r==0:
        r = ThreeAndOne(b, c, d, a)
    
    if r==0:
        r = ThreeAndOne(b, d, a, c)
    
    if r==0:
        r = ThreeAndOne(b, d, c, a)
    
    if r==0:
        r = ThreeAndOne(c, d, a, b)
    
    if r==0:
        r = ThreeAndOne(c, d, b, a)
    
    if r==0:
        print('Sorry, no way to make', goal)
    
    return r

# %%
x = Is24(5,5,5,1)
print(x)
# Out:
# Hint: ( 5 1 ) -> 0.2 then ( 0.2 5 ) - > 4.8 then  4.8 * 5 = 24
# 1

# %%
x = Is24(3,3,7,7)
print(x)
# Out:
# Hint: ( 3 7 ) -> 0.42857142857142855 then ( 0.42857142857142855 3 ) - > 3.4285714285714284 then  3.4285714285714284 * 7 = 24
# 1

# %%
x = Is24(1,6,3,4)
# Out:
# Hint: ( 3 4 ) -> 0.75 then ( 0.75 1 ) - > 0.25 then  6 / 0.25 = 24

# %% [markdown]
# ### Now, with the code working, we can do a statistics to see how many possible ways that we can get a solution of the game by randomly drawing four cards from a deck. We will consider on 1-10 case

# %%
p = 0
t = 0
# p is a counter. If one combination can make 24, then t+1
# t is to count how many total tests have been made. It can be estimated easily, but I put it here to track if there is any bug
for a in range (1,11):
    for b in range (1,11):
        for c in range (1,11):
            for d in range (1,11):
                x = Is24(a, b, c, d)
                t = t+1
                if x == 1:
                    p = p+1

print(p, 'out of', t, 'number of combinations can make', goal, 'ratio is', p/t)
# Out:
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 1 1 ) -> 2 then ( 2 1 ) - > 3 then  3 * 8 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 1 1 ) -> 2 and ( 2 6 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 2 ) -> 3 and ( 1 7 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 2 ) -> 3 and ( 1 8 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 2 ) -> 3 and ( 1 9 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 1 ) -> 2 and ( 2 10 ) - > 12 then  2 * 12 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 1 1 ) -> 2 and ( 3 4 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 3 ) -> 4 and ( 1 5 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 3 ) -> 4 and ( 1 6 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 3 ) -> 4 and ( 1 7 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 1 ) -> 0 and ( 3 8 ) - > 24 then  0 + 24 = 24
# Hint: ( 1 1 ) -> 2 and ( 3 9 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 1 ) -> 2 then ( 2 10 ) - > 8 then  8 * 3 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 1 1 ) -> 2 and ( 4 3 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 1 ) -> 2 then ( 2 4 ) - > 6 then  6 * 4 = 24
# Hint: ( 1 4 ) -> 4 and ( 1 5 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 1 ) -> 0 and ( 4 6 ) - > 24 then  0 + 24 = 24
# Hint: ( 1 4 ) -> 3 and ( 1 7 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 1 ) -> 2 and ( 4 8 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 4 ) -> -3 and ( 1 9 ) - > -8 then  -3 * -8 = 24
# Hint: ( 1 1 ) -> 2 then ( 2 10 ) - > 20 then  20 + 4 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 1 5 ) -> 6 and ( 1 3 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 5 ) -> 6 and ( 1 4 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 1 ) -> 1 and ( 5 5 ) - > 25 then  25 - 1 = 24
# Hint: ( 1 5 ) -> 4 and ( 1 6 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 1 ) -> 2 and ( 5 7 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 1 ) -> 2 then ( 2 5 ) - > 3 then  3 * 8 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 1 1 ) -> 2 and ( 6 2 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 6 ) -> 6 and ( 1 3 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 1 ) -> 0 and ( 6 4 ) - > 24 then  0 + 24 = 24
# Hint: ( 1 6 ) -> 6 and ( 1 5 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 1 ) -> 2 and ( 6 6 ) - > 12 then  2 * 12 = 24
# Sorry, no way to make 24
# Hint: ( 1 1 ) -> 2 and ( 6 8 ) - > 48 then  48 / 2 = 24
# Hint: ( 1 1 ) -> 2 then ( 2 9 ) - > 18 then  18 + 6 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 1 7 ) -> 8 and ( 1 2 ) - > 3 then  8 * 3 = 24
# Hint: ( 1 7 ) -> 8 and ( 1 3 ) - > 3 then  8 * 3 = 24
# Hint: ( 1 7 ) -> 8 and ( 1 4 ) - > 3 then  8 * 3 = 24
# Hint: ( 1 1 ) -> 2 and ( 7 5 ) - > 12 then  2 * 12 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 1 1 ) -> 2 then ( 2 7 ) - > 14 then  14 + 10 = 24
# Hint: ( 1 1 ) -> 2 then ( 2 1 ) - > 3 then  3 * 8 = 24
# Hint: ( 1 8 ) -> 8 and ( 1 2 ) - > 3 then  8 * 3 = 24
# Hint: ( 1 1 ) -> 0 and ( 8 3 ) - > 24 then  0 + 24 = 24
# Hint: ( 1 1 ) -> 2 and ( 8 4 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 1 ) -> 2 then ( 2 5 ) - > 3 then  3 * 8 = 24
# Hint: ( 1 1 ) -> 2 and ( 8 6 ) - > 48 then  48 / 2 = 24
# Sorry, no way to make 24
# Hint: ( 1 1 ) -> 2 then ( 2 8 ) - > 16 then  16 + 8 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 1 9 ) -> 8 and ( 1 2 ) - > 3 then  8 * 3 = 24
# Hint: ( 1 1 ) -> 2 and ( 9 3 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 9 ) -> -8 and ( 1 4 ) - > -3 then  -8 * -3 = 24
# Sorry, no way to make 24
# Hint: ( 1 1 ) -> 2 then ( 2 9 ) - > 18 then  18 + 6 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 1 1 ) -> 2 and ( 10 2 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 1 ) -> 2 then ( 2 10 ) - > 8 then  8 * 3 = 24
# Hint: ( 1 1 ) -> 2 then ( 2 10 ) - > 20 then  20 + 4 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 1 1 ) -> 2 then ( 2 7 ) - > 14 then  14 + 10 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 1 1 ) -> 2 and ( 2 6 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 2 ) -> 3 and ( 1 7 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 2 ) -> 3 and ( 1 8 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 2 ) -> 3 and ( 1 9 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 1 ) -> 2 and ( 2 10 ) - > 12 then  2 * 12 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 1 2 ) -> 3 and ( 2 4 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 5 ) -> 6 and ( 2 2 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 2 ) -> 3 and ( 2 6 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 7 ) -> 6 and ( 2 2 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 2 ) -> -1 then ( -1 2 ) - > 3 then  3 * 8 = 24
# Hint: ( 1 2 ) -> 3 then ( 3 9 ) - > 12 then  12 * 2 = 24
# Hint: ( 1 2 ) -> 3 and ( 2 10 ) - > 8 then  3 * 8 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 1 3 ) -> 4 and ( 2 3 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 2 ) -> 2 and ( 3 4 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 2 ) -> 3 and ( 3 5 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 3 ) -> 2 and ( 2 6 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 2 ) -> 3 and ( 3 7 ) - > 21 then  3 + 21 = 24
# Hint: ( 1 2 ) -> 1 and ( 3 8 ) - > 24 then  1 * 24 = 24
# Hint: ( 1 2 ) -> 3 and ( 3 9 ) - > 27 then  27 - 3 = 24
# Hint: ( 1 3 ) -> 4 and ( 2 10 ) - > 20 then  4 + 20 = 24
# Sorry, no way to make 24
# Hint: ( 1 2 ) -> 3 and ( 4 2 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 2 ) -> 2 and ( 4 3 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 2 ) -> 3 and ( 4 4 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 5 ) -> 4 and ( 2 4 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 2 ) -> 1 and ( 4 6 ) - > 24 then  1 * 24 = 24
# Hint: ( 1 2 ) -> -1 then ( -1 7 ) - > 6 then  6 * 4 = 24
# Hint: ( 1 2 ) -> 2 and ( 4 8 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 2 ) -> 3 then ( 3 9 ) - > 6 then  6 * 4 = 24
# Hint: ( 1 4 ) -> -3 and ( 2 10 ) - > -8 then  -3 * -8 = 24
# Sorry, no way to make 24
# Hint: ( 1 5 ) -> 6 and ( 2 2 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 2 ) -> 3 and ( 5 3 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 5 ) -> 4 and ( 2 4 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 2 ) -> -1 and ( 5 5 ) - > 25 then  -1 + 25 = 24
# Hint: ( 1 5 ) -> 6 and ( 2 6 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 2 ) -> 2 and ( 5 7 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 5 ) -> 6 and ( 2 8 ) - > 0.25 then  6 / 0.25 = 24
# Hint: ( 1 5 ) -> 6 and ( 2 9 ) - > 18 then  6 + 18 = 24
# Hint: ( 1 5 ) -> -4 and ( 2 10 ) - > 20 then  20 - -4 = 24
# Hint: ( 1 1 ) -> 2 and ( 2 6 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 2 ) -> 3 and ( 6 2 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 3 ) -> 2 and ( 2 6 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 2 ) -> 1 and ( 6 4 ) - > 24 then  1 * 24 = 24
# Hint: ( 1 5 ) -> 6 and ( 2 6 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 2 ) -> 2 and ( 6 6 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 7 ) -> 8 and ( 2 6 ) - > 0.3333333333333333 then  8 / 0.3333333333333333 = 24
# Hint: ( 1 2 ) -> 2 and ( 6 8 ) - > 48 then  48 / 2 = 24
# Hint: ( 1 6 ) -> 6 and ( 2 9 ) - > 18 then  6 + 18 = 24
# Hint: ( 1 2 ) -> 3 then ( 3 10 ) - > 30 then  30 - 6 = 24
# Hint: ( 1 2 ) -> 3 and ( 7 1 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 7 ) -> 6 and ( 2 2 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 2 ) -> 3 and ( 7 3 ) - > 21 then  3 + 21 = 24
# Hint: ( 1 2 ) -> -1 then ( -1 7 ) - > 6 then  6 * 4 = 24
# Hint: ( 1 2 ) -> 2 and ( 7 5 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 7 ) -> 8 and ( 2 6 ) - > 0.3333333333333333 then  8 / 0.3333333333333333 = 24
# Hint: ( 7 7 ) -> 49 then ( 49 1 ) - > 48 then  48 / 2 = 24
# Hint: ( 1 7 ) -> 8 and ( 2 8 ) - > 16 then  8 + 16 = 24
# Hint: ( 1 7 ) -> -6 and ( 2 9 ) - > 18 then  18 - -6 = 24
# Hint: ( 1 10 ) -> 10 and ( 2 7 ) - > 14 then  10 + 14 = 24
# Hint: ( 1 2 ) -> 3 and ( 8 1 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 2 ) -> -1 then ( -1 2 ) - > 3 then  3 * 8 = 24
# Hint: ( 1 2 ) -> 1 and ( 8 3 ) - > 24 then  1 * 24 = 24
# Hint: ( 1 2 ) -> 2 and ( 8 4 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 8 ) -> 8 and ( 2 5 ) - > 3 then  8 * 3 = 24
# Hint: ( 1 2 ) -> 2 and ( 8 6 ) - > 48 then  48 / 2 = 24
# Hint: ( 1 7 ) -> 8 and ( 2 8 ) - > 16 then  8 + 16 = 24
# Hint: ( 1 8 ) -> 8 and ( 2 8 ) - > 16 then  8 + 16 = 24
# Hint: ( 1 2 ) -> 3 and ( 8 9 ) - > 72 then  72 / 3 = 24
# Hint: ( 1 8 ) -> -7 then ( -7 2 ) - > -14 then  10 - -14 = 24
# Hint: ( 1 2 ) -> 3 and ( 9 1 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 2 ) -> 3 then ( 3 9 ) - > 12 then  12 * 2 = 24
# Hint: ( 1 2 ) -> 3 and ( 9 3 ) - > 27 then  27 - 3 = 24
# Hint: ( 1 2 ) -> 3 then ( 3 9 ) - > 6 then  6 * 4 = 24
# Hint: ( 1 9 ) -> -8 and ( 2 5 ) - > -3 then  -8 * -3 = 24
# Hint: ( 1 9 ) -> 8 and ( 2 6 ) - > 0.3333333333333333 then  8 / 0.3333333333333333 = 24
# Hint: ( 1 9 ) -> 10 and ( 2 7 ) - > 14 then  10 + 14 = 24
# Hint: ( 1 2 ) -> 3 and ( 9 8 ) - > 72 then  72 / 3 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 1 1 ) -> 2 and ( 2 10 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 2 ) -> 3 and ( 10 2 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 3 ) -> 4 and ( 2 10 ) - > 20 then  4 + 20 = 24
# Hint: ( 1 4 ) -> -3 and ( 2 10 ) - > -8 then  -3 * -8 = 24
# Hint: ( 1 5 ) -> -4 and ( 2 10 ) - > 20 then  20 - -4 = 24
# Hint: ( 1 2 ) -> 3 then ( 3 10 ) - > 30 then  30 - 6 = 24
# Hint: ( 1 10 ) -> 10 and ( 2 7 ) - > 14 then  10 + 14 = 24
# Hint: ( 1 8 ) -> -7 then ( -7 2 ) - > -14 then  10 - -14 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 1 1 ) -> 2 and ( 3 4 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 3 ) -> 4 and ( 1 5 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 3 ) -> 4 and ( 1 6 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 3 ) -> 4 and ( 1 7 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 3 ) -> 3 and ( 1 8 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 3 ) -> 3 and ( 1 9 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 1 ) -> 2 then ( 2 10 ) - > 8 then  8 * 3 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 1 3 ) -> 4 and ( 2 3 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 3 ) -> 4 and ( 2 4 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 2 ) -> 3 and ( 3 5 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 3 ) -> 2 and ( 2 6 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 2 ) -> 3 and ( 3 7 ) - > 21 then  3 + 21 = 24
# Hint: ( 1 3 ) -> 4 and ( 2 8 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 2 ) -> 3 and ( 3 9 ) - > 27 then  27 - 3 = 24
# Hint: ( 1 3 ) -> 4 and ( 2 10 ) - > 20 then  4 + 20 = 24
# Sorry, no way to make 24
# Hint: ( 1 3 ) -> 4 and ( 3 2 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 3 ) -> 4 and ( 3 3 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 3 ) -> 2 and ( 3 4 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 3 ) -> 3 and ( 3 5 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 3 ) -> -2 then ( -2 6 ) - > 8 then  8 * 3 = 24
# Hint: ( 1 3 ) -> 3 and ( 3 7 ) - > 21 then  3 + 21 = 24
# Hint: ( 1 8 ) -> 9 then ( 9 3 ) - > 27 then  27 - 3 = 24
# Hint: ( 1 3 ) -> 4 and ( 3 9 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 3 ) -> -2 then ( -2 10 ) - > 8 then  8 * 3 = 24
# Hint: ( 1 1 ) -> 2 and ( 3 4 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 3 ) -> 4 and ( 4 2 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 3 ) -> 2 and ( 4 3 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 3 ) -> 3 and ( 4 4 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 3 ) -> 4 and ( 4 5 ) - > 20 then  4 + 20 = 24
# Hint: ( 3 4 ) -> 0.75 then ( 0.75 1 ) - > 0.25 then  6 / 0.25 = 24
# Hint: ( 1 3 ) -> 4 and ( 4 7 ) - > 28 then  28 - 4 = 24
# Hint: ( 1 3 ) -> 2 and ( 4 8 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 4 ) -> -3 and ( 3 9 ) - > 27 then  -3 + 27 = 24
# Hint: ( 1 3 ) -> 4 and ( 4 10 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 3 ) -> 4 and ( 5 1 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 5 ) -> 4 and ( 3 2 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 3 ) -> 3 and ( 5 3 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 3 ) -> 4 and ( 5 4 ) - > 20 then  4 + 20 = 24
# Sorry, no way to make 24
# Hint: ( 1 5 ) -> 6 and ( 3 6 ) - > 18 then  6 + 18 = 24
# Hint: ( 1 3 ) -> 2 and ( 5 7 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 8 ) -> 9 and ( 3 5 ) - > 15 then  9 + 15 = 24
# Hint: ( 1 5 ) -> -4 and ( 3 9 ) - > -6 then  -4 * -6 = 24
# Hint: ( 1 5 ) -> 6 and ( 3 10 ) - > 30 then  30 - 6 = 24
# Hint: ( 1 3 ) -> 4 and ( 6 1 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 3 ) -> 2 and ( 6 2 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 3 ) -> -2 then ( -2 6 ) - > 8 then  8 * 3 = 24
# Hint: ( 3 4 ) -> 0.75 then ( 0.75 1 ) - > 0.25 then  6 / 0.25 = 24
# Hint: ( 1 5 ) -> 6 and ( 3 6 ) - > 18 then  6 + 18 = 24
# Hint: ( 1 3 ) -> 2 and ( 6 6 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 6 ) -> 6 and ( 3 7 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 3 ) -> 2 and ( 6 8 ) - > 48 then  48 / 2 = 24
# Hint: ( 1 9 ) -> -8 and ( 3 6 ) - > -3 then  -8 * -3 = 24
# Hint: ( 1 6 ) -> 6 and ( 3 10 ) - > 30 then  30 - 6 = 24
# Hint: ( 1 3 ) -> 4 and ( 7 1 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 2 ) -> 3 and ( 3 7 ) - > 21 then  3 + 21 = 24
# Hint: ( 1 3 ) -> 3 and ( 7 3 ) - > 21 then  3 + 21 = 24
# Hint: ( 1 3 ) -> 4 and ( 7 4 ) - > 28 then  28 - 4 = 24
# Hint: ( 1 3 ) -> 2 and ( 7 5 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 7 ) -> 8 and ( 3 6 ) - > 3 then  8 * 3 = 24
# Hint: ( 1 7 ) -> -6 and ( 3 7 ) - > -4 then  -6 * -4 = 24
# Hint: ( 1 3 ) -> 4 then ( 4 7 ) - > 3 then  3 * 8 = 24
# Hint: ( 1 7 ) -> 8 and ( 3 9 ) - > 0.3333333333333333 then  8 / 0.3333333333333333 = 24
# Hint: ( 1 7 ) -> -6 and ( 3 10 ) - > 30 then  -6 + 30 = 24
# Hint: ( 1 3 ) -> 3 and ( 8 1 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 3 ) -> 4 and ( 8 2 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 8 ) -> 9 then ( 9 3 ) - > 27 then  27 - 3 = 24
# Hint: ( 1 3 ) -> 2 and ( 8 4 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 8 ) -> 9 and ( 3 5 ) - > 15 then  9 + 15 = 24
# Hint: ( 1 3 ) -> 2 and ( 8 6 ) - > 48 then  48 / 2 = 24
# Hint: ( 1 3 ) -> 4 then ( 4 7 ) - > 3 then  3 * 8 = 24
# Hint: ( 1 8 ) -> 9 and ( 3 8 ) - > 0.375 then  9 / 0.375 = 24
# Hint: ( 1 3 ) -> 3 and ( 8 9 ) - > 72 then  72 / 3 = 24
# Hint: ( 1 10 ) -> 9 and ( 3 8 ) - > 0.375 then  9 / 0.375 = 24
# Hint: ( 1 3 ) -> 3 and ( 9 1 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 2 ) -> 3 and ( 3 9 ) - > 27 then  27 - 3 = 24
# Hint: ( 1 3 ) -> 4 and ( 9 3 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 4 ) -> -3 and ( 3 9 ) - > 27 then  -3 + 27 = 24
# Hint: ( 1 9 ) -> 9 and ( 3 5 ) - > 15 then  9 + 15 = 24
# Hint: ( 1 9 ) -> -8 and ( 3 6 ) - > -3 then  -8 * -3 = 24
# Hint: ( 1 7 ) -> 8 and ( 3 9 ) - > 0.3333333333333333 then  8 / 0.3333333333333333 = 24
# Hint: ( 1 3 ) -> 3 and ( 9 8 ) - > 72 then  72 / 3 = 24
# Hint: ( 1 9 ) -> 8 and ( 3 9 ) - > 0.3333333333333333 then  8 / 0.3333333333333333 = 24
# Hint: ( 1 10 ) -> 11 then ( 11 3 ) - > 33 then  33 - 9 = 24
# Hint: ( 1 10 ) -> 9 then ( 9 1 ) - > 8 then  8 * 3 = 24
# Hint: ( 1 3 ) -> 4 and ( 10 2 ) - > 20 then  4 + 20 = 24
# Hint: ( 1 3 ) -> -2 then ( -2 10 ) - > 8 then  8 * 3 = 24
# Hint: ( 1 3 ) -> 4 and ( 10 4 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 10 ) -> -9 and ( 3 5 ) - > 15 then  15 - -9 = 24
# Hint: ( 1 6 ) -> 6 and ( 3 10 ) - > 30 then  30 - 6 = 24
# Hint: ( 1 7 ) -> -6 and ( 3 10 ) - > 30 then  -6 + 30 = 24
# Hint: ( 1 10 ) -> 9 and ( 3 8 ) - > 0.375 then  9 / 0.375 = 24
# Hint: ( 1 10 ) -> 11 then ( 11 3 ) - > 33 then  33 - 9 = 24
# Hint: ( 1 3 ) -> 4 and ( 10 10 ) - > 20 then  4 + 20 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 1 1 ) -> 2 and ( 4 3 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 4 ) -> 5 then ( 5 1 ) - > 6 then  6 * 4 = 24
# Hint: ( 1 4 ) -> 4 and ( 1 5 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 4 ) -> 4 and ( 1 6 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 4 ) -> 3 and ( 1 7 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 4 ) -> 3 and ( 1 8 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 4 ) -> -3 and ( 1 9 ) - > -8 then  -3 * -8 = 24
# Hint: ( 1 1 ) -> 2 then ( 2 10 ) - > 20 then  20 + 4 = 24
# Sorry, no way to make 24
# Hint: ( 1 2 ) -> 3 and ( 4 2 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 4 ) -> 4 and ( 2 3 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 4 ) -> 3 and ( 2 4 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 5 ) -> 4 and ( 4 2 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 4 ) -> 3 and ( 2 6 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 4 ) -> 5 then ( 5 7 ) - > 12 then  12 * 2 = 24
# Hint: ( 1 4 ) -> 4 and ( 2 8 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 4 ) -> -3 then ( -3 9 ) - > 12 then  12 * 2 = 24
# Hint: ( 1 4 ) -> -3 and ( 2 10 ) - > -8 then  -3 * -8 = 24
# Hint: ( 1 1 ) -> 2 and ( 4 3 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 4 ) -> 4 and ( 3 2 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 4 ) -> 4 and ( 3 3 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 3 ) -> 3 and ( 4 4 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 4 ) -> 3 and ( 3 5 ) - > 8 then  3 * 8 = 24
# Hint: ( 4 3 ) -> 0.75 then ( 0.75 1 ) - > 0.25 then  6 / 0.25 = 24
# Hint: ( 1 4 ) -> -3 and ( 3 7 ) - > 21 then  21 - -3 = 24
# Hint: ( 1 3 ) -> 2 and ( 4 8 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 4 ) -> -3 and ( 3 9 ) - > 27 then  -3 + 27 = 24
# Hint: ( 1 3 ) -> 4 and ( 4 10 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 4 ) -> 5 then ( 5 1 ) - > 6 then  6 * 4 = 24
# Hint: ( 1 4 ) -> 3 and ( 4 2 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 3 ) -> 3 and ( 4 4 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 4 ) -> 3 and ( 4 4 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 4 ) -> 4 and ( 4 5 ) - > 20 then  4 + 20 = 24
# Hint: ( 1 6 ) -> 7 then ( 7 4 ) - > 28 then  28 - 4 = 24
# Hint: ( 1 4 ) -> 4 and ( 4 7 ) - > 28 then  28 - 4 = 24
# Hint: ( 1 8 ) -> 8 and ( 4 4 ) - > 16 then  8 + 16 = 24
# Hint: ( 1 9 ) -> -8 and ( 4 4 ) - > 16 then  16 - -8 = 24
# Hint: ( 1 4 ) -> 4 and ( 4 10 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 4 ) -> 4 and ( 5 1 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 5 ) -> 4 and ( 4 2 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 4 ) -> 3 and ( 5 3 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 4 ) -> 4 and ( 5 4 ) - > 20 then  4 + 20 = 24
# Hint: ( 1 5 ) -> -4 and ( 4 5 ) - > 20 then  20 - -4 = 24
# Hint: ( 4 5 ) -> 1.25 then ( 1.25 1 ) - > 0.25 then  6 / 0.25 = 24
# Hint: ( 1 5 ) -> -4 and ( 4 7 ) - > 28 then  -4 + 28 = 24
# Hint: ( 1 5 ) -> 6 and ( 4 8 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 4 ) -> -3 then ( -3 5 ) - > -15 then  9 - -15 = 24
# Hint: ( 1 5 ) -> -4 and ( 4 10 ) - > -6 then  -4 * -6 = 24
# Hint: ( 1 4 ) -> 4 and ( 6 1 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 4 ) -> 3 and ( 6 2 ) - > 8 then  3 * 8 = 24
# Hint: ( 4 3 ) -> 0.75 then ( 0.75 1 ) - > 0.25 then  6 / 0.25 = 24
# Hint: ( 1 6 ) -> 7 then ( 7 4 ) - > 28 then  28 - 4 = 24
# Hint: ( 4 5 ) -> 1.25 then ( 1.25 1 ) - > 0.25 then  6 / 0.25 = 24
# Hint: ( 1 4 ) -> 5 then ( 5 6 ) - > 30 then  30 - 6 = 24
# Hint: ( 1 4 ) -> -3 then ( -3 7 ) - > 4 then  4 * 6 = 24
# Hint: ( 1 6 ) -> 6 and ( 4 8 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 4 ) -> 5 then ( 5 9 ) - > 4 then  4 * 6 = 24
# Hint: ( 1 4 ) -> 3 then ( 3 10 ) - > 30 then  30 - 6 = 24
# Hint: ( 1 4 ) -> 3 and ( 7 1 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 4 ) -> 5 then ( 5 7 ) - > 12 then  12 * 2 = 24
# Hint: ( 1 4 ) -> -3 and ( 7 3 ) - > 21 then  21 - -3 = 24
# Hint: ( 1 4 ) -> 4 and ( 7 4 ) - > 28 then  28 - 4 = 24
# Hint: ( 1 5 ) -> -4 and ( 4 7 ) - > 28 then  -4 + 28 = 24
# Hint: ( 1 4 ) -> -3 then ( -3 7 ) - > 4 then  4 * 6 = 24
# Hint: ( 1 7 ) -> 8 and ( 4 7 ) - > 3 then  8 * 3 = 24
# Hint: ( 1 7 ) -> 8 and ( 4 8 ) - > 32 then  32 - 8 = 24
# Hint: ( 1 9 ) -> -8 and ( 4 7 ) - > -3 then  -8 * -3 = 24
# Sorry, no way to make 24
# Hint: ( 1 4 ) -> 3 and ( 8 1 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 4 ) -> 4 and ( 8 2 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 3 ) -> 2 and ( 4 8 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 8 ) -> 8 and ( 4 4 ) - > 16 then  8 + 16 = 24
# Hint: ( 1 5 ) -> 6 and ( 4 8 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 6 ) -> 6 and ( 4 8 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 8 ) -> 8 and ( 4 7 ) - > 3 then  8 * 3 = 24
# Hint: ( 1 8 ) -> 8 and ( 4 8 ) - > 32 then  32 - 8 = 24
# Hint: ( 1 4 ) -> 3 and ( 8 9 ) - > 72 then  72 / 3 = 24
# Sorry, no way to make 24
# Hint: ( 1 4 ) -> -3 and ( 9 1 ) - > -8 then  -3 * -8 = 24
# Hint: ( 1 4 ) -> -3 then ( -3 9 ) - > 12 then  12 * 2 = 24
# Hint: ( 1 4 ) -> -3 and ( 9 3 ) - > 27 then  -3 + 27 = 24
# Hint: ( 1 9 ) -> -8 and ( 4 4 ) - > 16 then  16 - -8 = 24
# Hint: ( 1 4 ) -> -3 then ( -3 5 ) - > -15 then  9 - -15 = 24
# Hint: ( 1 4 ) -> 5 then ( 5 9 ) - > 4 then  4 * 6 = 24
# Hint: ( 1 9 ) -> -8 and ( 4 7 ) - > -3 then  -8 * -3 = 24
# Hint: ( 1 4 ) -> 3 and ( 9 8 ) - > 72 then  72 / 3 = 24
# Sorry, no way to make 24
# Hint: ( 1 4 ) -> 5 and ( 9 10 ) - > 19 then  5 + 19 = 24
# Hint: ( 1 1 ) -> 2 then ( 2 10 ) - > 20 then  20 + 4 = 24
# Hint: ( 1 4 ) -> -3 and ( 10 2 ) - > -8 then  -3 * -8 = 24
# Hint: ( 1 3 ) -> 4 and ( 4 10 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 4 ) -> 4 and ( 10 4 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 5 ) -> -4 and ( 4 10 ) - > -6 then  -4 * -6 = 24
# Hint: ( 1 4 ) -> 3 then ( 3 10 ) - > 30 then  30 - 6 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 1 4 ) -> 5 and ( 10 9 ) - > 19 then  5 + 19 = 24
# Hint: ( 1 4 ) -> 4 and ( 10 10 ) - > 20 then  4 + 20 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 1 5 ) -> 6 and ( 1 3 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 5 ) -> 6 and ( 1 4 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 5 ) -> 6 and ( 1 5 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 5 ) -> 4 and ( 1 6 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 5 ) -> -4 and ( 1 7 ) - > -6 then  -4 * -6 = 24
# Hint: ( 1 5 ) -> 4 then ( 4 1 ) - > 3 then  3 * 8 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 1 5 ) -> 6 and ( 2 2 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 5 ) -> 4 and ( 2 3 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 5 ) -> 4 and ( 2 4 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 2 ) -> -1 and ( 5 5 ) - > 25 then  -1 + 25 = 24
# Hint: ( 1 5 ) -> 6 and ( 2 6 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 2 ) -> 2 and ( 5 7 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 5 ) -> 6 and ( 2 8 ) - > 0.25 then  6 / 0.25 = 24
# Hint: ( 1 5 ) -> 6 and ( 2 9 ) - > 18 then  6 + 18 = 24
# Hint: ( 1 5 ) -> -4 and ( 2 10 ) - > 20 then  20 - -4 = 24
# Hint: ( 1 5 ) -> 6 and ( 3 1 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 5 ) -> 4 and ( 3 2 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 5 ) -> 4 and ( 3 3 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 3 ) -> 4 and ( 5 4 ) - > 20 then  4 + 20 = 24
# Sorry, no way to make 24
# Hint: ( 1 5 ) -> 6 and ( 3 6 ) - > 18 then  6 + 18 = 24
# Hint: ( 1 5 ) -> 6 and ( 3 7 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 8 ) -> 9 and ( 5 3 ) - > 15 then  9 + 15 = 24
# Hint: ( 1 5 ) -> -4 and ( 3 9 ) - > -6 then  -4 * -6 = 24
# Hint: ( 1 5 ) -> 6 and ( 3 10 ) - > 30 then  30 - 6 = 24
# Hint: ( 1 5 ) -> 6 and ( 4 1 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 5 ) -> 4 and ( 4 2 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 4 ) -> 3 and ( 5 3 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 4 ) -> 4 and ( 5 4 ) - > 20 then  4 + 20 = 24
# Hint: ( 1 5 ) -> -4 and ( 4 5 ) - > 20 then  20 - -4 = 24
# Hint: ( 5 4 ) -> 1.25 then ( 1.25 1 ) - > 0.25 then  6 / 0.25 = 24
# Hint: ( 1 5 ) -> -4 and ( 4 7 ) - > 28 then  -4 + 28 = 24
# Hint: ( 1 5 ) -> 6 and ( 4 8 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 4 ) -> -3 then ( -3 5 ) - > -15 then  9 - -15 = 24
# Hint: ( 1 5 ) -> -4 and ( 4 10 ) - > -6 then  -4 * -6 = 24
# Hint: ( 1 5 ) -> 6 and ( 5 1 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 2 ) -> -1 and ( 5 5 ) - > 25 then  -1 + 25 = 24
# Sorry, no way to make 24
# Hint: ( 1 5 ) -> -4 and ( 5 4 ) - > 20 then  20 - -4 = 24
# Hint: ( 1 5 ) -> 0.2 then ( 0.2 5 ) - > 4.8 then  4.8 * 5 = 24
# Hint: ( 1 5 ) -> 6 and ( 5 6 ) - > 30 then  30 - 6 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 1 5 ) -> 6 and ( 5 9 ) - > 4 then  6 * 4 = 24
# Hint: ( 5 10 ) -> 5 then ( 5 5 ) - > 25 then  25 - 1 = 24
# Hint: ( 1 5 ) -> 4 and ( 6 1 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 5 ) -> 6 and ( 6 2 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 5 ) -> 6 and ( 6 3 ) - > 18 then  6 + 18 = 24
# Hint: ( 5 6 ) -> 0.8333333333333334 then ( 0.8333333333333334 1 ) - > 0.16666666666666663 then  4 / 0.16666666666666663 = 24
# Hint: ( 1 5 ) -> 6 and ( 6 5 ) - > 30 then  30 - 6 = 24
# Hint: ( 1 6 ) -> 6 and ( 5 6 ) - > 30 then  30 - 6 = 24
# Hint: ( 1 7 ) -> -6 and ( 5 6 ) - > 30 then  -6 + 30 = 24
# Hint: ( 1 5 ) -> -4 then ( -4 8 ) - > 4 then  4 * 6 = 24
# Hint: ( 1 6 ) -> 6 and ( 5 9 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 5 ) -> 6 and ( 6 10 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 5 ) -> -4 and ( 7 1 ) - > -6 then  -4 * -6 = 24
# Hint: ( 1 7 ) -> 8 and ( 5 2 ) - > 3 then  8 * 3 = 24
# Hint: ( 1 5 ) -> 6 and ( 7 3 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 5 ) -> -4 and ( 7 4 ) - > 28 then  -4 + 28 = 24
# Sorry, no way to make 24
# Hint: ( 1 7 ) -> -6 and ( 5 6 ) - > 30 then  -6 + 30 = 24
# Sorry, no way to make 24
# Hint: ( 1 7 ) -> 8 and ( 5 8 ) - > 3 then  8 * 3 = 24
# Hint: ( 1 7 ) -> -6 and ( 5 9 ) - > -4 then  -6 * -4 = 24
# Hint: ( 1 10 ) -> 11 and ( 5 7 ) - > 35 then  35 - 11 = 24
# Hint: ( 1 5 ) -> 4 then ( 4 1 ) - > 3 then  3 * 8 = 24
# Hint: ( 1 5 ) -> 6 and ( 8 2 ) - > 4.0 then  6 * 4.0 = 24
# Hint: ( 1 8 ) -> 9 and ( 5 3 ) - > 15 then  9 + 15 = 24
# Hint: ( 1 5 ) -> 6 and ( 8 4 ) - > 4 then  6 * 4 = 24
# Sorry, no way to make 24
# Hint: ( 1 5 ) -> -4 then ( -4 8 ) - > 4 then  4 * 6 = 24
# Hint: ( 1 7 ) -> 8 and ( 5 8 ) - > 3 then  8 * 3 = 24
# Hint: ( 1 8 ) -> 8 and ( 5 8 ) - > 3 then  8 * 3 = 24
# Hint: ( 1 9 ) -> -8 and ( 5 8 ) - > -3 then  -8 * -3 = 24
# Hint: ( 1 5 ) -> 6 and ( 8 10 ) - > 18 then  6 + 18 = 24
# Sorry, no way to make 24
# Hint: ( 1 5 ) -> 6 and ( 9 2 ) - > 18 then  6 + 18 = 24
# Hint: ( 1 5 ) -> -4 and ( 9 3 ) - > -6 then  -4 * -6 = 24
# Hint: ( 1 4 ) -> -3 then ( -3 5 ) - > -15 then  9 - -15 = 24
# Hint: ( 1 5 ) -> 6 and ( 9 5 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 6 ) -> 6 and ( 5 9 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 7 ) -> -6 and ( 5 9 ) - > -4 then  -6 * -4 = 24
# Hint: ( 1 9 ) -> -8 and ( 5 8 ) - > -3 then  -8 * -3 = 24
# Hint: ( 1 5 ) -> 6 and ( 9 9 ) - > 18 then  6 + 18 = 24
# Hint: ( 1 5 ) -> 5 and ( 9 10 ) - > 19 then  5 + 19 = 24
# Sorry, no way to make 24
# Hint: ( 1 5 ) -> -4 and ( 10 2 ) - > 20 then  20 - -4 = 24
# Hint: ( 1 5 ) -> 6 and ( 10 3 ) - > 30 then  30 - 6 = 24
# Hint: ( 1 5 ) -> -4 and ( 10 4 ) - > -6 then  -4 * -6 = 24
# Hint: ( 5 10 ) -> 5 then ( 5 5 ) - > 25 then  25 - 1 = 24
# Hint: ( 1 5 ) -> 6 and ( 10 6 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 10 ) -> 11 and ( 5 7 ) - > 35 then  35 - 11 = 24
# Hint: ( 1 5 ) -> 6 and ( 10 8 ) - > 18 then  6 + 18 = 24
# Hint: ( 1 5 ) -> 5 and ( 10 9 ) - > 19 then  5 + 19 = 24
# Hint: ( 1 5 ) -> -4 and ( 10 10 ) - > 20 then  20 - -4 = 24
# Sorry, no way to make 24
# Hint: ( 1 1 ) -> 2 and ( 6 2 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 6 ) -> 6 and ( 1 3 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 6 ) -> 6 and ( 1 4 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 6 ) -> 6 and ( 1 5 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 1 ) -> 2 and ( 6 6 ) - > 12 then  2 * 12 = 24
# Sorry, no way to make 24
# Hint: ( 1 1 ) -> 2 and ( 6 8 ) - > 48 then  48 / 2 = 24
# Hint: ( 1 1 ) -> 2 then ( 2 9 ) - > 18 then  18 + 6 = 24
# Sorry, no way to make 24
# Hint: ( 1 1 ) -> 2 and ( 6 2 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 6 ) -> 6 and ( 2 2 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 3 ) -> 2 and ( 6 2 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 2 ) -> 1 and ( 6 4 ) - > 24 then  1 * 24 = 24
# Hint: ( 1 5 ) -> 6 and ( 6 2 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 6 ) -> 6 and ( 2 6 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 7 ) -> 8 and ( 6 2 ) - > 3.0 then  8 * 3.0 = 24
# Hint: ( 1 6 ) -> 6 and ( 2 8 ) - > 0.25 then  6 / 0.25 = 24
# Hint: ( 1 6 ) -> 6 and ( 2 9 ) - > 18 then  6 + 18 = 24
# Hint: ( 1 6 ) -> 7 then ( 7 2 ) - > 14 then  14 + 10 = 24
# Hint: ( 1 6 ) -> 6 and ( 3 1 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 3 ) -> 2 and ( 6 2 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 6 ) -> 7 then ( 7 3 ) - > 21 then  21 + 3 = 24
# Hint: ( 3 4 ) -> 0.75 then ( 0.75 1 ) - > 0.25 then  6 / 0.25 = 24
# Hint: ( 1 5 ) -> 6 and ( 6 3 ) - > 18 then  6 + 18 = 24
# Hint: ( 1 6 ) -> 6 and ( 3 6 ) - > 18 then  6 + 18 = 24
# Hint: ( 1 6 ) -> 6 and ( 3 7 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 3 ) -> 2 and ( 6 8 ) - > 48 then  48 / 2 = 24
# Hint: ( 1 9 ) -> -8 and ( 6 3 ) - > -3 then  -8 * -3 = 24
# Hint: ( 1 6 ) -> 6 and ( 3 10 ) - > 30 then  30 - 6 = 24
# Hint: ( 1 6 ) -> 6 and ( 4 1 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 4 ) -> 3 and ( 6 2 ) - > 8 then  3 * 8 = 24
# Hint: ( 4 3 ) -> 0.75 then ( 0.75 1 ) - > 0.25 then  6 / 0.25 = 24
# Hint: ( 1 6 ) -> 7 then ( 7 4 ) - > 28 then  28 - 4 = 24
# Hint: ( 6 5 ) -> 0.8333333333333334 then ( 0.8333333333333334 1 ) - > 0.16666666666666663 then  4 / 0.16666666666666663 = 24
# Hint: ( 1 4 ) -> 5 then ( 5 6 ) - > 30 then  30 - 6 = 24
# Hint: ( 1 4 ) -> -3 then ( -3 7 ) - > 4 then  4 * 6 = 24
# Hint: ( 1 6 ) -> 6 and ( 4 8 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 4 ) -> 5 then ( 5 9 ) - > 4 then  4 * 6 = 24
# Hint: ( 1 4 ) -> 3 then ( 3 10 ) - > 30 then  30 - 6 = 24
# Hint: ( 1 6 ) -> 6 and ( 5 1 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 5 ) -> 6 and ( 6 2 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 5 ) -> 6 and ( 6 3 ) - > 18 then  6 + 18 = 24
# Hint: ( 6 5 ) -> 0.8333333333333334 then ( 0.8333333333333334 1 ) - > 0.16666666666666663 then  4 / 0.16666666666666663 = 24
# Hint: ( 1 5 ) -> 6 and ( 6 5 ) - > 30 then  30 - 6 = 24
# Hint: ( 1 6 ) -> 6 and ( 5 6 ) - > 30 then  30 - 6 = 24
# Hint: ( 1 7 ) -> -6 and ( 6 5 ) - > 30 then  -6 + 30 = 24
# Hint: ( 1 5 ) -> -4 then ( -4 8 ) - > 4 then  4 * 6 = 24
# Hint: ( 1 6 ) -> 6 and ( 5 9 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 5 ) -> 6 and ( 6 10 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 1 ) -> 2 and ( 6 6 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 6 ) -> 6 and ( 6 2 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 6 ) -> 6 and ( 6 3 ) - > 18 then  6 + 18 = 24
# Hint: ( 1 4 ) -> 5 then ( 5 6 ) - > 30 then  30 - 6 = 24
# Hint: ( 1 6 ) -> 6 and ( 6 5 ) - > 30 then  30 - 6 = 24
# Hint: ( 1 6 ) -> 5 then ( 5 6 ) - > 30 then  30 - 6 = 24
# Sorry, no way to make 24
# Hint: ( 6 8 ) -> 0.75 then ( 0.75 1 ) - > 0.25 then  6 / 0.25 = 24
# Hint: ( 1 6 ) -> -5 then ( -5 9 ) - > 4 then  4 * 6 = 24
# Hint: ( 1 6 ) -> 6 and ( 6 10 ) - > 4 then  6 * 4 = 24
# Sorry, no way to make 24
# Hint: ( 1 7 ) -> 8 and ( 6 2 ) - > 3.0 then  8 * 3.0 = 24
# Hint: ( 1 6 ) -> 6 and ( 7 3 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 7 ) -> 8 then ( 8 4 ) - > 4 then  4 * 6 = 24
# Hint: ( 1 7 ) -> -6 and ( 6 5 ) - > 30 then  -6 + 30 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 1 7 ) -> 8 and ( 6 9 ) - > 3 then  8 * 3 = 24
# Hint: ( 1 6 ) -> 7 and ( 7 10 ) - > 17 then  7 + 17 = 24
# Hint: ( 1 1 ) -> 2 and ( 6 8 ) - > 48 then  48 / 2 = 24
# Hint: ( 1 6 ) -> 6 and ( 8 2 ) - > 4.0 then  6 * 4.0 = 24
# Hint: ( 1 8 ) -> 8 and ( 6 3 ) - > 3 then  8 * 3 = 24
# Hint: ( 1 6 ) -> 6 and ( 8 4 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 8 ) -> 9 then ( 9 5 ) - > 4 then  4 * 6 = 24
# Hint: ( 6 8 ) -> 0.75 then ( 0.75 1 ) - > 0.25 then  6 / 0.25 = 24
# Sorry, no way to make 24
# Hint: ( 1 6 ) -> -5 then ( -5 8 ) - > 3 then  3 * 8 = 24
# Hint: ( 1 6 ) -> 7 and ( 8 9 ) - > 17 then  7 + 17 = 24
# Hint: ( 1 6 ) -> 6 and ( 8 10 ) - > 18 then  6 + 18 = 24
# Hint: ( 1 1 ) -> 2 then ( 2 9 ) - > 18 then  18 + 6 = 24
# Hint: ( 1 6 ) -> 6 and ( 9 2 ) - > 18 then  6 + 18 = 24
# Hint: ( 1 9 ) -> -8 and ( 6 3 ) - > -3 then  -8 * -3 = 24
# Hint: ( 1 9 ) -> 8 then ( 8 4 ) - > 4 then  4 * 6 = 24
# Hint: ( 1 6 ) -> 6 and ( 9 5 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 6 ) -> -5 then ( -5 9 ) - > 4 then  4 * 6 = 24
# Hint: ( 1 7 ) -> 8 and ( 6 9 ) - > 3 then  8 * 3 = 24
# Hint: ( 1 6 ) -> 7 and ( 9 8 ) - > 17 then  7 + 17 = 24
# Hint: ( 1 6 ) -> 6 and ( 9 9 ) - > 18 then  6 + 18 = 24
# Hint: ( 1 6 ) -> -5 and ( 9 10 ) - > 19 then  19 - -5 = 24
# Sorry, no way to make 24
# Hint: ( 1 6 ) -> 7 then ( 7 2 ) - > 14 then  14 + 10 = 24
# Hint: ( 1 6 ) -> 6 and ( 10 3 ) - > 30 then  30 - 6 = 24
# Hint: ( 1 4 ) -> 3 then ( 3 10 ) - > 30 then  30 - 6 = 24
# Hint: ( 1 5 ) -> 6 and ( 6 10 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 6 ) -> 6 and ( 10 6 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 6 ) -> 7 and ( 10 7 ) - > 17 then  7 + 17 = 24
# Hint: ( 1 6 ) -> 6 and ( 10 8 ) - > 18 then  6 + 18 = 24
# Hint: ( 1 6 ) -> -5 and ( 10 9 ) - > 19 then  19 - -5 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 1 7 ) -> 8 and ( 1 2 ) - > 3 then  8 * 3 = 24
# Hint: ( 1 7 ) -> 8 and ( 1 3 ) - > 3 then  8 * 3 = 24
# Hint: ( 1 7 ) -> 8 and ( 1 4 ) - > 3 then  8 * 3 = 24
# Hint: ( 1 7 ) -> -6 and ( 1 5 ) - > -4 then  -6 * -4 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 1 1 ) -> 2 then ( 2 7 ) - > 14 then  14 + 10 = 24
# Hint: ( 1 7 ) -> 8 and ( 2 1 ) - > 3 then  8 * 3 = 24
# Hint: ( 1 7 ) -> 6 and ( 2 2 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 2 ) -> 3 and ( 7 3 ) - > 21 then  3 + 21 = 24
# Hint: ( 1 7 ) -> 8 then ( 8 2 ) - > 6 then  6 * 4 = 24
# Hint: ( 1 7 ) -> 8 and ( 2 5 ) - > 3 then  8 * 3 = 24
# Hint: ( 1 7 ) -> 8 and ( 2 6 ) - > 0.3333333333333333 then  8 / 0.3333333333333333 = 24
# Hint: ( 7 7 ) -> 49 then ( 49 1 ) - > 48 then  48 / 2 = 24
# Hint: ( 1 7 ) -> 8 and ( 2 8 ) - > 16 then  8 + 16 = 24
# Hint: ( 1 7 ) -> -6 and ( 2 9 ) - > 18 then  18 - -6 = 24
# Hint: ( 1 10 ) -> 10 and ( 7 2 ) - > 14 then  10 + 14 = 24
# Hint: ( 1 7 ) -> 8 and ( 3 1 ) - > 3 then  8 * 3 = 24
# Hint: ( 1 2 ) -> 3 and ( 7 3 ) - > 21 then  3 + 21 = 24
# Hint: ( 1 3 ) -> 3 and ( 7 3 ) - > 21 then  3 + 21 = 24
# Hint: ( 1 3 ) -> 4 and ( 7 4 ) - > 28 then  28 - 4 = 24
# Hint: ( 1 3 ) -> 2 and ( 7 5 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 7 ) -> 8 and ( 3 6 ) - > 3 then  8 * 3 = 24
# Hint: ( 1 7 ) -> -6 and ( 3 7 ) - > -4 then  -6 * -4 = 24
# Hint: ( 1 7 ) -> 6 then ( 6 3 ) - > 3 then  3 * 8 = 24
# Hint: ( 1 7 ) -> 8 and ( 3 9 ) - > 0.3333333333333333 then  8 / 0.3333333333333333 = 24
# Hint: ( 1 7 ) -> -6 and ( 3 10 ) - > 30 then  -6 + 30 = 24
# Hint: ( 1 7 ) -> 8 and ( 4 1 ) - > 3 then  8 * 3 = 24
# Hint: ( 1 7 ) -> 8 then ( 8 4 ) - > 12 then  12 * 2 = 24
# Hint: ( 1 4 ) -> -3 and ( 7 3 ) - > 21 then  21 - -3 = 24
# Hint: ( 1 7 ) -> 8 and ( 4 4 ) - > 16 then  8 + 16 = 24
# Hint: ( 1 5 ) -> -4 and ( 7 4 ) - > 28 then  -4 + 28 = 24
# Hint: ( 1 7 ) -> 8 then ( 8 4 ) - > 4 then  4 * 6 = 24
# Hint: ( 1 7 ) -> 8 and ( 4 7 ) - > 3 then  8 * 3 = 24
# Hint: ( 1 7 ) -> 8 and ( 4 8 ) - > 32 then  32 - 8 = 24
# Hint: ( 1 9 ) -> -8 and ( 7 4 ) - > -3 then  -8 * -3 = 24
# Sorry, no way to make 24
# Hint: ( 1 7 ) -> -6 and ( 5 1 ) - > -4 then  -6 * -4 = 24
# Hint: ( 1 7 ) -> 8 and ( 5 2 ) - > 3 then  8 * 3 = 24
# Hint: ( 1 5 ) -> 6 and ( 7 3 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 5 ) -> -4 and ( 7 4 ) - > 28 then  -4 + 28 = 24
# Sorry, no way to make 24
# Hint: ( 1 7 ) -> -6 and ( 5 6 ) - > 30 then  -6 + 30 = 24
# Sorry, no way to make 24
# Hint: ( 1 7 ) -> 8 and ( 5 8 ) - > 3 then  8 * 3 = 24
# Hint: ( 1 7 ) -> -6 and ( 5 9 ) - > -4 then  -6 * -4 = 24
# Hint: ( 1 10 ) -> 11 and ( 7 5 ) - > 35 then  35 - 11 = 24
# Sorry, no way to make 24
# Hint: ( 1 7 ) -> 8 and ( 6 2 ) - > 3.0 then  8 * 3.0 = 24
# Hint: ( 1 7 ) -> 8 and ( 6 3 ) - > 3 then  8 * 3 = 24
# Hint: ( 1 7 ) -> 8 then ( 8 4 ) - > 4 then  4 * 6 = 24
# Hint: ( 1 7 ) -> -6 and ( 6 5 ) - > 30 then  -6 + 30 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 1 7 ) -> 8 and ( 6 9 ) - > 3 then  8 * 3 = 24
# Hint: ( 1 7 ) -> 8 and ( 6 10 ) - > 16 then  8 + 16 = 24
# Sorry, no way to make 24
# Hint: ( 7 7 ) -> 49 then ( 49 1 ) - > 48 then  48 / 2 = 24
# Hint: ( 1 7 ) -> -6 and ( 7 3 ) - > -4 then  -6 * -4 = 24
# Hint: ( 1 7 ) -> 8 and ( 7 4 ) - > 3 then  8 * 3 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 1 7 ) -> 8 and ( 7 9 ) - > 16 then  8 + 16 = 24
# Hint: ( 1 7 ) -> 8 and ( 7 10 ) - > 3 then  8 * 3 = 24
# Sorry, no way to make 24
# Hint: ( 1 7 ) -> 8 and ( 8 2 ) - > 16 then  8 + 16 = 24
# Hint: ( 1 7 ) -> 6 then ( 6 3 ) - > 3 then  3 * 8 = 24
# Hint: ( 1 7 ) -> 8 and ( 8 4 ) - > 32 then  32 - 8 = 24
# Hint: ( 1 7 ) -> 8 and ( 8 5 ) - > 3 then  8 * 3 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 1 7 ) -> 8 and ( 8 8 ) - > 16 then  8 + 16 = 24
# Hint: ( 1 7 ) -> 7 and ( 8 9 ) - > 17 then  7 + 17 = 24
# Hint: ( 1 7 ) -> -6 and ( 8 10 ) - > 18 then  18 - -6 = 24
# Sorry, no way to make 24
# Hint: ( 1 7 ) -> -6 and ( 9 2 ) - > 18 then  18 - -6 = 24
# Hint: ( 1 7 ) -> 8 and ( 9 3 ) - > 3.0 then  8 * 3.0 = 24
# Hint: ( 1 9 ) -> -8 and ( 7 4 ) - > -3 then  -8 * -3 = 24
# Hint: ( 1 7 ) -> -6 and ( 9 5 ) - > -4 then  -6 * -4 = 24
# Hint: ( 1 7 ) -> 8 and ( 9 6 ) - > 3 then  8 * 3 = 24
# Hint: ( 1 7 ) -> 8 and ( 9 7 ) - > 16 then  8 + 16 = 24
# Hint: ( 1 7 ) -> 7 and ( 9 8 ) - > 17 then  7 + 17 = 24
# Hint: ( 1 7 ) -> -6 and ( 9 9 ) - > 18 then  18 - -6 = 24
# Hint: ( 1 9 ) -> -8 and ( 7 10 ) - > -3 then  -8 * -3 = 24
# Hint: ( 1 1 ) -> 2 then ( 2 7 ) - > 14 then  14 + 10 = 24
# Hint: ( 1 10 ) -> 10 and ( 7 2 ) - > 14 then  10 + 14 = 24
# Hint: ( 1 7 ) -> -6 and ( 10 3 ) - > 30 then  -6 + 30 = 24
# Sorry, no way to make 24
# Hint: ( 1 10 ) -> 11 and ( 7 5 ) - > 35 then  35 - 11 = 24
# Hint: ( 1 7 ) -> 8 and ( 10 6 ) - > 16 then  8 + 16 = 24
# Hint: ( 1 7 ) -> 8 and ( 10 7 ) - > 3 then  8 * 3 = 24
# Hint: ( 1 7 ) -> -6 and ( 10 8 ) - > 18 then  18 - -6 = 24
# Hint: ( 1 9 ) -> -8 and ( 7 10 ) - > -3 then  -8 * -3 = 24
# Sorry, no way to make 24
# Hint: ( 1 1 ) -> 2 then ( 2 1 ) - > 3 then  3 * 8 = 24
# Hint: ( 1 8 ) -> 8 and ( 1 2 ) - > 3 then  8 * 3 = 24
# Hint: ( 1 8 ) -> 8 and ( 1 3 ) - > 3 then  8 * 3 = 24
# Hint: ( 1 8 ) -> 8 and ( 1 4 ) - > 3 then  8 * 3 = 24
# Hint: ( 1 1 ) -> 2 then ( 2 5 ) - > 3 then  3 * 8 = 24
# Hint: ( 1 1 ) -> 2 and ( 8 6 ) - > 48 then  48 / 2 = 24
# Sorry, no way to make 24
# Hint: ( 1 1 ) -> 2 then ( 2 8 ) - > 16 then  16 + 8 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 1 8 ) -> 8 and ( 2 1 ) - > 3 then  8 * 3 = 24
# Hint: ( 1 2 ) -> -1 then ( -1 2 ) - > 3 then  3 * 8 = 24
# Hint: ( 1 2 ) -> 1 and ( 8 3 ) - > 24 then  1 * 24 = 24
# Hint: ( 1 2 ) -> 2 and ( 8 4 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 8 ) -> 8 and ( 2 5 ) - > 3 then  8 * 3 = 24
# Hint: ( 1 8 ) -> 8 and ( 2 6 ) - > 0.3333333333333333 then  8 / 0.3333333333333333 = 24
# Hint: ( 1 7 ) -> 8 and ( 8 2 ) - > 16 then  8 + 16 = 24
# Hint: ( 1 8 ) -> 8 and ( 2 8 ) - > 16 then  8 + 16 = 24
# Hint: ( 1 2 ) -> 3 and ( 8 9 ) - > 72 then  72 / 3 = 24
# Hint: ( 1 8 ) -> -7 then ( -7 2 ) - > -14 then  10 - -14 = 24
# Hint: ( 1 8 ) -> 8 and ( 3 1 ) - > 3 then  8 * 3 = 24
# Hint: ( 1 3 ) -> 4 and ( 8 2 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 8 ) -> 9 then ( 9 3 ) - > 27 then  27 - 3 = 24
# Hint: ( 1 3 ) -> 2 and ( 8 4 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 8 ) -> 9 and ( 3 5 ) - > 15 then  9 + 15 = 24
# Hint: ( 1 8 ) -> 8 and ( 3 6 ) - > 3 then  8 * 3 = 24
# Hint: ( 1 3 ) -> 4 then ( 4 7 ) - > 3 then  3 * 8 = 24
# Hint: ( 1 8 ) -> 9 and ( 3 8 ) - > 0.375 then  9 / 0.375 = 24
# Hint: ( 1 8 ) -> 8 and ( 3 9 ) - > 0.3333333333333333 then  8 / 0.3333333333333333 = 24
# Hint: ( 1 10 ) -> 9 and ( 8 3 ) - > 2.6666666666666665 then  9 * 2.6666666666666665 = 24
# Hint: ( 1 8 ) -> 8 and ( 4 1 ) - > 3 then  8 * 3 = 24
# Hint: ( 1 4 ) -> 4 and ( 8 2 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 3 ) -> 2 and ( 8 4 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 8 ) -> 8 and ( 4 4 ) - > 16 then  8 + 16 = 24
# Hint: ( 1 5 ) -> 6 and ( 8 4 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 6 ) -> 6 and ( 8 4 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 8 ) -> 8 and ( 4 7 ) - > 3 then  8 * 3 = 24
# Hint: ( 1 8 ) -> 8 and ( 4 8 ) - > 32 then  32 - 8 = 24
# Hint: ( 1 4 ) -> 3 and ( 8 9 ) - > 72 then  72 / 3 = 24
# Sorry, no way to make 24
# Hint: ( 1 5 ) -> 4 then ( 4 1 ) - > 3 then  3 * 8 = 24
# Hint: ( 1 8 ) -> 8 and ( 5 2 ) - > 3 then  8 * 3 = 24
# Hint: ( 1 8 ) -> 9 and ( 5 3 ) - > 15 then  9 + 15 = 24
# Hint: ( 1 5 ) -> 6 and ( 8 4 ) - > 4 then  6 * 4 = 24
# Sorry, no way to make 24
# Hint: ( 1 8 ) -> 9 then ( 9 5 ) - > 4 then  4 * 6 = 24
# Hint: ( 1 7 ) -> 8 and ( 8 5 ) - > 3 then  8 * 3 = 24
# Hint: ( 1 8 ) -> 8 and ( 5 8 ) - > 3 then  8 * 3 = 24
# Hint: ( 1 9 ) -> -8 and ( 8 5 ) - > -3 then  -8 * -3 = 24
# Hint: ( 1 8 ) -> 9 and ( 5 10 ) - > 15 then  9 + 15 = 24
# Hint: ( 1 1 ) -> 2 and ( 8 6 ) - > 48 then  48 / 2 = 24
# Hint: ( 1 8 ) -> 8 and ( 6 2 ) - > 3.0 then  8 * 3.0 = 24
# Hint: ( 1 8 ) -> 8 and ( 6 3 ) - > 3 then  8 * 3 = 24
# Hint: ( 1 6 ) -> 6 and ( 8 4 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 8 ) -> 9 then ( 9 5 ) - > 4 then  4 * 6 = 24
# Hint: ( 8 6 ) -> 0.75 then ( 0.75 1 ) - > 0.25 then  6 / 0.25 = 24
# Sorry, no way to make 24
# Hint: ( 1 8 ) -> 9 then ( 9 6 ) - > 3 then  3 * 8 = 24
# Hint: ( 1 8 ) -> 9 and ( 6 9 ) - > 15 then  9 + 15 = 24
# Hint: ( 1 8 ) -> 8 and ( 6 10 ) - > 16 then  8 + 16 = 24
# Sorry, no way to make 24
# Hint: ( 1 7 ) -> 8 and ( 8 2 ) - > 16 then  8 + 16 = 24
# Hint: ( 1 7 ) -> 6 then ( 6 3 ) - > 3 then  3 * 8 = 24
# Hint: ( 1 8 ) -> 8 and ( 7 4 ) - > 3 then  8 * 3 = 24
# Hint: ( 1 7 ) -> 8 and ( 8 5 ) - > 3 then  8 * 3 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 1 8 ) -> 9 and ( 7 8 ) - > 15 then  9 + 15 = 24
# Hint: ( 1 8 ) -> 8 and ( 7 9 ) - > 16 then  8 + 16 = 24
# Hint: ( 1 8 ) -> -7 and ( 7 10 ) - > 17 then  17 - -7 = 24
# Hint: ( 1 1 ) -> 2 then ( 2 8 ) - > 16 then  16 + 8 = 24
# Hint: ( 1 8 ) -> 8 and ( 8 2 ) - > 16 then  8 + 16 = 24
# Hint: ( 1 8 ) -> 9 and ( 8 3 ) - > 2.6666666666666665 then  9 * 2.6666666666666665 = 24
# Hint: ( 1 8 ) -> 8 and ( 8 4 ) - > 32 then  32 - 8 = 24
# Hint: ( 1 8 ) -> 8 and ( 8 5 ) - > 3 then  8 * 3 = 24
# Hint: ( 1 8 ) -> 9 then ( 9 6 ) - > 3 then  3 * 8 = 24
# Hint: ( 1 8 ) -> 9 and ( 8 7 ) - > 15 then  9 + 15 = 24
# Hint: ( 1 8 ) -> 8 and ( 8 8 ) - > 16 then  8 + 16 = 24
# Hint: ( 1 8 ) -> -7 and ( 8 9 ) - > 17 then  17 - -7 = 24
# Hint: ( 1 8 ) -> -7 then ( -7 10 ) - > 3 then  3 * 8 = 24
# Sorry, no way to make 24
# Hint: ( 1 9 ) -> -8 and ( 8 2 ) - > 16 then  16 - -8 = 24
# Hint: ( 1 8 ) -> 8 and ( 9 3 ) - > 3.0 then  8 * 3.0 = 24
# Hint: ( 1 9 ) -> -8 and ( 8 4 ) - > 32 then  -8 + 32 = 24
# Hint: ( 1 9 ) -> -8 and ( 8 5 ) - > -3 then  -8 * -3 = 24
# Hint: ( 1 8 ) -> 9 and ( 9 6 ) - > 15 then  9 + 15 = 24
# Hint: ( 1 8 ) -> 8 and ( 9 7 ) - > 16 then  8 + 16 = 24
# Hint: ( 1 8 ) -> -7 and ( 9 8 ) - > 17 then  17 - -7 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 1 8 ) -> -7 then ( -7 2 ) - > -14 then  10 - -14 = 24
# Hint: ( 1 10 ) -> 9 and ( 8 3 ) - > 2.6666666666666665 then  9 * 2.6666666666666665 = 24
# Sorry, no way to make 24
# Hint: ( 1 8 ) -> 9 and ( 10 5 ) - > 15 then  9 + 15 = 24
# Hint: ( 1 8 ) -> 8 and ( 10 6 ) - > 16 then  8 + 16 = 24
# Hint: ( 1 8 ) -> -7 and ( 10 7 ) - > 17 then  17 - -7 = 24
# Hint: ( 1 8 ) -> -7 then ( -7 10 ) - > 3 then  3 * 8 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 1 9 ) -> 8 and ( 1 2 ) - > 3 then  8 * 3 = 24
# Hint: ( 1 9 ) -> 8 and ( 1 3 ) - > 3 then  8 * 3 = 24
# Hint: ( 1 9 ) -> -8 and ( 1 4 ) - > -3 then  -8 * -3 = 24
# Sorry, no way to make 24
# Hint: ( 1 1 ) -> 2 then ( 2 9 ) - > 18 then  18 + 6 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 1 9 ) -> 8 and ( 2 1 ) - > 3 then  8 * 3 = 24
# Hint: ( 1 9 ) -> 10 then ( 10 2 ) - > 12 then  12 * 2 = 24
# Hint: ( 1 2 ) -> 3 and ( 9 3 ) - > 27 then  27 - 3 = 24
# Hint: ( 1 9 ) -> 10 then ( 10 2 ) - > 20 then  20 + 4 = 24
# Hint: ( 1 9 ) -> -8 and ( 2 5 ) - > -3 then  -8 * -3 = 24
# Hint: ( 1 9 ) -> 8 and ( 2 6 ) - > 0.3333333333333333 then  8 / 0.3333333333333333 = 24
# Hint: ( 1 9 ) -> 10 and ( 2 7 ) - > 14 then  10 + 14 = 24
# Hint: ( 1 9 ) -> -8 and ( 2 8 ) - > 16 then  16 - -8 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 1 9 ) -> 8 and ( 3 1 ) - > 3 then  8 * 3 = 24
# Hint: ( 1 2 ) -> 3 and ( 9 3 ) - > 27 then  27 - 3 = 24
# Hint: ( 1 3 ) -> 4 and ( 9 3 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 4 ) -> -3 and ( 9 3 ) - > 27 then  -3 + 27 = 24
# Hint: ( 1 9 ) -> 9 and ( 3 5 ) - > 15 then  9 + 15 = 24
# Hint: ( 1 9 ) -> -8 and ( 3 6 ) - > -3 then  -8 * -3 = 24
# Hint: ( 1 7 ) -> 8 and ( 9 3 ) - > 3.0 then  8 * 3.0 = 24
# Hint: ( 1 9 ) -> 9 and ( 3 8 ) - > 0.375 then  9 / 0.375 = 24
# Hint: ( 1 9 ) -> 8 and ( 3 9 ) - > 0.3333333333333333 then  8 / 0.3333333333333333 = 24
# Hint: ( 1 10 ) -> 11 then ( 11 3 ) - > 33 then  33 - 9 = 24
# Hint: ( 1 9 ) -> -8 and ( 4 1 ) - > -3 then  -8 * -3 = 24
# Hint: ( 1 9 ) -> -8 then ( -8 4 ) - > 12 then  12 * 2 = 24
# Hint: ( 1 4 ) -> -3 and ( 9 3 ) - > 27 then  -3 + 27 = 24
# Hint: ( 1 9 ) -> -8 and ( 4 4 ) - > 16 then  16 - -8 = 24
# Hint: ( 1 4 ) -> -3 then ( -3 5 ) - > -15 then  9 - -15 = 24
# Hint: ( 1 9 ) -> 8 then ( 8 4 ) - > 4 then  4 * 6 = 24
# Hint: ( 1 9 ) -> -8 and ( 4 7 ) - > -3 then  -8 * -3 = 24
# Hint: ( 1 9 ) -> -8 and ( 4 8 ) - > 32 then  -8 + 32 = 24
# Sorry, no way to make 24
# Hint: ( 1 9 ) -> 10 and ( 4 10 ) - > 14 then  10 + 14 = 24
# Sorry, no way to make 24
# Hint: ( 1 9 ) -> -8 and ( 5 2 ) - > -3 then  -8 * -3 = 24
# Hint: ( 1 9 ) -> 9 and ( 5 3 ) - > 15 then  9 + 15 = 24
# Hint: ( 1 4 ) -> -3 then ( -3 5 ) - > -15 then  9 - -15 = 24
# Hint: ( 1 5 ) -> 6 and ( 9 5 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 6 ) -> 6 and ( 9 5 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 7 ) -> -6 and ( 9 5 ) - > -4 then  -6 * -4 = 24
# Hint: ( 1 9 ) -> -8 and ( 5 8 ) - > -3 then  -8 * -3 = 24
# Hint: ( 1 9 ) -> 10 and ( 5 9 ) - > 14 then  10 + 14 = 24
# Hint: ( 1 9 ) -> 9 and ( 5 10 ) - > 15 then  9 + 15 = 24
# Hint: ( 1 1 ) -> 2 then ( 2 9 ) - > 18 then  18 + 6 = 24
# Hint: ( 1 9 ) -> 8 and ( 6 2 ) - > 3.0 then  8 * 3.0 = 24
# Hint: ( 1 9 ) -> -8 and ( 6 3 ) - > -3 then  -8 * -3 = 24
# Hint: ( 1 9 ) -> 8 then ( 8 4 ) - > 4 then  4 * 6 = 24
# Hint: ( 1 6 ) -> 6 and ( 9 5 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 9 ) -> 10 then ( 10 6 ) - > 4 then  4 * 6 = 24
# Hint: ( 1 7 ) -> 8 and ( 9 6 ) - > 3 then  8 * 3 = 24
# Hint: ( 1 9 ) -> 10 and ( 6 8 ) - > 14 then  10 + 14 = 24
# Hint: ( 1 9 ) -> -8 and ( 6 9 ) - > -3 then  -8 * -3 = 24
# Hint: ( 1 9 ) -> -8 and ( 6 10 ) - > 16 then  16 - -8 = 24
# Sorry, no way to make 24
# Hint: ( 1 9 ) -> 10 and ( 7 2 ) - > 14 then  10 + 14 = 24
# Hint: ( 1 7 ) -> 8 and ( 9 3 ) - > 3.0 then  8 * 3.0 = 24
# Hint: ( 1 9 ) -> -8 and ( 7 4 ) - > -3 then  -8 * -3 = 24
# Hint: ( 1 7 ) -> -6 and ( 9 5 ) - > -4 then  -6 * -4 = 24
# Hint: ( 1 7 ) -> 8 and ( 9 6 ) - > 3 then  8 * 3 = 24
# Hint: ( 1 9 ) -> 10 and ( 7 7 ) - > 14 then  10 + 14 = 24
# Hint: ( 1 9 ) -> 9 and ( 7 8 ) - > 15 then  9 + 15 = 24
# Hint: ( 1 9 ) -> -8 and ( 7 9 ) - > 16 then  16 - -8 = 24
# Hint: ( 1 9 ) -> -8 and ( 7 10 ) - > -3 then  -8 * -3 = 24
# Sorry, no way to make 24
# Hint: ( 1 9 ) -> -8 and ( 8 2 ) - > 16 then  16 - -8 = 24
# Hint: ( 1 9 ) -> 9 and ( 8 3 ) - > 2.6666666666666665 then  9 * 2.6666666666666665 = 24
# Hint: ( 1 9 ) -> -8 and ( 8 4 ) - > 32 then  -8 + 32 = 24
# Hint: ( 1 9 ) -> -8 and ( 8 5 ) - > -3 then  -8 * -3 = 24
# Hint: ( 1 9 ) -> 10 and ( 8 6 ) - > 14 then  10 + 14 = 24
# Hint: ( 1 9 ) -> 9 and ( 8 7 ) - > 15 then  9 + 15 = 24
# Hint: ( 1 9 ) -> -8 and ( 8 8 ) - > 16 then  16 - -8 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 1 9 ) -> 8 and ( 9 3 ) - > 3.0 then  8 * 3.0 = 24
# Sorry, no way to make 24
# Hint: ( 1 9 ) -> 10 and ( 9 5 ) - > 14 then  10 + 14 = 24
# Hint: ( 1 9 ) -> -8 and ( 9 6 ) - > -3 then  -8 * -3 = 24
# Hint: ( 1 9 ) -> -8 and ( 9 7 ) - > 16 then  16 - -8 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 1 10 ) -> 11 then ( 11 3 ) - > 33 then  33 - 9 = 24
# Hint: ( 1 9 ) -> 10 and ( 10 4 ) - > 14 then  10 + 14 = 24
# Hint: ( 1 9 ) -> 9 and ( 10 5 ) - > 15 then  9 + 15 = 24
# Hint: ( 1 9 ) -> -8 and ( 10 6 ) - > 16 then  16 - -8 = 24
# Hint: ( 1 9 ) -> -8 and ( 10 7 ) - > -3 then  -8 * -3 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 1 1 ) -> 2 and ( 10 2 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 10 ) -> 9 then ( 9 1 ) - > 8 then  8 * 3 = 24
# Hint: ( 1 1 ) -> 2 then ( 2 10 ) - > 20 then  20 + 4 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 1 1 ) -> 2 then ( 2 7 ) - > 14 then  14 + 10 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 1 1 ) -> 2 and ( 10 2 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 2 ) -> 3 and ( 10 2 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 3 ) -> 4 and ( 10 2 ) - > 20 then  4 + 20 = 24
# Hint: ( 1 4 ) -> -3 and ( 10 2 ) - > -8 then  -3 * -8 = 24
# Hint: ( 1 5 ) -> -4 and ( 10 2 ) - > 20 then  20 - -4 = 24
# Hint: ( 1 10 ) -> -9 then ( -9 2 ) - > -18 then  6 - -18 = 24
# Hint: ( 1 10 ) -> 10 and ( 2 7 ) - > 14 then  10 + 14 = 24
# Hint: ( 1 8 ) -> -7 then ( -7 2 ) - > -14 then  10 - -14 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 1 10 ) -> 9 then ( 9 1 ) - > 8 then  8 * 3 = 24
# Hint: ( 1 3 ) -> 4 and ( 10 2 ) - > 20 then  4 + 20 = 24
# Hint: ( 1 10 ) -> 11 then ( 11 3 ) - > 8 then  8 * 3 = 24
# Hint: ( 1 3 ) -> 4 and ( 10 4 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 10 ) -> -9 and ( 3 5 ) - > 15 then  15 - -9 = 24
# Hint: ( 1 6 ) -> 6 and ( 10 3 ) - > 30 then  30 - 6 = 24
# Hint: ( 1 7 ) -> -6 and ( 10 3 ) - > 30 then  -6 + 30 = 24
# Hint: ( 1 10 ) -> 9 and ( 3 8 ) - > 0.375 then  9 / 0.375 = 24
# Hint: ( 1 10 ) -> 11 then ( 11 3 ) - > 33 then  33 - 9 = 24
# Hint: ( 1 10 ) -> 11 and ( 3 10 ) - > 13 then  11 + 13 = 24
# Hint: ( 1 1 ) -> 2 then ( 2 10 ) - > 20 then  20 + 4 = 24
# Hint: ( 1 4 ) -> -3 and ( 10 2 ) - > -8 then  -3 * -8 = 24
# Hint: ( 1 3 ) -> 4 and ( 10 4 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 4 ) -> 4 and ( 10 4 ) - > 6 then  4 * 6 = 24
# ...
# Hint: ( 10 7 ) -> 3 and ( 7 3 ) - > 21 then  3 + 21 = 24
# Sorry, no way to make 24
# Hint: ( 7 5 ) -> 2 then ( 2 7 ) - > 14 then  14 + 10 = 24
# Hint: ( 10 7 ) -> 3 then ( 3 7 ) - > 4 then  4 * 6 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 7 9 ) -> -2 then ( -2 7 ) - > -14 then  10 - -14 = 24
# Sorry, no way to make 24
# Hint: ( 10 7 ) -> 17 and ( 8 1 ) - > 7 then  17 + 7 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 7 8 ) -> 56 then ( 56 4 ) - > 14.0 then  14.0 + 10 = 24
# Hint: ( 10 8 ) -> 2 and ( 7 5 ) - > 12 then  2 * 12 = 24
# Hint: ( 10 8 ) -> 18 and ( 7 6 ) - > 42 then  42 - 18 = 24
# Sorry, no way to make 24
# Hint: ( 10 8 ) -> 80 and ( 7 8 ) - > 56 then  80 - 56 = 24
# Hint: ( 10 7 ) -> 3 and ( 8 9 ) - > 72 then  72 / 3 = 24
# Hint: ( 10 8 ) -> 2 then ( 2 7 ) - > 14 then  14 + 10 = 24
# Hint: ( 10 7 ) -> 3 and ( 9 1 ) - > 8 then  3 * 8 = 24
# Hint: ( 10 7 ) -> 17 and ( 9 2 ) - > 7 then  17 + 7 = 24
# Hint: ( 10 7 ) -> 3 and ( 9 3 ) - > 27 then  27 - 3 = 24
# Hint: ( 10 4 ) -> 40 and ( 7 9 ) - > 16 then  40 - 16 = 24
# Hint: ( 10 7 ) -> 3 then ( 3 5 ) - > 15 then  15 + 9 = 24
# Sorry, no way to make 24
# Hint: ( 7 9 ) -> -2 then ( -2 7 ) - > -14 then  10 - -14 = 24
# Hint: ( 10 7 ) -> 3 and ( 9 8 ) - > 72 then  72 / 3 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 10 7 ) -> 3 and ( 10 2 ) - > 8 then  3 * 8 = 24
# Hint: ( 10 7 ) -> 17 and ( 10 3 ) - > 7 then  17 + 7 = 24
# Hint: ( 10 10 ) -> 1.0 then ( 1.0 7 ) - > 6.0 then  6.0 * 4 = 24
# Hint: ( 10 7 ) -> 70 then ( 70 5 ) - > 14.0 then  14.0 + 10 = 24
# Hint: ( 10 7 ) -> 3 then ( 3 10 ) - > 30 then  30 - 6 = 24
# Sorry, no way to make 24
# Hint: ( 10 8 ) -> 2 then ( 2 7 ) - > 14 then  14 + 10 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 8 1 ) -> 7 then ( 7 2 ) - > 14 then  14 + 10 = 24
# Hint: ( 10 1 ) -> 9 and ( 8 3 ) - > 2.6666666666666665 then  9 * 2.6666666666666665 = 24
# Sorry, no way to make 24
# Hint: ( 10 8 ) -> 18 and ( 1 5 ) - > 6 then  18 + 6 = 24
# Hint: ( 10 8 ) -> 18 and ( 1 6 ) - > 6 then  18 + 6 = 24
# Hint: ( 10 8 ) -> 18 and ( 1 7 ) - > -6 then  18 - -6 = 24
# Hint: ( 10 8 ) -> 2 then ( 2 1 ) - > 3 then  3 * 8 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 8 1 ) -> 7 then ( 7 2 ) - > 14 then  14 + 10 = 24
# Hint: ( 10 2 ) -> 8 and ( 8 2 ) - > 16 then  8 + 16 = 24
# Hint: ( 10 8 ) -> 18 and ( 2 3 ) - > 6 then  18 + 6 = 24
# Hint: ( 10 8 ) -> 18 and ( 2 4 ) - > 6 then  18 + 6 = 24
# Hint: ( 10 2 ) -> 8 and ( 8 5 ) - > 3 then  8 * 3 = 24
# Hint: ( 10 8 ) -> 2 and ( 2 6 ) - > 12 then  2 * 12 = 24
# Sorry, no way to make 24
# Hint: ( 10 8 ) -> 18 and ( 2 8 ) - > -6 then  18 - -6 = 24
# Hint: ( 10 2 ) -> 12 then ( 12 9 ) - > 3 then  3 * 8 = 24
# Hint: ( 10 8 ) -> 2 and ( 2 10 ) - > 12 then  2 * 12 = 24
# Hint: ( 10 1 ) -> 9 and ( 8 3 ) - > 2.6666666666666665 then  9 * 2.6666666666666665 = 24
# Hint: ( 10 8 ) -> 18 and ( 3 2 ) - > 6 then  18 + 6 = 24
# Hint: ( 10 8 ) -> 18 and ( 3 3 ) - > 6 then  18 + 6 = 24
# Hint: ( 10 8 ) -> 18 and ( 3 4 ) - > 0.75 then  18 / 0.75 = 24
# Sorry, no way to make 24
# Hint: ( 10 8 ) -> 2 then ( 2 6 ) - > 8 then  8 * 3 = 24
# Sorry, no way to make 24
# Hint: ( 10 8 ) -> 80 then ( 80 8 ) - > 72 then  72 / 3 = 24
# Hint: ( 10 8 ) -> 18 and ( 3 9 ) - > -6 then  18 - -6 = 24
# Hint: ( 10 8 ) -> 80 and ( 3 10 ) - > 0.3 then  80 * 0.3 = 24
# Sorry, no way to make 24
# Hint: ( 10 8 ) -> 18 and ( 4 2 ) - > 6 then  18 + 6 = 24
# Hint: ( 10 8 ) -> 18 and ( 4 3 ) - > 1.3333333333333333 then  18 * 1.3333333333333333 = 24
# Hint: ( 10 4 ) -> 6 and ( 8 4 ) - > 4 then  6 * 4 = 24
# Hint: ( 10 5 ) -> 2.0 and ( 8 4 ) - > 12 then  2.0 * 12 = 24
# Hint: ( 10 6 ) -> 4 then ( 4 4 ) - > 16 then  16 + 8 = 24
# Hint: ( 8 4 ) -> 2.0 then ( 2.0 7 ) - > 14.0 then  14.0 + 10 = 24
# Hint: ( 10 8 ) -> 2 and ( 4 8 ) - > 12 then  2 * 12 = 24
# Hint: ( 10 4 ) -> 6 then ( 6 9 ) - > 3 then  3 * 8 = 24
# Hint: ( 10 8 ) -> 18 and ( 4 10 ) - > -6 then  18 - -6 = 24
# Hint: ( 10 8 ) -> 18 and ( 5 1 ) - > 6 then  18 + 6 = 24
# Hint: ( 10 2 ) -> 8 and ( 8 5 ) - > 3 then  8 * 3 = 24
# Sorry, no way to make 24
# Hint: ( 10 5 ) -> 2.0 and ( 8 4 ) - > 12 then  2.0 * 12 = 24
# Hint: ( 10 5 ) -> 15 and ( 8 5 ) - > 1.6 then  15 * 1.6 = 24
# Hint: ( 10 8 ) -> 1.25 and ( 5 6 ) - > 30 then  30 / 1.25 = 24
# Hint: ( 10 8 ) -> 2 and ( 5 7 ) - > 12 then  2 * 12 = 24
# Hint: ( 10 8 ) -> 2 then ( 2 5 ) - > 3 then  3 * 8 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 10 8 ) -> 18 and ( 6 1 ) - > 6 then  18 + 6 = 24
# Hint: ( 10 8 ) -> 2 and ( 6 2 ) - > 12 then  2 * 12 = 24
# Hint: ( 10 8 ) -> 2 then ( 2 6 ) - > 8 then  8 * 3 = 24
# Hint: ( 10 6 ) -> 4 then ( 4 4 ) - > 16 then  16 + 8 = 24
# Hint: ( 10 8 ) -> 1.25 and ( 6 5 ) - > 30 then  30 / 1.25 = 24
# Hint: ( 10 8 ) -> 2 and ( 6 6 ) - > 12 then  2 * 12 = 24
# Hint: ( 10 8 ) -> 18 and ( 6 7 ) - > 42 then  42 - 18 = 24
# Hint: ( 10 8 ) -> 18 and ( 6 8 ) - > 0.75 then  18 / 0.75 = 24
# Hint: ( 10 8 ) -> 2 then ( 2 9 ) - > 18 then  18 + 6 = 24
# Sorry, no way to make 24
# Hint: ( 10 8 ) -> 18 and ( 7 1 ) - > 6 then  18 + 6 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 8 7 ) -> 56 then ( 56 4 ) - > 14.0 then  14.0 + 10 = 24
# Hint: ( 10 8 ) -> 2 and ( 7 5 ) - > 12 then  2 * 12 = 24
# Hint: ( 10 8 ) -> 18 and ( 7 6 ) - > 42 then  42 - 18 = 24
# Sorry, no way to make 24
# Hint: ( 10 8 ) -> 80 and ( 7 8 ) - > 56 then  80 - 56 = 24
# Hint: ( 10 7 ) -> 3 and ( 8 9 ) - > 72 then  72 / 3 = 24
# Hint: ( 10 8 ) -> 2 then ( 2 7 ) - > 14 then  14 + 10 = 24
# Hint: ( 10 8 ) -> 2 then ( 2 1 ) - > 3 then  3 * 8 = 24
# Hint: ( 10 8 ) -> 18 and ( 8 2 ) - > 6 then  18 + 6 = 24
# Hint: ( 10 8 ) -> 80 then ( 80 8 ) - > 72 then  72 / 3 = 24
# Hint: ( 10 8 ) -> 2 and ( 8 4 ) - > 12 then  2 * 12 = 24
# Hint: ( 10 8 ) -> 2 then ( 2 5 ) - > 3 then  3 * 8 = 24
# Hint: ( 10 8 ) -> 18 and ( 8 6 ) - > 1.3333333333333333 then  18 * 1.3333333333333333 = 24
# Hint: ( 10 8 ) -> 80 and ( 8 7 ) - > 56 then  80 - 56 = 24
# Hint: ( 10 8 ) -> 2 then ( 2 8 ) - > 16 then  16 + 8 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 10 9 ) -> 1 then ( 1 2 ) - > 3 then  3 * 8 = 24
# Hint: ( 10 8 ) -> 18 and ( 9 3 ) - > 6 then  18 + 6 = 24
# Hint: ( 10 9 ) -> 1 then ( 1 4 ) - > 3 then  3 * 8 = 24
# Sorry, no way to make 24
# Hint: ( 10 8 ) -> 2 then ( 2 9 ) - > 18 then  18 + 6 = 24
# Hint: ( 10 7 ) -> 3 and ( 8 9 ) - > 72 then  72 / 3 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 10 8 ) -> 2 and ( 10 2 ) - > 12 then  2 * 12 = 24
# Hint: ( 10 8 ) -> 80 and ( 10 3 ) - > 3.3333333333333335 then  80 / 3.3333333333333335 = 24
# Hint: ( 10 8 ) -> 18 and ( 10 4 ) - > 6 then  18 + 6 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 10 8 ) -> 2 then ( 2 7 ) - > 14 then  14 + 10 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 10 1 ) -> 11 then ( 11 3 ) - > 33 then  33 - 9 = 24
# Hint: ( 10 9 ) -> 19 and ( 1 4 ) - > 5 then  19 + 5 = 24
# Hint: ( 10 9 ) -> 19 and ( 1 5 ) - > 5 then  19 + 5 = 24
# Hint: ( 10 9 ) -> 19 and ( 1 6 ) - > -5 then  19 - -5 = 24
# Hint: ( 10 7 ) -> 3 and ( 9 1 ) - > 8 then  3 * 8 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 9 2 ) -> 7 then ( 7 2 ) - > 14 then  14 + 10 = 24
# Hint: ( 10 9 ) -> 19 and ( 2 3 ) - > 5 then  19 + 5 = 24
# Hint: ( 10 2 ) -> 12 and ( 9 4 ) - > 36 then  36 - 12 = 24
# Hint: ( 10 2 ) -> 20 and ( 9 5 ) - > 4 then  20 + 4 = 24
# Hint: ( 10 2 ) -> 8 and ( 9 6 ) - > 3 then  8 * 3 = 24
# Hint: ( 10 9 ) -> 19 and ( 2 7 ) - > -5 then  19 - -5 = 24
# Hint: ( 10 9 ) -> 1 then ( 1 2 ) - > 3 then  3 * 8 = 24
# Sorry, no way to make 24
# Hint: ( 10 9 ) -> 19 and ( 2 10 ) - > 5.0 then  19 + 5.0 = 24
# Hint: ( 10 1 ) -> 11 then ( 11 3 ) - > 33 then  33 - 9 = 24
# Hint: ( 10 9 ) -> 19 and ( 3 2 ) - > 5 then  19 + 5 = 24
# Hint: ( 10 3 ) -> 30 and ( 9 3 ) - > 6 then  30 - 6 = 24
# Sorry, no way to make 24
# Hint: ( 10 5 ) -> 2.0 and ( 9 3 ) - > 12 then  2.0 * 12 = 24
# Hint: ( 10 3 ) -> 30 and ( 9 6 ) - > 54 then  54 - 30 = 24
# Hint: ( 10 7 ) -> 3 and ( 9 3 ) - > 27 then  27 - 3 = 24
# Hint: ( 10 9 ) -> 19 and ( 3 8 ) - > -5 then  19 - -5 = 24
# Hint: ( 10 9 ) -> 1 then ( 1 9 ) - > 8 then  8 * 3 = 24
# Hint: ( 10 10 ) -> 1.0 then ( 1.0 9 ) - > 8.0 then  8.0 * 3 = 24
# Hint: ( 10 9 ) -> 19 and ( 4 1 ) - > 5 then  19 + 5 = 24
# Hint: ( 10 4 ) -> 6 and ( 9 2 ) - > 18 then  6 + 18 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 10 4 ) -> 6 and ( 9 5 ) - > 4 then  6 * 4 = 24
# Hint: ( 10 9 ) -> 1 and ( 4 6 ) - > 24 then  1 * 24 = 24
# Hint: ( 10 4 ) -> 40 and ( 9 7 ) - > 16 then  40 - 16 = 24
# Hint: ( 10 9 ) -> 1 then ( 1 4 ) - > 3 then  3 * 8 = 24
# Hint: ( 10 9 ) -> 19 and ( 4 9 ) - > -5 then  19 - -5 = 24
# Sorry, no way to make 24
# Hint: ( 10 9 ) -> 19 and ( 5 1 ) - > 5 then  19 + 5 = 24
# Hint: ( 10 2 ) -> 20 and ( 9 5 ) - > 4 then  20 + 4 = 24
# Hint: ( 10 5 ) -> 2.0 and ( 9 3 ) - > 12 then  2.0 * 12 = 24
# Hint: ( 10 4 ) -> 6 and ( 9 5 ) - > 4 then  6 * 4 = 24
# Hint: ( 10 9 ) -> 1 and ( 5 5 ) - > 25 then  25 - 1 = 24
# Hint: ( 10 9 ) -> 1 then ( 1 5 ) - > 4 then  4 * 6 = 24
# Hint: ( 10 7 ) -> 3 then ( 3 5 ) - > 15 then  15 + 9 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 10 9 ) -> 19 and ( 5 10 ) - > -5 then  19 - -5 = 24
# Hint: ( 10 9 ) -> 19 and ( 6 1 ) - > 5 then  19 + 5 = 24
# Hint: ( 10 2 ) -> 8 and ( 9 6 ) - > 3 then  8 * 3 = 24
# Hint: ( 10 6 ) -> 4 and ( 9 3 ) - > 6 then  4 * 6 = 24
# Hint: ( 10 9 ) -> 1 and ( 6 4 ) - > 24 then  1 * 24 = 24
# Hint: ( 10 9 ) -> 1 then ( 1 5 ) - > 4 then  4 * 6 = 24
# Hint: ( 10 6 ) -> 16 and ( 9 6 ) - > 1.5 then  16 * 1.5 = 24
# Sorry, no way to make 24
# Hint: ( 10 8 ) -> 2 then ( 2 9 ) - > 18 then  18 + 6 = 24
# Hint: ( 10 9 ) -> 90 then ( 90 6 ) - > 15.0 then  15.0 + 9 = 24
# Sorry, no way to make 24
# Hint: ( 10 7 ) -> 3 and ( 9 1 ) - > 8 then  3 * 8 = 24
# Hint: ( 10 9 ) -> 19 and ( 7 2 ) - > 5 then  19 + 5 = 24
# Hint: ( 10 7 ) -> 3 and ( 9 3 ) - > 27 then  27 - 3 = 24
# Hint: ( 10 4 ) -> 40 and ( 9 7 ) - > 16 then  40 - 16 = 24
# Hint: ( 10 7 ) -> 3 then ( 3 5 ) - > 15 then  15 + 9 = 24
# Sorry, no way to make 24
# Hint: ( 9 7 ) -> 2 then ( 2 7 ) - > 14 then  14 + 10 = 24
# Hint: ( 10 7 ) -> 3 and ( 9 8 ) - > 72 then  72 / 3 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 10 9 ) -> 1 then ( 1 2 ) - > 3 then  3 * 8 = 24
# Hint: ( 10 9 ) -> 19 and ( 8 3 ) - > 5 then  19 + 5 = 24
# Hint: ( 10 9 ) -> 1 then ( 1 4 ) - > 3 then  3 * 8 = 24
# Sorry, no way to make 24
# Hint: ( 10 8 ) -> 2 then ( 2 9 ) - > 18 then  18 + 6 = 24
# Hint: ( 10 7 ) -> 3 and ( 9 8 ) - > 72 then  72 / 3 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 10 9 ) -> 1 then ( 1 9 ) - > 8 then  8 * 3 = 24
# Hint: ( 10 9 ) -> 19 and ( 9 4 ) - > 5 then  19 + 5 = 24
# Sorry, no way to make 24
# Hint: ( 10 9 ) -> 90 then ( 90 6 ) - > 15.0 then  15.0 + 9 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 10 9 ) -> 19 and ( 10 2 ) - > 5.0 then  19 + 5.0 = 24
# Hint: ( 10 10 ) -> 1.0 then ( 1.0 9 ) - > 8.0 then  8.0 * 3 = 24
# Sorry, no way to make 24
# Hint: ( 10 9 ) -> 19 and ( 10 5 ) - > 5 then  19 + 5 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 10 10 ) -> 20 and ( 1 3 ) - > 4 then  20 + 4 = 24
# Hint: ( 10 10 ) -> 20 and ( 1 4 ) - > 4 then  20 + 4 = 24
# Hint: ( 10 10 ) -> 20 and ( 1 5 ) - > -4 then  20 - -4 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 10 10 ) -> 20 and ( 2 2 ) - > 4 then  20 + 4 = 24
# Hint: ( 10 3 ) -> 7 then ( 7 2 ) - > 14 then  14 + 10 = 24
# Hint: ( 10 4 ) -> 0.4 then ( 0.4 2 ) - > 2.4 then  2.4 * 10 = 24
# Hint: ( 10 2 ) -> 12 and ( 10 5 ) - > 2.0 then  12 * 2.0 = 24
# Hint: ( 10 10 ) -> 20 and ( 2 6 ) - > -4 then  20 - -4 = 24
# Hint: ( 10 2 ) -> 8 and ( 10 7 ) - > 3 then  8 * 3 = 24
# Hint: ( 10 10 ) -> 20 and ( 2 8 ) - > 4.0 then  20 + 4.0 = 24
# Hint: ( 10 2 ) -> 5.0 and ( 10 9 ) - > 19 then  5.0 + 19 = 24
# Sorry, no way to make 24
# Hint: ( 10 10 ) -> 20 and ( 3 1 ) - > 4 then  20 + 4 = 24
# Hint: ( 10 3 ) -> 7 then ( 7 2 ) - > 14 then  14 + 10 = 24
# Sorry, no way to make 24
# Hint: ( 10 3 ) -> 30 and ( 10 4 ) - > 6 then  30 - 6 = 24
# Hint: ( 10 5 ) -> 2.0 then ( 2.0 10 ) - > 8.0 then  8.0 * 3 = 24
# Hint: ( 10 10 ) -> 1.0 then ( 1.0 3 ) - > 4.0 then  4.0 * 6 = 24
# Hint: ( 10 10 ) -> 20 and ( 3 7 ) - > -4 then  20 - -4 = 24
# Hint: ( 10 10 ) -> 0 and ( 3 8 ) - > 24 then  0 + 24 = 24
# Hint: ( 10 10 ) -> 1.0 then ( 1.0 9 ) - > 8.0 then  8.0 * 3 = 24
# Sorry, no way to make 24
# Hint: ( 10 10 ) -> 20 and ( 4 1 ) - > 4 then  20 + 4 = 24
# Hint: ( 10 4 ) -> 0.4 then ( 0.4 2 ) - > 2.4 then  2.4 * 10 = 24
# Hint: ( 10 4 ) -> 6 and ( 10 3 ) - > 30 then  30 - 6 = 24
# Hint: ( 10 10 ) -> 100 then ( 100 4 ) - > 96 then  96 / 4 = 24
# Hint: ( 10 10 ) -> 100 then ( 100 5 ) - > 20.0 then  20.0 + 4 = 24
# Hint: ( 10 10 ) -> 0 and ( 4 6 ) - > 24 then  0 + 24 = 24
# Hint: ( 10 10 ) -> 1.0 then ( 1.0 7 ) - > 6.0 then  6.0 * 4 = 24
# Hint: ( 10 10 ) -> 20 and ( 4 8 ) - > -4 then  20 - -4 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 10 10 ) -> 20 and ( 5 1 ) - > 4 then  20 + 4 = 24
# Hint: ( 10 5 ) -> 2.0 and ( 10 2 ) - > 12 then  2.0 * 12 = 24
# Hint: ( 10 5 ) -> 2.0 then ( 2.0 10 ) - > 8.0 then  8.0 * 3 = 24
# Hint: ( 10 10 ) -> 100 then ( 100 5 ) - > 20.0 then  20.0 + 4 = 24
# Hint: ( 10 10 ) -> 1.0 and ( 5 5 ) - > 25 then  25 - 1.0 = 24
# Hint: ( 10 10 ) -> 20 and ( 5 6 ) - > 0.8333333333333334 then  20 / 0.8333333333333334 = 24
# Hint: ( 10 5 ) -> 2.0 then ( 2.0 7 ) - > 14.0 then  14.0 + 10 = 24
# Sorry, no way to make 24
# Hint: ( 10 10 ) -> 20 and ( 5 9 ) - > -4 then  20 - -4 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 10 10 ) -> 20 and ( 6 2 ) - > 4 then  20 + 4 = 24
# Hint: ( 10 10 ) -> 1.0 then ( 1.0 3 ) - > 4.0 then  4.0 * 6 = 24
# Hint: ( 10 10 ) -> 0 and ( 6 4 ) - > 24 then  0 + 24 = 24
# Hint: ( 10 10 ) -> 20 and ( 6 5 ) - > 1.2 then  20 * 1.2 = 24
# Sorry, no way to make 24
# Hint: ( 10 7 ) -> 3 then ( 3 10 ) - > 30 then  30 - 6 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 10 10 ) -> 20 and ( 6 10 ) - > -4 then  20 - -4 = 24
# Sorry, no way to make 24
# Hint: ( 10 7 ) -> 3 and ( 10 2 ) - > 8 then  3 * 8 = 24
# Hint: ( 10 10 ) -> 20 and ( 7 3 ) - > 4 then  20 + 4 = 24
# Hint: ( 10 10 ) -> 1.0 then ( 1.0 7 ) - > 6.0 then  6.0 * 4 = 24
# Hint: ( 10 7 ) -> 70 then ( 70 5 ) - > 14.0 then  14.0 + 10 = 24
# Hint: ( 10 7 ) -> 3 then ( 3 10 ) - > 30 then  30 - 6 = 24
# Sorry, no way to make 24
# Hint: ( 10 8 ) -> 2 then ( 2 7 ) - > 14 then  14 + 10 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 10 10 ) -> 20 and ( 8 2 ) - > 4.0 then  20 + 4.0 = 24
# Hint: ( 10 10 ) -> 0 and ( 8 3 ) - > 24 then  0 + 24 = 24
# Hint: ( 10 10 ) -> 20 and ( 8 4 ) - > 4 then  20 + 4 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 10 8 ) -> 2 then ( 2 7 ) - > 14 then  14 + 10 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 10 9 ) -> 19 and ( 10 2 ) - > 5.0 then  19 + 5.0 = 24
# Hint: ( 10 10 ) -> 1.0 then ( 1.0 9 ) - > 8.0 then  8.0 * 3 = 24
# Sorry, no way to make 24
# Hint: ( 10 10 ) -> 20 and ( 9 5 ) - > 4 then  20 + 4 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 10 10 ) -> 20 and ( 10 6 ) - > 4 then  20 + 4 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# 8558 out of 10000 number of combinations can make 24 ratio is 0.8558

# %% [markdown]
# ### Now Consider J, Q and K, which are count as 11, 12, 13

# %%
p = 0
t = 0
# p is a counter. If one combination can make 24, then t+1
# t is to count how many total tests have been made. It can be estimated easily, but I put it here to track if there is any bug
for a in range (1,14):
    for b in range (1,14):
        for c in range (1,14):
            for d in range (1,14):
                x = Is24(a, b, c, d)
                t = t+1
                if x == 1:
                    p = p+1

print(p, 'out of', t, 'number of combinations can make', goal, 'ratio is', p/t)
# Out:
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 1 1 ) -> 2 then ( 2 1 ) - > 3 then  3 * 8 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 1 1 ) -> 2 and ( 1 11 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 1 ) -> 2 and ( 1 12 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 1 ) -> 2 and ( 1 13 ) - > 12 then  2 * 12 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 1 1 ) -> 2 and ( 2 6 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 2 ) -> 3 and ( 1 7 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 2 ) -> 3 and ( 1 8 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 2 ) -> 3 and ( 1 9 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 1 ) -> 2 and ( 2 10 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 1 ) -> 2 and ( 2 11 ) - > 22 then  2 + 22 = 24
# Hint: ( 1 1 ) -> 0 and ( 2 12 ) - > 24 then  0 + 24 = 24
# Hint: ( 1 1 ) -> 2 and ( 2 13 ) - > 26 then  26 - 2 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 1 1 ) -> 2 and ( 3 4 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 3 ) -> 4 and ( 1 5 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 3 ) -> 4 and ( 1 6 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 3 ) -> 4 and ( 1 7 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 1 ) -> 0 and ( 3 8 ) - > 24 then  0 + 24 = 24
# Hint: ( 1 1 ) -> 2 and ( 3 9 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 1 ) -> 2 then ( 2 10 ) - > 8 then  8 * 3 = 24
# Hint: ( 1 3 ) -> 2 and ( 1 11 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 3 ) -> 2 and ( 1 12 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 3 ) -> -2 and ( 1 13 ) - > -12 then  -2 * -12 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 1 1 ) -> 2 and ( 4 3 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 1 ) -> 2 then ( 2 4 ) - > 6 then  6 * 4 = 24
# Hint: ( 1 4 ) -> 4 and ( 1 5 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 1 ) -> 0 and ( 4 6 ) - > 24 then  0 + 24 = 24
# Hint: ( 1 4 ) -> 3 and ( 1 7 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 1 ) -> 2 and ( 4 8 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 4 ) -> -3 and ( 1 9 ) - > -8 then  -3 * -8 = 24
# Hint: ( 1 1 ) -> 2 then ( 2 10 ) - > 20 then  20 + 4 = 24
# Sorry, no way to make 24
# Hint: ( 1 1 ) -> 2 and ( 4 12 ) - > 48 then  48 / 2 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 1 5 ) -> 6 and ( 1 3 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 5 ) -> 6 and ( 1 4 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 1 ) -> 1 and ( 5 5 ) - > 25 then  25 - 1 = 24
# Hint: ( 1 5 ) -> 4 and ( 1 6 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 1 ) -> 2 and ( 5 7 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 1 ) -> 2 then ( 2 5 ) - > 3 then  3 * 8 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 1 1 ) -> 2 and ( 6 2 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 6 ) -> 6 and ( 1 3 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 1 ) -> 0 and ( 6 4 ) - > 24 then  0 + 24 = 24
# Hint: ( 1 6 ) -> 6 and ( 1 5 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 1 ) -> 2 and ( 6 6 ) - > 12 then  2 * 12 = 24
# Sorry, no way to make 24
# Hint: ( 1 1 ) -> 2 and ( 6 8 ) - > 48 then  48 / 2 = 24
# Hint: ( 1 1 ) -> 2 then ( 2 9 ) - > 18 then  18 + 6 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 1 1 ) -> 2 then ( 2 6 ) - > 12 then  12 + 12 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 1 7 ) -> 8 and ( 1 2 ) - > 3 then  8 * 3 = 24
# Hint: ( 1 7 ) -> 8 and ( 1 3 ) - > 3 then  8 * 3 = 24
# Hint: ( 1 7 ) -> 8 and ( 1 4 ) - > 3 then  8 * 3 = 24
# Hint: ( 1 1 ) -> 2 and ( 7 5 ) - > 12 then  2 * 12 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 1 1 ) -> 2 then ( 2 7 ) - > 14 then  14 + 10 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 1 1 ) -> 2 then ( 2 1 ) - > 3 then  3 * 8 = 24
# Hint: ( 1 8 ) -> 8 and ( 1 2 ) - > 3 then  8 * 3 = 24
# Hint: ( 1 1 ) -> 0 and ( 8 3 ) - > 24 then  0 + 24 = 24
# Hint: ( 1 1 ) -> 2 and ( 8 4 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 1 ) -> 2 then ( 2 5 ) - > 3 then  3 * 8 = 24
# Hint: ( 1 1 ) -> 2 and ( 8 6 ) - > 48 then  48 / 2 = 24
# Sorry, no way to make 24
# Hint: ( 1 1 ) -> 2 then ( 2 8 ) - > 16 then  16 + 8 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 1 9 ) -> 8 and ( 1 2 ) - > 3 then  8 * 3 = 24
# Hint: ( 1 1 ) -> 2 and ( 9 3 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 9 ) -> -8 and ( 1 4 ) - > -3 then  -8 * -3 = 24
# Sorry, no way to make 24
# Hint: ( 1 1 ) -> 2 then ( 2 9 ) - > 18 then  18 + 6 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 1 1 ) -> 2 and ( 9 13 ) - > 22 then  2 + 22 = 24
# Sorry, no way to make 24
# Hint: ( 1 1 ) -> 2 and ( 10 2 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 1 ) -> 2 then ( 2 10 ) - > 8 then  8 * 3 = 24
# Hint: ( 1 1 ) -> 2 then ( 2 10 ) - > 20 then  20 + 4 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 1 1 ) -> 2 then ( 2 7 ) - > 14 then  14 + 10 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 1 1 ) -> 2 and ( 10 12 ) - > 22 then  2 + 22 = 24
# Hint: ( 1 1 ) -> 1 and ( 10 13 ) - > 23 then  1 + 23 = 24
# Hint: ( 1 1 ) -> 2 and ( 11 1 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 1 ) -> 2 and ( 11 2 ) - > 22 then  2 + 22 = 24
# Hint: ( 1 11 ) -> 12 and ( 1 3 ) - > 2 then  12 * 2 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 1 1 ) -> 2 and ( 11 11 ) - > 22 then  2 + 22 = 24
# Hint: ( 1 1 ) -> 1 and ( 11 12 ) - > 23 then  1 + 23 = 24
# Hint: ( 1 1 ) -> 0 and ( 11 13 ) - > 24 then  0 + 24 = 24
# Hint: ( 1 1 ) -> 2 and ( 12 1 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 1 ) -> 0 and ( 12 2 ) - > 24 then  0 + 24 = 24
# Hint: ( 1 12 ) -> 12 and ( 1 3 ) - > 2 then  12 * 2 = 24
# Hint: ( 1 1 ) -> 2 and ( 12 4 ) - > 48 then  48 / 2 = 24
# Sorry, no way to make 24
# Hint: ( 1 1 ) -> 2 then ( 2 6 ) - > 12 then  12 + 12 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 1 1 ) -> 2 and ( 12 10 ) - > 22 then  2 + 22 = 24
# Hint: ( 1 1 ) -> 1 and ( 12 11 ) - > 23 then  1 + 23 = 24
# Hint: ( 1 1 ) -> 0 and ( 12 12 ) - > 24 then  0 + 24 = 24
# Hint: ( 1 1 ) -> 1 and ( 12 13 ) - > 25 then  25 - 1 = 24
# Hint: ( 1 1 ) -> 2 and ( 13 1 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 1 ) -> 2 and ( 13 2 ) - > 26 then  26 - 2 = 24
# Hint: ( 1 13 ) -> -12 and ( 1 3 ) - > -2 then  -12 * -2 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 1 1 ) -> 2 and ( 13 9 ) - > 22 then  2 + 22 = 24
# Hint: ( 1 1 ) -> 1 and ( 13 10 ) - > 23 then  1 + 23 = 24
# Hint: ( 1 1 ) -> 0 and ( 13 11 ) - > 24 then  0 + 24 = 24
# Hint: ( 1 1 ) -> 1 and ( 13 12 ) - > 25 then  25 - 1 = 24
# Hint: ( 1 1 ) -> 2 and ( 13 13 ) - > 26 then  26 - 2 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 1 1 ) -> 2 and ( 2 6 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 2 ) -> 3 and ( 1 7 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 2 ) -> 3 and ( 1 8 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 2 ) -> 3 and ( 1 9 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 1 ) -> 2 and ( 2 10 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 2 ) -> 2 and ( 1 11 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 2 ) -> 2 and ( 1 12 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 2 ) -> 2 and ( 1 13 ) - > 12 then  2 * 12 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 1 2 ) -> 3 and ( 2 4 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 5 ) -> 6 and ( 2 2 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 2 ) -> 3 and ( 2 6 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 7 ) -> 6 and ( 2 2 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 2 ) -> -1 then ( -1 2 ) - > 3 then  3 * 8 = 24
# Hint: ( 1 2 ) -> 3 then ( 3 9 ) - > 12 then  12 * 2 = 24
# Hint: ( 1 2 ) -> 3 and ( 2 10 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 2 ) -> 2 and ( 2 11 ) - > 22 then  2 + 22 = 24
# Hint: ( 1 2 ) -> 1 and ( 2 12 ) - > 24 then  1 * 24 = 24
# Hint: ( 1 2 ) -> 2 and ( 2 13 ) - > 26 then  26 - 2 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 1 3 ) -> 4 and ( 2 3 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 2 ) -> 2 and ( 3 4 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 2 ) -> 3 and ( 3 5 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 3 ) -> 2 and ( 2 6 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 2 ) -> 3 and ( 3 7 ) - > 21 then  3 + 21 = 24
# Hint: ( 1 2 ) -> 1 and ( 3 8 ) - > 24 then  1 * 24 = 24
# Hint: ( 1 2 ) -> 3 and ( 3 9 ) - > 27 then  27 - 3 = 24
# Hint: ( 1 3 ) -> 4 and ( 2 10 ) - > 20 then  4 + 20 = 24
# Hint: ( 1 2 ) -> 3 and ( 3 11 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 3 ) -> 4 and ( 2 12 ) - > 0.16666666666666666 then  4 / 0.16666666666666666 = 24
# Hint: ( 1 3 ) -> -2 and ( 2 13 ) - > 26 then  -2 + 26 = 24
# Sorry, no way to make 24
# Hint: ( 1 2 ) -> 3 and ( 4 2 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 2 ) -> 2 and ( 4 3 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 2 ) -> 3 and ( 4 4 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 5 ) -> 4 and ( 2 4 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 2 ) -> 1 and ( 4 6 ) - > 24 then  1 * 24 = 24
# Hint: ( 1 2 ) -> -1 then ( -1 7 ) - > 6 then  6 * 4 = 24
# Hint: ( 1 2 ) -> 2 and ( 4 8 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 2 ) -> 3 then ( 3 9 ) - > 6 then  6 * 4 = 24
# Hint: ( 1 4 ) -> -3 and ( 2 10 ) - > -8 then  -3 * -8 = 24
# Hint: ( 1 11 ) -> 12 and ( 2 4 ) - > 2 then  12 * 2 = 24
# Hint: ( 1 2 ) -> 3 and ( 4 12 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 13 ) -> -12 and ( 2 4 ) - > -2 then  -12 * -2 = 24
# Sorry, no way to make 24
# Hint: ( 1 5 ) -> 6 and ( 2 2 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 2 ) -> 3 and ( 5 3 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 5 ) -> 4 and ( 2 4 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 2 ) -> -1 and ( 5 5 ) - > 25 then  -1 + 25 = 24
# Hint: ( 1 5 ) -> 6 and ( 2 6 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 2 ) -> 2 and ( 5 7 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 5 ) -> 6 and ( 2 8 ) - > 0.25 then  6 / 0.25 = 24
# Hint: ( 1 5 ) -> 6 and ( 2 9 ) - > 18 then  6 + 18 = 24
# Hint: ( 1 5 ) -> -4 and ( 2 10 ) - > 20 then  20 - -4 = 24
# Sorry, no way to make 24
# Hint: ( 1 5 ) -> 4 and ( 2 12 ) - > 0.16666666666666666 then  4 / 0.16666666666666666 = 24
# Hint: ( 1 2 ) -> 3 and ( 5 13 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 1 ) -> 2 and ( 2 6 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 2 ) -> 3 and ( 6 2 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 3 ) -> 2 and ( 2 6 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 2 ) -> 1 and ( 6 4 ) - > 24 then  1 * 24 = 24
# Hint: ( 1 5 ) -> 6 and ( 2 6 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 2 ) -> 2 and ( 6 6 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 7 ) -> 8 and ( 2 6 ) - > 0.3333333333333333 then  8 / 0.3333333333333333 = 24
# Hint: ( 1 2 ) -> 2 and ( 6 8 ) - > 48 then  48 / 2 = 24
# Hint: ( 1 6 ) -> 6 and ( 2 9 ) - > 18 then  6 + 18 = 24
# Hint: ( 1 2 ) -> 3 then ( 3 10 ) - > 30 then  30 - 6 = 24
# Hint: ( 1 11 ) -> 12 and ( 2 6 ) - > 12 then  12 + 12 = 24
# Hint: ( 1 2 ) -> 3 and ( 6 12 ) - > 72 then  72 / 3 = 24
# Hint: ( 1 13 ) -> -12 and ( 2 6 ) - > 12 then  12 - -12 = 24
# Hint: ( 1 2 ) -> 3 and ( 7 1 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 7 ) -> 6 and ( 2 2 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 2 ) -> 3 and ( 7 3 ) - > 21 then  3 + 21 = 24
# Hint: ( 1 2 ) -> -1 then ( -1 7 ) - > 6 then  6 * 4 = 24
# Hint: ( 1 2 ) -> 2 and ( 7 5 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 7 ) -> 8 and ( 2 6 ) - > 0.3333333333333333 then  8 / 0.3333333333333333 = 24
# Hint: ( 7 7 ) -> 49 then ( 49 1 ) - > 48 then  48 / 2 = 24
# Hint: ( 1 7 ) -> 8 and ( 2 8 ) - > 16 then  8 + 16 = 24
# Hint: ( 1 7 ) -> -6 and ( 2 9 ) - > 18 then  18 - -6 = 24
# Hint: ( 1 10 ) -> 10 and ( 2 7 ) - > 14 then  10 + 14 = 24
# Hint: ( 1 11 ) -> -10 and ( 2 7 ) - > 14 then  14 - -10 = 24
# Hint: ( 1 7 ) -> -6 then ( -6 2 ) - > -12 then  12 - -12 = 24
# Sorry, no way to make 24
# Hint: ( 1 2 ) -> 3 and ( 8 1 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 2 ) -> -1 then ( -1 2 ) - > 3 then  3 * 8 = 24
# Hint: ( 1 2 ) -> 1 and ( 8 3 ) - > 24 then  1 * 24 = 24
# Hint: ( 1 2 ) -> 2 and ( 8 4 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 8 ) -> 8 and ( 2 5 ) - > 3 then  8 * 3 = 24
# Hint: ( 1 2 ) -> 2 and ( 8 6 ) - > 48 then  48 / 2 = 24
# Hint: ( 1 7 ) -> 8 and ( 2 8 ) - > 16 then  8 + 16 = 24
# Hint: ( 1 8 ) -> 8 and ( 2 8 ) - > 16 then  8 + 16 = 24
# Hint: ( 1 2 ) -> 3 and ( 8 9 ) - > 72 then  72 / 3 = 24
# Hint: ( 1 8 ) -> -7 then ( -7 2 ) - > -14 then  10 - -14 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 1 2 ) -> 3 and ( 8 13 ) - > 21 then  3 + 21 = 24
# Hint: ( 1 2 ) -> 3 and ( 9 1 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 2 ) -> 3 then ( 3 9 ) - > 12 then  12 * 2 = 24
# Hint: ( 1 2 ) -> 3 and ( 9 3 ) - > 27 then  27 - 3 = 24
# Hint: ( 1 2 ) -> 3 then ( 3 9 ) - > 6 then  6 * 4 = 24
# Hint: ( 1 9 ) -> -8 and ( 2 5 ) - > -3 then  -8 * -3 = 24
# Hint: ( 1 9 ) -> 8 and ( 2 6 ) - > 0.3333333333333333 then  8 / 0.3333333333333333 = 24
# Hint: ( 1 9 ) -> 10 and ( 2 7 ) - > 14 then  10 + 14 = 24
# Hint: ( 1 2 ) -> 3 and ( 9 8 ) - > 72 then  72 / 3 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 1 2 ) -> 3 then ( 3 11 ) - > 33 then  33 - 9 = 24
# Hint: ( 1 2 ) -> 3 and ( 9 12 ) - > 21 then  3 + 21 = 24
# Hint: ( 1 2 ) -> 2 and ( 9 13 ) - > 22 then  2 + 22 = 24
# Hint: ( 1 1 ) -> 2 and ( 2 10 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 2 ) -> 3 and ( 10 2 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 3 ) -> 4 and ( 2 10 ) - > 20 then  4 + 20 = 24
# Hint: ( 1 4 ) -> -3 and ( 2 10 ) - > -8 then  -3 * -8 = 24
# Hint: ( 1 5 ) -> -4 and ( 2 10 ) - > 20 then  20 - -4 = 24
# Hint: ( 1 2 ) -> 3 then ( 3 10 ) - > 30 then  30 - 6 = 24
# Hint: ( 1 10 ) -> 10 and ( 2 7 ) - > 14 then  10 + 14 = 24
# Hint: ( 1 8 ) -> -7 then ( -7 2 ) - > -14 then  10 - -14 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 1 2 ) -> 3 and ( 10 11 ) - > 21 then  3 + 21 = 24
# Hint: ( 1 2 ) -> 2 and ( 10 12 ) - > 22 then  2 + 22 = 24
# Hint: ( 1 2 ) -> -1 and ( 10 13 ) - > 23 then  23 - -1 = 24
# Hint: ( 1 2 ) -> 2 and ( 11 1 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 2 ) -> 2 and ( 11 2 ) - > 22 then  2 + 22 = 24
# Hint: ( 1 2 ) -> 3 and ( 11 3 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 11 ) -> 12 and ( 2 4 ) - > 2 then  12 * 2 = 24
# Sorry, no way to make 24
# Hint: ( 1 11 ) -> 12 and ( 2 6 ) - > 12 then  12 + 12 = 24
# Hint: ( 1 11 ) -> -10 and ( 2 7 ) - > 14 then  14 - -10 = 24
# Sorry, no way to make 24
# Hint: ( 1 2 ) -> 3 then ( 3 11 ) - > 33 then  33 - 9 = 24
# Hint: ( 1 2 ) -> 3 and ( 11 10 ) - > 21 then  3 + 21 = 24
# Hint: ( 1 2 ) -> 2 and ( 11 11 ) - > 22 then  2 + 22 = 24
# Hint: ( 1 2 ) -> -1 and ( 11 12 ) - > 23 then  23 - -1 = 24
# Hint: ( 1 2 ) -> 1 and ( 11 13 ) - > 24 then  1 * 24 = 24
# Hint: ( 1 2 ) -> 2 and ( 12 1 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 2 ) -> 1 and ( 12 2 ) - > 24 then  1 * 24 = 24
# Hint: ( 1 3 ) -> 4 and ( 2 12 ) - > 0.16666666666666666 then  4 / 0.16666666666666666 = 24
# Hint: ( 1 2 ) -> 3 and ( 12 4 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 5 ) -> 4 and ( 2 12 ) - > 0.16666666666666666 then  4 / 0.16666666666666666 = 24
# Hint: ( 1 2 ) -> 3 and ( 12 6 ) - > 72 then  72 / 3 = 24
# Hint: ( 1 7 ) -> -6 then ( -6 2 ) - > -12 then  12 - -12 = 24
# Sorry, no way to make 24
# Hint: ( 1 2 ) -> 3 and ( 12 9 ) - > 21 then  3 + 21 = 24
# Hint: ( 1 2 ) -> 2 and ( 12 10 ) - > 22 then  2 + 22 = 24
# Hint: ( 1 2 ) -> -1 and ( 12 11 ) - > 23 then  23 - -1 = 24
# Hint: ( 1 2 ) -> 1 and ( 12 12 ) - > 24 then  1 * 24 = 24
# Hint: ( 1 2 ) -> -1 and ( 12 13 ) - > 25 then  -1 + 25 = 24
# Hint: ( 1 2 ) -> 2 and ( 13 1 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 2 ) -> 2 and ( 13 2 ) - > 26 then  26 - 2 = 24
# Hint: ( 1 3 ) -> -2 and ( 2 13 ) - > 26 then  -2 + 26 = 24
# Hint: ( 1 13 ) -> -12 and ( 2 4 ) - > -2 then  -12 * -2 = 24
# Hint: ( 1 2 ) -> 3 and ( 13 5 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 13 ) -> -12 and ( 2 6 ) - > 12 then  12 - -12 = 24
# Sorry, no way to make 24
# Hint: ( 1 2 ) -> 3 and ( 13 8 ) - > 21 then  3 + 21 = 24
# Hint: ( 1 2 ) -> 2 and ( 13 9 ) - > 22 then  2 + 22 = 24
# Hint: ( 1 2 ) -> -1 and ( 13 10 ) - > 23 then  23 - -1 = 24
# Hint: ( 1 2 ) -> 1 and ( 13 11 ) - > 24 then  1 * 24 = 24
# Hint: ( 1 2 ) -> -1 and ( 13 12 ) - > 25 then  -1 + 25 = 24
# Hint: ( 1 2 ) -> 2 and ( 13 13 ) - > 26 then  26 - 2 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 1 1 ) -> 2 and ( 3 4 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 3 ) -> 4 and ( 1 5 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 3 ) -> 4 and ( 1 6 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 3 ) -> 4 and ( 1 7 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 3 ) -> 3 and ( 1 8 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 3 ) -> 3 and ( 1 9 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 1 ) -> 2 then ( 2 10 ) - > 8 then  8 * 3 = 24
# Hint: ( 1 3 ) -> 2 and ( 1 11 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 3 ) -> 2 and ( 1 12 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 3 ) -> -2 and ( 1 13 ) - > -12 then  -2 * -12 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 1 3 ) -> 4 and ( 2 3 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 3 ) -> 4 and ( 2 4 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 2 ) -> 3 and ( 3 5 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 3 ) -> 2 and ( 2 6 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 2 ) -> 3 and ( 3 7 ) - > 21 then  3 + 21 = 24
# Hint: ( 1 3 ) -> 4 and ( 2 8 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 2 ) -> 3 and ( 3 9 ) - > 27 then  27 - 3 = 24
# Hint: ( 1 3 ) -> 4 and ( 2 10 ) - > 20 then  4 + 20 = 24
# Hint: ( 1 3 ) -> -2 and ( 2 11 ) - > 22 then  22 - -2 = 24
# Hint: ( 1 3 ) -> 4 and ( 2 12 ) - > 0.16666666666666666 then  4 / 0.16666666666666666 = 24
# Hint: ( 1 3 ) -> -2 and ( 2 13 ) - > 26 then  -2 + 26 = 24
# Sorry, no way to make 24
# Hint: ( 1 3 ) -> 4 and ( 3 2 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 3 ) -> 4 and ( 3 3 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 3 ) -> 2 and ( 3 4 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 3 ) -> 3 and ( 3 5 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 3 ) -> -2 then ( -2 6 ) - > 8 then  8 * 3 = 24
# Hint: ( 1 3 ) -> 3 and ( 3 7 ) - > 21 then  3 + 21 = 24
# Hint: ( 1 8 ) -> 9 then ( 9 3 ) - > 27 then  27 - 3 = 24
# Hint: ( 1 3 ) -> 4 and ( 3 9 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 3 ) -> -2 then ( -2 10 ) - > 8 then  8 * 3 = 24
# Hint: ( 1 3 ) -> 3 and ( 3 11 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 3 ) -> 4 then ( 4 3 ) - > 12 then  12 + 12 = 24
# Sorry, no way to make 24
# Hint: ( 1 1 ) -> 2 and ( 3 4 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 3 ) -> 4 and ( 4 2 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 3 ) -> 2 and ( 4 3 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 3 ) -> 3 and ( 4 4 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 3 ) -> 4 and ( 4 5 ) - > 20 then  4 + 20 = 24
# Hint: ( 3 4 ) -> 0.75 then ( 0.75 1 ) - > 0.25 then  6 / 0.25 = 24
# Hint: ( 1 3 ) -> 4 and ( 4 7 ) - > 28 then  28 - 4 = 24
# Hint: ( 1 3 ) -> 2 and ( 4 8 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 4 ) -> -3 and ( 3 9 ) - > 27 then  -3 + 27 = 24
# Hint: ( 1 3 ) -> 4 and ( 4 10 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 4 ) -> -3 and ( 3 11 ) - > -8 then  -3 * -8 = 24
# Hint: ( 1 3 ) -> 2 and ( 4 12 ) - > 48 then  48 / 2 = 24
# Hint: ( 1 13 ) -> -12 and ( 3 4 ) - > 12 then  12 - -12 = 24
# Hint: ( 1 3 ) -> 4 and ( 5 1 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 5 ) -> 4 and ( 3 2 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 3 ) -> 3 and ( 5 3 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 3 ) -> 4 and ( 5 4 ) - > 20 then  4 + 20 = 24
# Sorry, no way to make 24
# Hint: ( 1 5 ) -> 6 and ( 3 6 ) - > 18 then  6 + 18 = 24
# Hint: ( 1 3 ) -> 2 and ( 5 7 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 8 ) -> 9 and ( 3 5 ) - > 15 then  9 + 15 = 24
# Hint: ( 1 5 ) -> -4 and ( 3 9 ) - > -6 then  -4 * -6 = 24
# Hint: ( 1 5 ) -> 6 and ( 3 10 ) - > 30 then  30 - 6 = 24
# Hint: ( 1 3 ) -> 4 and ( 5 11 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 5 ) -> 6 and ( 3 12 ) - > 0.25 then  6 / 0.25 = 24
# Hint: ( 1 3 ) -> 3 and ( 5 13 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 3 ) -> 4 and ( 6 1 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 3 ) -> 2 and ( 6 2 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 3 ) -> -2 then ( -2 6 ) - > 8 then  8 * 3 = 24
# Hint: ( 3 4 ) -> 0.75 then ( 0.75 1 ) - > 0.25 then  6 / 0.25 = 24
# Hint: ( 1 5 ) -> 6 and ( 3 6 ) - > 18 then  6 + 18 = 24
# Hint: ( 1 3 ) -> 2 and ( 6 6 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 6 ) -> 6 and ( 3 7 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 3 ) -> 2 and ( 6 8 ) - > 48 then  48 / 2 = 24
# Hint: ( 1 9 ) -> -8 and ( 3 6 ) - > -3 then  -8 * -3 = 24
# Hint: ( 1 6 ) -> 6 and ( 3 10 ) - > 30 then  30 - 6 = 24
# Hint: ( 1 11 ) -> 12 and ( 3 6 ) - > 0.5 then  12 / 0.5 = 24
# Hint: ( 1 3 ) -> 4 and ( 6 12 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 13 ) -> 12 and ( 3 6 ) - > 0.5 then  12 / 0.5 = 24
# Hint: ( 1 3 ) -> 4 and ( 7 1 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 2 ) -> 3 and ( 3 7 ) - > 21 then  3 + 21 = 24
# Hint: ( 1 3 ) -> 3 and ( 7 3 ) - > 21 then  3 + 21 = 24
# Hint: ( 1 3 ) -> 4 and ( 7 4 ) - > 28 then  28 - 4 = 24
# Hint: ( 1 3 ) -> 2 and ( 7 5 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 7 ) -> 8 and ( 3 6 ) - > 3 then  8 * 3 = 24
# Hint: ( 1 7 ) -> -6 and ( 3 7 ) - > -4 then  -6 * -4 = 24
# Hint: ( 1 3 ) -> 4 then ( 4 7 ) - > 3 then  3 * 8 = 24
# Hint: ( 1 7 ) -> 8 and ( 3 9 ) - > 0.3333333333333333 then  8 / 0.3333333333333333 = 24
# Hint: ( 1 7 ) -> -6 and ( 3 10 ) - > 30 then  -6 + 30 = 24
# Sorry, no way to make 24
# Hint: ( 1 7 ) -> 6 and ( 3 12 ) - > 0.25 then  6 / 0.25 = 24
# Hint: ( 1 3 ) -> 4 and ( 7 13 ) - > 20 then  4 + 20 = 24
# Hint: ( 1 3 ) -> 3 and ( 8 1 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 3 ) -> 4 and ( 8 2 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 8 ) -> 9 then ( 9 3 ) - > 27 then  27 - 3 = 24
# Hint: ( 1 3 ) -> 2 and ( 8 4 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 8 ) -> 9 and ( 3 5 ) - > 15 then  9 + 15 = 24
# Hint: ( 1 3 ) -> 2 and ( 8 6 ) - > 48 then  48 / 2 = 24
# Hint: ( 1 3 ) -> 4 then ( 4 7 ) - > 3 then  3 * 8 = 24
# Hint: ( 1 8 ) -> 9 and ( 3 8 ) - > 0.375 then  9 / 0.375 = 24
# Hint: ( 1 3 ) -> 3 and ( 8 9 ) - > 72 then  72 / 3 = 24
# Hint: ( 1 10 ) -> 9 and ( 3 8 ) - > 0.375 then  9 / 0.375 = 24
# Hint: ( 1 8 ) -> 9 and ( 3 11 ) - > 33 then  33 - 9 = 24
# Hint: ( 1 3 ) -> 4 and ( 8 12 ) - > 20 then  4 + 20 = 24
# Hint: ( 1 3 ) -> 3 and ( 8 13 ) - > 21 then  3 + 21 = 24
# Hint: ( 1 3 ) -> 3 and ( 9 1 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 2 ) -> 3 and ( 3 9 ) - > 27 then  27 - 3 = 24
# Hint: ( 1 3 ) -> 4 and ( 9 3 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 4 ) -> -3 and ( 3 9 ) - > 27 then  -3 + 27 = 24
# Hint: ( 1 9 ) -> 9 and ( 3 5 ) - > 15 then  9 + 15 = 24
# Hint: ( 1 9 ) -> -8 and ( 3 6 ) - > -3 then  -8 * -3 = 24
# Hint: ( 1 7 ) -> 8 and ( 3 9 ) - > 0.3333333333333333 then  8 / 0.3333333333333333 = 24
# Hint: ( 1 3 ) -> 3 and ( 9 8 ) - > 72 then  72 / 3 = 24
# Hint: ( 1 9 ) -> 8 and ( 3 9 ) - > 0.3333333333333333 then  8 / 0.3333333333333333 = 24
# Hint: ( 1 10 ) -> 11 then ( 11 3 ) - > 33 then  33 - 9 = 24
# Hint: ( 1 3 ) -> 4 and ( 9 11 ) - > 20 then  4 + 20 = 24
# Hint: ( 1 3 ) -> 3 and ( 9 12 ) - > 21 then  3 + 21 = 24
# Hint: ( 1 3 ) -> -2 and ( 9 13 ) - > 22 then  22 - -2 = 24
# Hint: ( 1 10 ) -> 9 then ( 9 1 ) - > 8 then  8 * 3 = 24
# Hint: ( 1 3 ) -> 4 and ( 10 2 ) - > 20 then  4 + 20 = 24
# Hint: ( 1 3 ) -> -2 then ( -2 10 ) - > 8 then  8 * 3 = 24
# Hint: ( 1 3 ) -> 4 and ( 10 4 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 10 ) -> -9 and ( 3 5 ) - > 15 then  15 - -9 = 24
# Hint: ( 1 6 ) -> 6 and ( 3 10 ) - > 30 then  30 - 6 = 24
# Hint: ( 1 7 ) -> -6 and ( 3 10 ) - > 30 then  -6 + 30 = 24
# Hint: ( 1 10 ) -> 9 and ( 3 8 ) - > 0.375 then  9 / 0.375 = 24
# Hint: ( 1 10 ) -> 11 then ( 11 3 ) - > 33 then  33 - 9 = 24
# Hint: ( 1 3 ) -> 4 and ( 10 10 ) - > 20 then  4 + 20 = 24
# Hint: ( 1 3 ) -> 3 and ( 10 11 ) - > 21 then  3 + 21 = 24
# Hint: ( 1 3 ) -> -2 and ( 10 12 ) - > 22 then  22 - -2 = 24
# Sorry, no way to make 24
# Hint: ( 1 3 ) -> 2 and ( 11 1 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 3 ) -> -2 and ( 11 2 ) - > 22 then  22 - -2 = 24
# Hint: ( 1 3 ) -> 3 and ( 11 3 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 11 ) -> 12 and ( 3 4 ) - > 12 then  12 + 12 = 24
# Hint: ( 1 3 ) -> 4 and ( 11 5 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 11 ) -> 12 and ( 3 6 ) - > 0.5 then  12 / 0.5 = 24
# Sorry, no way to make 24
# Hint: ( 1 8 ) -> 9 and ( 3 11 ) - > 33 then  33 - 9 = 24
# Hint: ( 1 3 ) -> 4 and ( 11 9 ) - > 20 then  4 + 20 = 24
# Hint: ( 1 3 ) -> 3 and ( 11 10 ) - > 21 then  3 + 21 = 24
# Hint: ( 1 3 ) -> -2 and ( 11 11 ) - > 22 then  22 - -2 = 24
# Hint: ( 1 11 ) -> 12 and ( 3 12 ) - > 36 then  36 - 12 = 24
# Sorry, no way to make 24
# Hint: ( 1 3 ) -> 2 and ( 12 1 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 3 ) -> 4 and ( 12 2 ) - > 6.0 then  4 * 6.0 = 24
# Hint: ( 1 3 ) -> 4 then ( 4 12 ) - > 8 then  8 * 3 = 24
# Hint: ( 1 3 ) -> 2 and ( 12 4 ) - > 48 then  48 / 2 = 24
# Hint: ( 1 12 ) -> 12 and ( 3 5 ) - > 2 then  12 * 2 = 24
# Hint: ( 1 3 ) -> 4 and ( 12 6 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 7 ) -> 6 and ( 3 12 ) - > 0.25 then  6 / 0.25 = 24
# Hint: ( 1 3 ) -> 4 and ( 12 8 ) - > 20 then  4 + 20 = 24
# Hint: ( 1 3 ) -> 3 and ( 12 9 ) - > 21 then  3 + 21 = 24
# Hint: ( 1 3 ) -> -2 and ( 12 10 ) - > 22 then  22 - -2 = 24
# Hint: ( 1 11 ) -> 12 and ( 3 12 ) - > 36 then  36 - 12 = 24
# Hint: ( 1 12 ) -> 12 and ( 3 12 ) - > 36 then  36 - 12 = 24
# Hint: ( 1 13 ) -> -12 and ( 3 12 ) - > 36 then  -12 + 36 = 24
# Hint: ( 1 3 ) -> -2 and ( 13 1 ) - > -12 then  -2 * -12 = 24
# Hint: ( 1 3 ) -> -2 and ( 13 2 ) - > 26 then  -2 + 26 = 24
# Sorry, no way to make 24
# Hint: ( 1 13 ) -> -12 and ( 3 4 ) - > 12 then  12 - -12 = 24
# Hint: ( 1 3 ) -> 3 and ( 13 5 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 13 ) -> 12 and ( 3 6 ) - > 0.5 then  12 / 0.5 = 24
# Hint: ( 1 3 ) -> 4 and ( 13 7 ) - > 20 then  4 + 20 = 24
# Hint: ( 1 3 ) -> 3 and ( 13 8 ) - > 21 then  3 + 21 = 24
# Hint: ( 1 3 ) -> -2 and ( 13 9 ) - > 22 then  22 - -2 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 1 13 ) -> -12 and ( 3 12 ) - > 36 then  -12 + 36 = 24
# Hint: ( 1 3 ) -> -2 and ( 13 13 ) - > 26 then  -2 + 26 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 1 1 ) -> 2 and ( 4 3 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 4 ) -> 5 then ( 5 1 ) - > 6 then  6 * 4 = 24
# Hint: ( 1 4 ) -> 4 and ( 1 5 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 4 ) -> 4 and ( 1 6 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 4 ) -> 3 and ( 1 7 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 4 ) -> 3 and ( 1 8 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 4 ) -> -3 and ( 1 9 ) - > -8 then  -3 * -8 = 24
# Hint: ( 1 1 ) -> 2 then ( 2 10 ) - > 20 then  20 + 4 = 24
# Sorry, no way to make 24
# Hint: ( 1 1 ) -> 2 and ( 4 12 ) - > 48 then  48 / 2 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 1 2 ) -> 3 and ( 4 2 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 4 ) -> 4 and ( 2 3 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 4 ) -> 3 and ( 2 4 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 5 ) -> 4 and ( 4 2 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 4 ) -> 3 and ( 2 6 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 4 ) -> 5 then ( 5 7 ) - > 12 then  12 * 2 = 24
# Hint: ( 1 4 ) -> 4 and ( 2 8 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 4 ) -> -3 then ( -3 9 ) - > 12 then  12 * 2 = 24
# Hint: ( 1 4 ) -> -3 and ( 2 10 ) - > -8 then  -3 * -8 = 24
# Hint: ( 1 11 ) -> 12 and ( 4 2 ) - > 2 then  12 * 2 = 24
# Hint: ( 1 4 ) -> 4 and ( 2 12 ) - > 0.16666666666666666 then  4 / 0.16666666666666666 = 24
# Hint: ( 1 13 ) -> -12 and ( 4 2 ) - > -2 then  -12 * -2 = 24
# Hint: ( 1 1 ) -> 2 and ( 4 3 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 4 ) -> 4 and ( 3 2 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 4 ) -> 4 and ( 3 3 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 3 ) -> 3 and ( 4 4 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 4 ) -> 3 and ( 3 5 ) - > 8 then  3 * 8 = 24
# Hint: ( 4 3 ) -> 0.75 then ( 0.75 1 ) - > 0.25 then  6 / 0.25 = 24
# Hint: ( 1 4 ) -> -3 and ( 3 7 ) - > 21 then  21 - -3 = 24
# Hint: ( 1 3 ) -> 2 and ( 4 8 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 4 ) -> -3 and ( 3 9 ) - > 27 then  -3 + 27 = 24
# Hint: ( 1 3 ) -> 4 and ( 4 10 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 4 ) -> -3 and ( 3 11 ) - > -8 then  -3 * -8 = 24
# Hint: ( 1 3 ) -> 2 and ( 4 12 ) - > 48 then  48 / 2 = 24
# Hint: ( 1 13 ) -> -12 and ( 4 3 ) - > 12 then  12 - -12 = 24
# Hint: ( 1 4 ) -> 5 then ( 5 1 ) - > 6 then  6 * 4 = 24
# Hint: ( 1 4 ) -> 3 and ( 4 2 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 3 ) -> 3 and ( 4 4 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 4 ) -> 3 and ( 4 4 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 4 ) -> 4 and ( 4 5 ) - > 20 then  4 + 20 = 24
# Hint: ( 1 6 ) -> 7 then ( 7 4 ) - > 28 then  28 - 4 = 24
# Hint: ( 1 4 ) -> 4 and ( 4 7 ) - > 28 then  28 - 4 = 24
# Hint: ( 1 8 ) -> 8 and ( 4 4 ) - > 16 then  8 + 16 = 24
# Hint: ( 1 9 ) -> -8 and ( 4 4 ) - > 16 then  16 - -8 = 24
# Hint: ( 1 4 ) -> 4 and ( 4 10 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 4 ) -> 5 then ( 5 11 ) - > 6 then  6 * 4 = 24
# Hint: ( 1 4 ) -> -3 and ( 4 12 ) - > -8 then  -3 * -8 = 24
# Sorry, no way to make 24
# Hint: ( 1 4 ) -> 4 and ( 5 1 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 5 ) -> 4 and ( 4 2 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 4 ) -> 3 and ( 5 3 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 4 ) -> 4 and ( 5 4 ) - > 20 then  4 + 20 = 24
# Hint: ( 1 5 ) -> -4 and ( 4 5 ) - > 20 then  20 - -4 = 24
# Hint: ( 4 5 ) -> 1.25 then ( 1.25 1 ) - > 0.25 then  6 / 0.25 = 24
# Hint: ( 1 5 ) -> -4 and ( 4 7 ) - > 28 then  -4 + 28 = 24
# Hint: ( 1 5 ) -> 6 and ( 4 8 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 4 ) -> -3 then ( -3 5 ) - > -15 then  9 - -15 = 24
# Hint: ( 1 5 ) -> -4 and ( 4 10 ) - > -6 then  -4 * -6 = 24
# Hint: ( 1 4 ) -> 4 and ( 5 11 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 4 ) -> -3 then ( -3 5 ) - > 2 then  2 * 12 = 24
# Hint: ( 1 4 ) -> -3 and ( 5 13 ) - > -8 then  -3 * -8 = 24
# Hint: ( 1 4 ) -> 4 and ( 6 1 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 4 ) -> 3 and ( 6 2 ) - > 8 then  3 * 8 = 24
# Hint: ( 4 3 ) -> 0.75 then ( 0.75 1 ) - > 0.25 then  6 / 0.25 = 24
# Hint: ( 1 6 ) -> 7 then ( 7 4 ) - > 28 then  28 - 4 = 24
# Hint: ( 4 5 ) -> 1.25 then ( 1.25 1 ) - > 0.25 then  6 / 0.25 = 24
# Hint: ( 1 4 ) -> 5 then ( 5 6 ) - > 30 then  30 - 6 = 24
# Hint: ( 1 4 ) -> -3 then ( -3 7 ) - > 4 then  4 * 6 = 24
# Hint: ( 1 6 ) -> 6 and ( 4 8 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 4 ) -> 5 then ( 5 9 ) - > 4 then  4 * 6 = 24
# Hint: ( 1 4 ) -> 3 then ( 3 10 ) - > 30 then  30 - 6 = 24
# Hint: ( 1 11 ) -> 12 and ( 4 6 ) - > 2 then  12 * 2 = 24
# Hint: ( 1 4 ) -> 3 and ( 6 12 ) - > 72 then  72 / 3 = 24
# Hint: ( 1 4 ) -> 5 and ( 6 13 ) - > 19 then  5 + 19 = 24
# Hint: ( 1 4 ) -> 3 and ( 7 1 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 4 ) -> 5 then ( 5 7 ) - > 12 then  12 * 2 = 24
# Hint: ( 1 4 ) -> -3 and ( 7 3 ) - > 21 then  21 - -3 = 24
# Hint: ( 1 4 ) -> 4 and ( 7 4 ) - > 28 then  28 - 4 = 24
# Hint: ( 1 5 ) -> -4 and ( 4 7 ) - > 28 then  -4 + 28 = 24
# Hint: ( 1 4 ) -> -3 then ( -3 7 ) - > 4 then  4 * 6 = 24
# Hint: ( 1 7 ) -> 8 and ( 4 7 ) - > 3 then  8 * 3 = 24
# Hint: ( 1 7 ) -> 8 and ( 4 8 ) - > 32 then  32 - 8 = 24
# Hint: ( 1 9 ) -> -8 and ( 4 7 ) - > -3 then  -8 * -3 = 24
# Sorry, no way to make 24
# Hint: ( 1 4 ) -> 5 then ( 5 7 ) - > 35 then  35 - 11 = 24
# Hint: ( 1 4 ) -> 5 and ( 7 12 ) - > 19 then  5 + 19 = 24
# Hint: ( 1 4 ) -> 4 and ( 7 13 ) - > 20 then  4 + 20 = 24
# Hint: ( 1 4 ) -> 3 and ( 8 1 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 4 ) -> 4 and ( 8 2 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 3 ) -> 2 and ( 4 8 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 8 ) -> 8 and ( 4 4 ) - > 16 then  8 + 16 = 24
# Hint: ( 1 5 ) -> 6 and ( 4 8 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 6 ) -> 6 and ( 4 8 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 8 ) -> 8 and ( 4 7 ) - > 3 then  8 * 3 = 24
# Hint: ( 1 8 ) -> 8 and ( 4 8 ) - > 32 then  32 - 8 = 24
# Hint: ( 1 4 ) -> 3 and ( 8 9 ) - > 72 then  72 / 3 = 24
# Sorry, no way to make 24
# Hint: ( 1 4 ) -> 5 and ( 8 11 ) - > 19 then  5 + 19 = 24
# Hint: ( 1 4 ) -> 4 and ( 8 12 ) - > 20 then  4 + 20 = 24
# Hint: ( 1 4 ) -> -3 and ( 8 13 ) - > 21 then  21 - -3 = 24
# Hint: ( 1 4 ) -> -3 and ( 9 1 ) - > -8 then  -3 * -8 = 24
# Hint: ( 1 4 ) -> -3 then ( -3 9 ) - > 12 then  12 * 2 = 24
# Hint: ( 1 4 ) -> -3 and ( 9 3 ) - > 27 then  -3 + 27 = 24
# Hint: ( 1 9 ) -> -8 and ( 4 4 ) - > 16 then  16 - -8 = 24
# Hint: ( 1 4 ) -> -3 then ( -3 5 ) - > -15 then  9 - -15 = 24
# Hint: ( 1 4 ) -> 5 then ( 5 9 ) - > 4 then  4 * 6 = 24
# Hint: ( 1 9 ) -> -8 and ( 4 7 ) - > -3 then  -8 * -3 = 24
# Hint: ( 1 4 ) -> 3 and ( 9 8 ) - > 72 then  72 / 3 = 24
# Sorry, no way to make 24
# Hint: ( 1 4 ) -> 5 and ( 9 10 ) - > 19 then  5 + 19 = 24
# Hint: ( 1 4 ) -> 4 and ( 9 11 ) - > 20 then  4 + 20 = 24
# Hint: ( 1 4 ) -> -3 and ( 9 12 ) - > 21 then  21 - -3 = 24
# Hint: ( 1 13 ) -> -12 and ( 4 9 ) - > 36 then  -12 + 36 = 24
# Hint: ( 1 1 ) -> 2 then ( 2 10 ) - > 20 then  20 + 4 = 24
# Hint: ( 1 4 ) -> -3 and ( 10 2 ) - > -8 then  -3 * -8 = 24
# Hint: ( 1 3 ) -> 4 and ( 4 10 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 4 ) -> 4 and ( 10 4 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 5 ) -> -4 and ( 4 10 ) - > -6 then  -4 * -6 = 24
# Hint: ( 1 4 ) -> 3 then ( 3 10 ) - > 30 then  30 - 6 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 1 4 ) -> 5 and ( 10 9 ) - > 19 then  5 + 19 = 24
# Hint: ( 1 4 ) -> 4 and ( 10 10 ) - > 20 then  4 + 20 = 24
# Hint: ( 1 4 ) -> -3 and ( 10 11 ) - > 21 then  21 - -3 = 24
# Hint: ( 1 4 ) -> 5 and ( 10 12 ) - > 120 then  120 / 5 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 1 11 ) -> 12 and ( 4 2 ) - > 2 then  12 * 2 = 24
# Hint: ( 1 4 ) -> -3 and ( 11 3 ) - > -8 then  -3 * -8 = 24
# Hint: ( 1 4 ) -> 5 then ( 5 11 ) - > 6 then  6 * 4 = 24
# Hint: ( 1 4 ) -> 4 and ( 11 5 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 11 ) -> 12 and ( 4 6 ) - > 2 then  12 * 2 = 24
# Hint: ( 1 4 ) -> 5 then ( 5 7 ) - > 35 then  35 - 11 = 24
# Hint: ( 1 4 ) -> 5 and ( 11 8 ) - > 19 then  5 + 19 = 24
# Hint: ( 1 4 ) -> 4 and ( 11 9 ) - > 20 then  4 + 20 = 24
# Hint: ( 1 4 ) -> -3 and ( 11 10 ) - > 21 then  21 - -3 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 1 1 ) -> 2 and ( 4 12 ) - > 48 then  48 / 2 = 24
# Hint: ( 1 4 ) -> 4 and ( 12 2 ) - > 6.0 then  4 * 6.0 = 24
# Hint: ( 1 12 ) -> 12 and ( 4 3 ) - > 12 then  12 + 12 = 24
# Hint: ( 1 4 ) -> -3 and ( 12 4 ) - > -8 then  -3 * -8 = 24
# Hint: ( 1 4 ) -> -3 then ( -3 5 ) - > 2 then  2 * 12 = 24
# Hint: ( 1 4 ) -> 3 and ( 12 6 ) - > 72 then  72 / 3 = 24
# Hint: ( 1 4 ) -> 5 and ( 12 7 ) - > 19 then  5 + 19 = 24
# Hint: ( 1 4 ) -> 4 and ( 12 8 ) - > 20 then  4 + 20 = 24
# Hint: ( 1 4 ) -> -3 and ( 12 9 ) - > 21 then  21 - -3 = 24
# Hint: ( 1 4 ) -> 5 and ( 12 10 ) - > 120 then  120 / 5 = 24
# Sorry, no way to make 24
# Hint: ( 1 4 ) -> 3 then ( 3 12 ) - > 36 then  36 - 12 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 1 13 ) -> -12 and ( 4 2 ) - > -2 then  -12 * -2 = 24
# Hint: ( 1 13 ) -> -12 and ( 4 3 ) - > 12 then  12 - -12 = 24
# Sorry, no way to make 24
# Hint: ( 1 4 ) -> -3 and ( 13 5 ) - > -8 then  -3 * -8 = 24
# Hint: ( 1 4 ) -> 5 and ( 13 6 ) - > 19 then  5 + 19 = 24
# Hint: ( 1 4 ) -> 4 and ( 13 7 ) - > 20 then  4 + 20 = 24
# Hint: ( 1 4 ) -> -3 and ( 13 8 ) - > 21 then  21 - -3 = 24
# Hint: ( 1 13 ) -> -12 and ( 4 9 ) - > 36 then  -12 + 36 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 1 5 ) -> 6 and ( 1 3 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 5 ) -> 6 and ( 1 4 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 5 ) -> 6 and ( 1 5 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 5 ) -> 4 and ( 1 6 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 5 ) -> -4 and ( 1 7 ) - > -6 then  -4 * -6 = 24
# Hint: ( 1 5 ) -> 4 then ( 4 1 ) - > 3 then  3 * 8 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 1 5 ) -> 6 and ( 2 2 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 5 ) -> 4 and ( 2 3 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 5 ) -> 4 and ( 2 4 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 2 ) -> -1 and ( 5 5 ) - > 25 then  -1 + 25 = 24
# Hint: ( 1 5 ) -> 6 and ( 2 6 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 2 ) -> 2 and ( 5 7 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 5 ) -> 6 and ( 2 8 ) - > 0.25 then  6 / 0.25 = 24
# Hint: ( 1 5 ) -> 6 and ( 2 9 ) - > 18 then  6 + 18 = 24
# Hint: ( 1 5 ) -> -4 and ( 2 10 ) - > 20 then  20 - -4 = 24
# Sorry, no way to make 24
# Hint: ( 1 5 ) -> 4 and ( 2 12 ) - > 0.16666666666666666 then  4 / 0.16666666666666666 = 24
# Hint: ( 1 2 ) -> 3 and ( 5 13 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 5 ) -> 6 and ( 3 1 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 5 ) -> 4 and ( 3 2 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 5 ) -> 4 and ( 3 3 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 3 ) -> 4 and ( 5 4 ) - > 20 then  4 + 20 = 24
# Sorry, no way to make 24
# Hint: ( 1 5 ) -> 6 and ( 3 6 ) - > 18 then  6 + 18 = 24
# Hint: ( 1 5 ) -> 6 and ( 3 7 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 8 ) -> 9 and ( 5 3 ) - > 15 then  9 + 15 = 24
# Hint: ( 1 5 ) -> -4 and ( 3 9 ) - > -6 then  -4 * -6 = 24
# Hint: ( 1 5 ) -> 6 and ( 3 10 ) - > 30 then  30 - 6 = 24
# Hint: ( 1 3 ) -> 4 and ( 5 11 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 5 ) -> 6 and ( 3 12 ) - > 0.25 then  6 / 0.25 = 24
# Hint: ( 1 3 ) -> 3 and ( 5 13 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 5 ) -> 6 and ( 4 1 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 5 ) -> 4 and ( 4 2 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 4 ) -> 3 and ( 5 3 ) - > 8 then  3 * 8 = 24
# Hint: ( 1 4 ) -> 4 and ( 5 4 ) - > 20 then  4 + 20 = 24
# Hint: ( 1 5 ) -> -4 and ( 4 5 ) - > 20 then  20 - -4 = 24
# Hint: ( 5 4 ) -> 1.25 then ( 1.25 1 ) - > 0.25 then  6 / 0.25 = 24
# Hint: ( 1 5 ) -> -4 and ( 4 7 ) - > 28 then  -4 + 28 = 24
# Hint: ( 1 5 ) -> 6 and ( 4 8 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 4 ) -> -3 then ( -3 5 ) - > -15 then  9 - -15 = 24
# Hint: ( 1 5 ) -> -4 and ( 4 10 ) - > -6 then  -4 * -6 = 24
# Hint: ( 1 4 ) -> 4 and ( 5 11 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 5 ) -> 6 then ( 6 4 ) - > 2 then  2 * 12 = 24
# Hint: ( 1 4 ) -> -3 and ( 5 13 ) - > -8 then  -3 * -8 = 24
# Hint: ( 1 5 ) -> 6 and ( 5 1 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 2 ) -> -1 and ( 5 5 ) - > 25 then  -1 + 25 = 24
# Sorry, no way to make 24
# Hint: ( 1 5 ) -> -4 and ( 5 4 ) - > 20 then  20 - -4 = 24
# Hint: ( 1 5 ) -> 0.2 then ( 0.2 5 ) - > 4.8 then  4.8 * 5 = 24
# Hint: ( 1 5 ) -> 6 and ( 5 6 ) - > 30 then  30 - 6 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 1 5 ) -> 6 and ( 5 9 ) - > 4 then  6 * 4 = 24
# Hint: ( 5 10 ) -> 5 then ( 5 5 ) - > 25 then  25 - 1 = 24
# Hint: ( 1 5 ) -> -4 and ( 5 11 ) - > -6 then  -4 * -6 = 24
# Hint: ( 5 5 ) -> 1.0 then ( 1.0 1 ) - > 2.0 then  2.0 * 12 = 24
# Hint: ( 1 5 ) -> 6 and ( 5 13 ) - > 18 then  6 + 18 = 24
# Hint: ( 1 5 ) -> 4 and ( 6 1 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 5 ) -> 6 and ( 6 2 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 5 ) -> 6 and ( 6 3 ) - > 18 then  6 + 18 = 24
# Hint: ( 5 6 ) -> 0.8333333333333334 then ( 0.8333333333333334 1 ) - > 0.16666666666666663 then  4 / 0.16666666666666663 = 24
# Hint: ( 1 5 ) -> 6 and ( 6 5 ) - > 30 then  30 - 6 = 24
# Hint: ( 1 6 ) -> 6 and ( 5 6 ) - > 30 then  30 - 6 = 24
# Hint: ( 1 7 ) -> -6 and ( 5 6 ) - > 30 then  -6 + 30 = 24
# Hint: ( 1 5 ) -> -4 then ( -4 8 ) - > 4 then  4 * 6 = 24
# Hint: ( 1 6 ) -> 6 and ( 5 9 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 5 ) -> 6 and ( 6 10 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 6 ) -> 7 then ( 7 5 ) - > 35 then  35 - 11 = 24
# Hint: ( 1 5 ) -> 6 and ( 6 12 ) - > 18 then  6 + 18 = 24
# Hint: ( 1 5 ) -> 5 and ( 6 13 ) - > 19 then  5 + 19 = 24
# Hint: ( 1 5 ) -> -4 and ( 7 1 ) - > -6 then  -4 * -6 = 24
# Hint: ( 1 7 ) -> 8 and ( 5 2 ) - > 3 then  8 * 3 = 24
# Hint: ( 1 5 ) -> 6 and ( 7 3 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 5 ) -> -4 and ( 7 4 ) - > 28 then  -4 + 28 = 24
# Sorry, no way to make 24
# Hint: ( 1 7 ) -> -6 and ( 5 6 ) - > 30 then  -6 + 30 = 24
# Sorry, no way to make 24
# Hint: ( 1 7 ) -> 8 and ( 5 8 ) - > 3 then  8 * 3 = 24
# Hint: ( 1 7 ) -> -6 and ( 5 9 ) - > -4 then  -6 * -4 = 24
# Hint: ( 1 10 ) -> 11 and ( 5 7 ) - > 35 then  35 - 11 = 24
# Hint: ( 1 5 ) -> 6 and ( 7 11 ) - > 18 then  6 + 18 = 24
# Hint: ( 1 5 ) -> 5 and ( 7 12 ) - > 19 then  5 + 19 = 24
# Hint: ( 1 5 ) -> -4 and ( 7 13 ) - > 20 then  20 - -4 = 24
# Hint: ( 1 5 ) -> 4 then ( 4 1 ) - > 3 then  3 * 8 = 24
# Hint: ( 1 5 ) -> 6 and ( 8 2 ) - > 4.0 then  6 * 4.0 = 24
# Hint: ( 1 8 ) -> 9 and ( 5 3 ) - > 15 then  9 + 15 = 24
# Hint: ( 1 5 ) -> 6 and ( 8 4 ) - > 4 then  6 * 4 = 24
# Sorry, no way to make 24
# Hint: ( 1 5 ) -> -4 then ( -4 8 ) - > 4 then  4 * 6 = 24
# Hint: ( 1 7 ) -> 8 and ( 5 8 ) - > 3 then  8 * 3 = 24
# Hint: ( 1 8 ) -> 8 and ( 5 8 ) - > 3 then  8 * 3 = 24
# Hint: ( 1 9 ) -> -8 and ( 5 8 ) - > -3 then  -8 * -3 = 24
# Hint: ( 1 5 ) -> 6 and ( 8 10 ) - > 18 then  6 + 18 = 24
# Hint: ( 1 5 ) -> 5 and ( 8 11 ) - > 19 then  5 + 19 = 24
# Hint: ( 1 5 ) -> 6 and ( 8 12 ) - > 4 then  6 * 4 = 24
# Hint: ( 8 13 ) -> 5 then ( 5 5 ) - > 25 then  25 - 1 = 24
# Sorry, no way to make 24
# Hint: ( 1 5 ) -> 6 and ( 9 2 ) - > 18 then  6 + 18 = 24
# Hint: ( 1 5 ) -> -4 and ( 9 3 ) - > -6 then  -4 * -6 = 24
# Hint: ( 1 4 ) -> -3 then ( -3 5 ) - > -15 then  9 - -15 = 24
# Hint: ( 1 5 ) -> 6 and ( 9 5 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 6 ) -> 6 and ( 5 9 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 7 ) -> -6 and ( 5 9 ) - > -4 then  -6 * -4 = 24
# Hint: ( 1 9 ) -> -8 and ( 5 8 ) - > -3 then  -8 * -3 = 24
# Hint: ( 1 5 ) -> 6 and ( 9 9 ) - > 18 then  6 + 18 = 24
# Hint: ( 1 5 ) -> 5 and ( 9 10 ) - > 19 then  5 + 19 = 24
# Hint: ( 1 5 ) -> -4 and ( 9 11 ) - > 20 then  20 - -4 = 24
# Hint: ( 1 9 ) -> 10 and ( 5 12 ) - > 0.4166666666666667 then  10 / 0.4166666666666667 = 24
# Hint: ( 1 5 ) -> 6 and ( 9 13 ) - > 4 then  6 * 4 = 24
# Sorry, no way to make 24
# Hint: ( 1 5 ) -> -4 and ( 10 2 ) - > 20 then  20 - -4 = 24
# Hint: ( 1 5 ) -> 6 and ( 10 3 ) - > 30 then  30 - 6 = 24
# Hint: ( 1 5 ) -> -4 and ( 10 4 ) - > -6 then  -4 * -6 = 24
# Hint: ( 5 10 ) -> 5 then ( 5 5 ) - > 25 then  25 - 1 = 24
# Hint: ( 1 5 ) -> 6 and ( 10 6 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 10 ) -> 11 and ( 5 7 ) - > 35 then  35 - 11 = 24
# Hint: ( 1 5 ) -> 6 and ( 10 8 ) - > 18 then  6 + 18 = 24
# Hint: ( 1 5 ) -> 5 and ( 10 9 ) - > 19 then  5 + 19 = 24
# Hint: ( 1 5 ) -> -4 and ( 10 10 ) - > 20 then  20 - -4 = 24
# Hint: ( 1 11 ) -> 12 and ( 5 10 ) - > 0.5 then  12 / 0.5 = 24
# Hint: ( 1 5 ) -> 5 and ( 10 12 ) - > 120 then  120 / 5 = 24
# Hint: ( 1 13 ) -> 12 and ( 5 10 ) - > 0.5 then  12 / 0.5 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 1 11 ) -> 12 and ( 5 3 ) - > 2 then  12 * 2 = 24
# Hint: ( 1 4 ) -> 4 and ( 5 11 ) - > 6 then  4 * 6 = 24
# Hint: ( 1 5 ) -> -4 and ( 11 5 ) - > -6 then  -4 * -6 = 24
# Hint: ( 1 6 ) -> 7 then ( 7 5 ) - > 35 then  35 - 11 = 24
# Hint: ( 1 5 ) -> 6 and ( 11 7 ) - > 18 then  6 + 18 = 24
# Hint: ( 1 5 ) -> 5 and ( 11 8 ) - > 19 then  5 + 19 = 24
# Hint: ( 1 5 ) -> -4 and ( 11 9 ) - > 20 then  20 - -4 = 24
# Hint: ( 1 11 ) -> 12 and ( 5 10 ) - > 0.5 then  12 / 0.5 = 24
# Hint: ( 11 11 ) -> 121 then ( 121 1 ) - > 120 then  120 / 5 = 24
# Hint: ( 1 11 ) -> 10 and ( 5 12 ) - > 0.4166666666666667 then  10 / 0.4166666666666667 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 1 5 ) -> 4 and ( 12 2 ) - > 6.0 then  4 * 6.0 = 24
# Hint: ( 1 5 ) -> 6 and ( 12 3 ) - > 4.0 then  6 * 4.0 = 24
# Hint: ( 1 5 ) -> 6 then ( 6 12 ) - > 6 then  6 * 4 = 24
# Hint: ( 5 5 ) -> 1.0 then ( 1.0 1 ) - > 2.0 then  2.0 * 12 = 24
# Hint: ( 1 5 ) -> 6 and ( 12 6 ) - > 18 then  6 + 18 = 24
# Hint: ( 1 5 ) -> 5 and ( 12 7 ) - > 19 then  5 + 19 = 24
# Hint: ( 1 5 ) -> 6 and ( 12 8 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 9 ) -> 10 and ( 5 12 ) - > 0.4166666666666667 then  10 / 0.4166666666666667 = 24
# Hint: ( 1 5 ) -> 5 and ( 12 10 ) - > 120 then  120 / 5 = 24
# Hint: ( 1 11 ) -> 10 and ( 5 12 ) - > 0.4166666666666667 then  10 / 0.4166666666666667 = 24
# Hint: ( 1 5 ) -> 6 and ( 12 12 ) - > 144 then  144 / 6 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 1 13 ) -> 14 and ( 5 2 ) - > 10 then  14 + 10 = 24
# Hint: ( 1 13 ) -> -12 and ( 5 3 ) - > -2 then  -12 * -2 = 24
# Hint: ( 1 4 ) -> -3 and ( 5 13 ) - > -8 then  -3 * -8 = 24
# Hint: ( 1 5 ) -> 6 and ( 13 5 ) - > 18 then  6 + 18 = 24
# Hint: ( 1 5 ) -> 5 and ( 13 6 ) - > 19 then  5 + 19 = 24
# Hint: ( 1 5 ) -> -4 and ( 13 7 ) - > 20 then  20 - -4 = 24
# Hint: ( 13 8 ) -> 5 then ( 5 5 ) - > 25 then  25 - 1 = 24
# Hint: ( 1 5 ) -> 6 and ( 13 9 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 13 ) -> 12 and ( 5 10 ) - > 0.5 then  12 / 0.5 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 1 1 ) -> 2 and ( 6 2 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 6 ) -> 6 and ( 1 3 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 6 ) -> 6 and ( 1 4 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 6 ) -> 6 and ( 1 5 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 1 ) -> 2 and ( 6 6 ) - > 12 then  2 * 12 = 24
# Sorry, no way to make 24
# Hint: ( 1 1 ) -> 2 and ( 6 8 ) - > 48 then  48 / 2 = 24
# Hint: ( 1 1 ) -> 2 then ( 2 9 ) - > 18 then  18 + 6 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 1 1 ) -> 2 then ( 2 6 ) - > 12 then  12 + 12 = 24
# Sorry, no way to make 24
# Hint: ( 1 1 ) -> 2 and ( 6 2 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 6 ) -> 6 and ( 2 2 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 3 ) -> 2 and ( 6 2 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 2 ) -> 1 and ( 6 4 ) - > 24 then  1 * 24 = 24
# Hint: ( 1 5 ) -> 6 and ( 6 2 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 6 ) -> 6 and ( 2 6 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 7 ) -> 8 and ( 6 2 ) - > 3.0 then  8 * 3.0 = 24
# Hint: ( 1 6 ) -> 6 and ( 2 8 ) - > 0.25 then  6 / 0.25 = 24
# Hint: ( 1 6 ) -> 6 and ( 2 9 ) - > 18 then  6 + 18 = 24
# Hint: ( 1 6 ) -> 7 then ( 7 2 ) - > 14 then  14 + 10 = 24
# Hint: ( 1 11 ) -> 12 and ( 6 2 ) - > 12 then  12 + 12 = 24
# Hint: ( 1 2 ) -> 3 and ( 6 12 ) - > 72 then  72 / 3 = 24
# Hint: ( 1 13 ) -> -12 and ( 6 2 ) - > 12 then  12 - -12 = 24
# Hint: ( 1 6 ) -> 6 and ( 3 1 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 3 ) -> 2 and ( 6 2 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 6 ) -> 7 then ( 7 3 ) - > 21 then  21 + 3 = 24
# Hint: ( 3 4 ) -> 0.75 then ( 0.75 1 ) - > 0.25 then  6 / 0.25 = 24
# Hint: ( 1 5 ) -> 6 and ( 6 3 ) - > 18 then  6 + 18 = 24
# Hint: ( 1 6 ) -> 6 and ( 3 6 ) - > 18 then  6 + 18 = 24
# Hint: ( 1 6 ) -> 6 and ( 3 7 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 3 ) -> 2 and ( 6 8 ) - > 48 then  48 / 2 = 24
# Hint: ( 1 9 ) -> -8 and ( 6 3 ) - > -3 then  -8 * -3 = 24
# Hint: ( 1 6 ) -> 6 and ( 3 10 ) - > 30 then  30 - 6 = 24
# Hint: ( 1 11 ) -> 12 and ( 6 3 ) - > 2.0 then  12 * 2.0 = 24
# Hint: ( 1 6 ) -> 6 and ( 3 12 ) - > 0.25 then  6 / 0.25 = 24
# Hint: ( 1 13 ) -> 12 and ( 6 3 ) - > 2.0 then  12 * 2.0 = 24
# Hint: ( 1 6 ) -> 6 and ( 4 1 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 4 ) -> 3 and ( 6 2 ) - > 8 then  3 * 8 = 24
# Hint: ( 4 3 ) -> 0.75 then ( 0.75 1 ) - > 0.25 then  6 / 0.25 = 24
# Hint: ( 1 6 ) -> 7 then ( 7 4 ) - > 28 then  28 - 4 = 24
# Hint: ( 6 5 ) -> 0.8333333333333334 then ( 0.8333333333333334 1 ) - > 0.16666666666666663 then  4 / 0.16666666666666663 = 24
# Hint: ( 1 4 ) -> 5 then ( 5 6 ) - > 30 then  30 - 6 = 24
# Hint: ( 1 4 ) -> -3 then ( -3 7 ) - > 4 then  4 * 6 = 24
# Hint: ( 1 6 ) -> 6 and ( 4 8 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 4 ) -> 5 then ( 5 9 ) - > 4 then  4 * 6 = 24
# Hint: ( 1 4 ) -> 3 then ( 3 10 ) - > 30 then  30 - 6 = 24
# Hint: ( 1 11 ) -> 12 and ( 6 4 ) - > 2 then  12 * 2 = 24
# Hint: ( 1 4 ) -> 3 and ( 6 12 ) - > 72 then  72 / 3 = 24
# Hint: ( 1 6 ) -> 7 and ( 4 13 ) - > 17 then  7 + 17 = 24
# Hint: ( 1 6 ) -> 6 and ( 5 1 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 5 ) -> 6 and ( 6 2 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 5 ) -> 6 and ( 6 3 ) - > 18 then  6 + 18 = 24
# Hint: ( 6 5 ) -> 0.8333333333333334 then ( 0.8333333333333334 1 ) - > 0.16666666666666663 then  4 / 0.16666666666666663 = 24
# Hint: ( 1 5 ) -> 6 and ( 6 5 ) - > 30 then  30 - 6 = 24
# Hint: ( 1 6 ) -> 6 and ( 5 6 ) - > 30 then  30 - 6 = 24
# Hint: ( 1 7 ) -> -6 and ( 6 5 ) - > 30 then  -6 + 30 = 24
# Hint: ( 1 5 ) -> -4 then ( -4 8 ) - > 4 then  4 * 6 = 24
# Hint: ( 1 6 ) -> 6 and ( 5 9 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 5 ) -> 6 and ( 6 10 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 6 ) -> 7 then ( 7 5 ) - > 35 then  35 - 11 = 24
# Hint: ( 1 6 ) -> 7 and ( 5 12 ) - > 17 then  7 + 17 = 24
# Hint: ( 1 6 ) -> 6 and ( 5 13 ) - > 18 then  6 + 18 = 24
# Hint: ( 1 1 ) -> 2 and ( 6 6 ) - > 12 then  2 * 12 = 24
# Hint: ( 1 6 ) -> 6 and ( 6 2 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 6 ) -> 6 and ( 6 3 ) - > 18 then  6 + 18 = 24
# Hint: ( 1 4 ) -> 5 then ( 5 6 ) - > 30 then  30 - 6 = 24
# Hint: ( 1 6 ) -> 6 and ( 6 5 ) - > 30 then  30 - 6 = 24
# Hint: ( 1 6 ) -> 5 then ( 5 6 ) - > 30 then  30 - 6 = 24
# Sorry, no way to make 24
# Hint: ( 6 8 ) -> 0.75 then ( 0.75 1 ) - > 0.25 then  6 / 0.25 = 24
# Hint: ( 1 6 ) -> -5 then ( -5 9 ) - > 4 then  4 * 6 = 24
# Hint: ( 1 6 ) -> 6 and ( 6 10 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 6 ) -> 7 and ( 6 11 ) - > 17 then  7 + 17 = 24
# Hint: ( 1 6 ) -> 6 and ( 6 12 ) - > 18 then  6 + 18 = 24
# Hint: ( 1 6 ) -> -5 and ( 6 13 ) - > 19 then  19 - -5 = 24
# Sorry, no way to make 24
# Hint: ( 1 7 ) -> 8 and ( 6 2 ) - > 3.0 then  8 * 3.0 = 24
# Hint: ( 1 6 ) -> 6 and ( 7 3 ) - > 4 then  6 * 4 = 24
# Hint: ( 1 7 ) -> 8 then ( 8 4 ) - > 4 then  4 * 6 = 24
# ...
# Hint: ( 13 11 ) -> 24 and ( 13 13 ) - > 0 then  24 + 0 = 24
# Hint: ( 13 12 ) -> 25 and ( 1 1 ) - > 1 then  25 - 1 = 24
# Hint: ( 13 12 ) -> 25 and ( 1 2 ) - > -1 then  25 + -1 = 24
# Hint: ( 13 1 ) -> 12 and ( 12 3 ) - > 36 then  36 - 12 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 13 1 ) -> 12 and ( 12 6 ) - > 2.0 then  12 * 2.0 = 24
# Hint: ( 13 1 ) -> 14 and ( 12 7 ) - > 1.7142857142857142 then  14 * 1.7142857142857142 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 13 1 ) -> 12 and ( 12 10 ) - > 2 then  12 * 2 = 24
# Hint: ( 13 11 ) -> 2 and ( 12 1 ) - > 12 then  2 * 12 = 24
# Hint: ( 13 12 ) -> 1 then ( 1 1 ) - > 2 then  2 * 12 = 24
# Hint: ( 13 13 ) -> 1.0 then ( 1.0 1 ) - > 2.0 then  2.0 * 12 = 24
# Hint: ( 13 12 ) -> 25 and ( 2 1 ) - > 1 then  25 - 1 = 24
# Hint: ( 13 12 ) -> 25 and ( 2 2 ) - > 1.0 then  25 - 1.0 = 24
# Hint: ( 13 12 ) -> 25 and ( 2 3 ) - > -1 then  25 + -1 = 24
# Sorry, no way to make 24
# Hint: ( 13 5 ) -> 18 and ( 12 2 ) - > 6.0 then  18 + 6.0 = 24
# Hint: ( 13 2 ) -> 26 and ( 12 6 ) - > 2.0 then  26 - 2.0 = 24
# Hint: ( 13 2 ) -> 6.5 then ( 6.5 7 ) - > 0.5 then  12 / 0.5 = 24
# Hint: ( 13 12 ) -> 1 then ( 1 2 ) - > 3 then  3 * 8 = 24
# Hint: ( 13 9 ) -> 4 and ( 12 2 ) - > 6.0 then  4 * 6.0 = 24
# Hint: ( 13 2 ) -> 26 and ( 12 10 ) - > 2 then  26 - 2 = 24
# Hint: ( 13 12 ) -> 1 then ( 1 11 ) - > 12 then  12 * 2 = 24
# Hint: ( 13 12 ) -> 1 and ( 2 12 ) - > 24 then  1 * 24 = 24
# Hint: ( 13 12 ) -> 156 and ( 2 13 ) - > 0.15384615384615385 then  156 * 0.15384615384615385 = 24
# Hint: ( 13 1 ) -> 12 and ( 12 3 ) - > 36 then  36 - 12 = 24
# Hint: ( 13 12 ) -> 25 and ( 3 2 ) - > 1 then  25 - 1 = 24
# Hint: ( 13 12 ) -> 25 and ( 3 3 ) - > 1.0 then  25 - 1.0 = 24
# Hint: ( 13 12 ) -> 25 and ( 3 4 ) - > -1 then  25 + -1 = 24
# Hint: ( 13 3 ) -> 10 and ( 12 5 ) - > 2.4 then  10 * 2.4 = 24
# Hint: ( 13 12 ) -> 1 then ( 1 3 ) - > 4 then  4 * 6 = 24
# Hint: ( 13 7 ) -> 20 and ( 12 3 ) - > 4.0 then  20 + 4.0 = 24
# Hint: ( 13 12 ) -> 1 and ( 3 8 ) - > 24 then  1 * 24 = 24
# Hint: ( 13 12 ) -> 1 then ( 1 9 ) - > 8 then  8 * 3 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 13 12 ) -> 1 then ( 1 3 ) - > 2 then  2 * 12 = 24
# Hint: ( 13 13 ) -> 1.0 then ( 1.0 3 ) - > 2.0 then  2.0 * 12 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 13 12 ) -> 25 and ( 4 3 ) - > 1 then  25 - 1 = 24
# Hint: ( 13 12 ) -> 25 and ( 4 4 ) - > 1.0 then  25 - 1.0 = 24
# Hint: ( 13 12 ) -> 25 and ( 4 5 ) - > -1 then  25 + -1 = 24
# Hint: ( 13 12 ) -> 1 and ( 4 6 ) - > 24 then  1 * 24 = 24
# Hint: ( 13 12 ) -> 1 then ( 1 7 ) - > 6 then  6 * 4 = 24
# Hint: ( 13 8 ) -> 21 and ( 12 4 ) - > 3.0 then  21 + 3.0 = 24
# Sorry, no way to make 24
# Hint: ( 13 10 ) -> 3 and ( 12 4 ) - > 8 then  3 * 8 = 24
# Hint: ( 13 11 ) -> 24 and ( 12 4 ) - > 48 then  48 - 24 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 13 5 ) -> 18 and ( 12 2 ) - > 6.0 then  18 + 6.0 = 24
# Hint: ( 13 3 ) -> 10 and ( 12 5 ) - > 2.4 then  10 * 2.4 = 24
# Hint: ( 13 12 ) -> 25 and ( 5 4 ) - > 1 then  25 - 1 = 24
# Hint: ( 13 12 ) -> 25 and ( 5 5 ) - > 1.0 then  25 - 1.0 = 24
# Hint: ( 13 12 ) -> 25 and ( 5 6 ) - > -1 then  25 + -1 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 13 5 ) -> 18 and ( 12 9 ) - > 1.3333333333333333 then  18 * 1.3333333333333333 = 24
# Hint: ( 13 5 ) -> 8 then ( 8 10 ) - > 2 then  2 * 12 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 13 1 ) -> 12 and ( 12 6 ) - > 2.0 then  12 * 2.0 = 24
# Hint: ( 13 2 ) -> 26 and ( 12 6 ) - > 2.0 then  26 - 2.0 = 24
# Hint: ( 13 12 ) -> 1 then ( 1 3 ) - > 4 then  4 * 6 = 24
# Hint: ( 13 12 ) -> 1 and ( 6 4 ) - > 24 then  1 * 24 = 24
# Hint: ( 13 12 ) -> 25 and ( 6 5 ) - > 1 then  25 - 1 = 24
# Hint: ( 13 12 ) -> 25 and ( 6 6 ) - > 1.0 then  25 - 1.0 = 24
# Hint: ( 13 12 ) -> 25 and ( 6 7 ) - > -1 then  25 + -1 = 24
# Sorry, no way to make 24
# Hint: ( 13 9 ) -> 22 and ( 12 6 ) - > 2.0 then  22 + 2.0 = 24
# Hint: ( 13 10 ) -> 3 and ( 12 6 ) - > 72 then  72 / 3 = 24
# Hint: ( 13 11 ) -> 2 then ( 2 6 ) - > 12 then  12 + 12 = 24
# Hint: ( 13 12 ) -> 156 then ( 156 12 ) - > 144 then  144 / 6 = 24
# Hint: ( 13 13 ) -> 26 and ( 12 6 ) - > 2.0 then  26 - 2.0 = 24
# Hint: ( 13 1 ) -> 14 and ( 12 7 ) - > 1.7142857142857142 then  14 * 1.7142857142857142 = 24
# Hint: ( 13 7 ) -> 6 then ( 6 2 ) - > 12 then  12 + 12 = 24
# Hint: ( 13 7 ) -> 20 and ( 12 3 ) - > 4.0 then  20 + 4.0 = 24
# Hint: ( 13 12 ) -> 1 then ( 1 7 ) - > 6 then  6 * 4 = 24
# Sorry, no way to make 24
# Hint: ( 13 12 ) -> 25 and ( 7 6 ) - > 1 then  25 - 1 = 24
# Hint: ( 13 12 ) -> 25 and ( 7 7 ) - > 49 then  49 - 25 = 24
# Hint: ( 13 12 ) -> 25 and ( 7 8 ) - > -1 then  25 + -1 = 24
# Sorry, no way to make 24
# Hint: ( 13 7 ) -> 20 and ( 12 10 ) - > 1.2 then  20 * 1.2 = 24
# Sorry, no way to make 24
# Hint: ( 13 7 ) -> 6 and ( 12 12 ) - > 144 then  144 / 6 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 13 12 ) -> 1 then ( 1 2 ) - > 3 then  3 * 8 = 24
# Hint: ( 13 12 ) -> 1 and ( 8 3 ) - > 24 then  1 * 24 = 24
# Hint: ( 13 8 ) -> 21 and ( 12 4 ) - > 3.0 then  21 + 3.0 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 13 12 ) -> 25 and ( 8 7 ) - > 1 then  25 - 1 = 24
# Hint: ( 13 12 ) -> 25 and ( 8 8 ) - > 1.0 then  25 - 1.0 = 24
# Hint: ( 13 12 ) -> 25 and ( 8 9 ) - > -1 then  25 + -1 = 24
# Hint: ( 13 8 ) -> 5 and ( 12 10 ) - > 120 then  120 / 5 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 13 9 ) -> 4 and ( 12 2 ) - > 6.0 then  4 * 6.0 = 24
# Hint: ( 13 12 ) -> 1 then ( 1 9 ) - > 8 then  8 * 3 = 24
# Sorry, no way to make 24
# Hint: ( 13 5 ) -> 18 and ( 12 9 ) - > 1.3333333333333333 then  18 * 1.3333333333333333 = 24
# Hint: ( 13 9 ) -> 22 and ( 12 6 ) - > 2.0 then  22 + 2.0 = 24
# Sorry, no way to make 24
# Hint: ( 13 12 ) -> 25 and ( 9 8 ) - > 1 then  25 - 1 = 24
# Hint: ( 13 12 ) -> 25 and ( 9 9 ) - > 1.0 then  25 - 1.0 = 24
# Hint: ( 13 12 ) -> 25 and ( 9 10 ) - > -1 then  25 + -1 = 24
# Hint: ( 13 9 ) -> 22 and ( 12 11 ) - > 1.0909090909090908 then  22 * 1.0909090909090908 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 13 1 ) -> 12 and ( 12 10 ) - > 2 then  12 * 2 = 24
# Hint: ( 13 2 ) -> 26 and ( 12 10 ) - > 2 then  26 - 2 = 24
# Sorry, no way to make 24
# Hint: ( 13 10 ) -> 3 and ( 12 4 ) - > 8 then  3 * 8 = 24
# Hint: ( 13 10 ) -> 3 then ( 3 5 ) - > 2 then  2 * 12 = 24
# Hint: ( 13 10 ) -> 3 and ( 12 6 ) - > 72 then  72 / 3 = 24
# Hint: ( 13 7 ) -> 20 and ( 12 10 ) - > 1.2 then  20 * 1.2 = 24
# Hint: ( 13 8 ) -> 5 and ( 12 10 ) - > 120 then  120 / 5 = 24
# Hint: ( 13 12 ) -> 25 and ( 10 9 ) - > 1 then  25 - 1 = 24
# Hint: ( 13 12 ) -> 25 and ( 10 10 ) - > 1.0 then  25 - 1.0 = 24
# Hint: ( 13 12 ) -> 25 and ( 10 11 ) - > -1 then  25 + -1 = 24
# Hint: ( 13 10 ) -> 23 and ( 12 12 ) - > 1.0 then  23 + 1.0 = 24
# Hint: ( 13 12 ) -> 1 and ( 10 13 ) - > 23 then  1 + 23 = 24
# Hint: ( 13 11 ) -> 2 and ( 12 1 ) - > 12 then  2 * 12 = 24
# Hint: ( 13 12 ) -> 1 then ( 1 11 ) - > 12 then  12 * 2 = 24
# Sorry, no way to make 24
# Hint: ( 13 11 ) -> 24 and ( 12 4 ) - > 48 then  48 - 24 = 24
# Sorry, no way to make 24
# Hint: ( 13 11 ) -> 2 then ( 2 6 ) - > 12 then  12 + 12 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 13 9 ) -> 22 and ( 12 11 ) - > 1.0909090909090908 then  22 * 1.0909090909090908 = 24
# Hint: ( 13 12 ) -> 25 and ( 11 10 ) - > 1 then  25 - 1 = 24
# Hint: ( 13 12 ) -> 25 and ( 11 11 ) - > 1.0 then  25 - 1.0 = 24
# Hint: ( 13 12 ) -> 25 and ( 11 12 ) - > -1 then  25 + -1 = 24
# Hint: ( 13 12 ) -> 1 and ( 11 13 ) - > 24 then  1 * 24 = 24
# Hint: ( 13 12 ) -> 1 then ( 1 1 ) - > 2 then  2 * 12 = 24
# Hint: ( 13 12 ) -> 1 and ( 12 2 ) - > 24 then  1 * 24 = 24
# Hint: ( 13 12 ) -> 1 then ( 1 3 ) - > 2 then  2 * 12 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 13 12 ) -> 156 then ( 156 12 ) - > 144 then  144 / 6 = 24
# Hint: ( 13 7 ) -> 6 and ( 12 12 ) - > 144 then  144 / 6 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 13 10 ) -> 23 and ( 12 12 ) - > 1.0 then  23 + 1.0 = 24
# Hint: ( 13 12 ) -> 25 and ( 12 11 ) - > 1 then  25 - 1 = 24
# Hint: ( 13 12 ) -> 25 and ( 12 12 ) - > 1.0 then  25 - 1.0 = 24
# Hint: ( 13 12 ) -> 25 and ( 12 13 ) - > -1 then  25 + -1 = 24
# Hint: ( 13 13 ) -> 1.0 then ( 1.0 1 ) - > 2.0 then  2.0 * 12 = 24
# Hint: ( 13 12 ) -> 156 and ( 13 2 ) - > 6.5 then  156 / 6.5 = 24
# Hint: ( 13 13 ) -> 1.0 then ( 1.0 3 ) - > 2.0 then  2.0 * 12 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 13 13 ) -> 26 and ( 12 6 ) - > 2.0 then  26 - 2.0 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 13 12 ) -> 1 and ( 13 10 ) - > 23 then  1 + 23 = 24
# Hint: ( 13 12 ) -> 1 and ( 13 11 ) - > 24 then  1 * 24 = 24
# Hint: ( 13 12 ) -> 25 and ( 13 12 ) - > 1 then  25 - 1 = 24
# Hint: ( 13 12 ) -> 25 and ( 13 13 ) - > 1.0 then  25 - 1.0 = 24
# Hint: ( 13 13 ) -> 26 and ( 1 1 ) - > 2 then  26 - 2 = 24
# Hint: ( 13 13 ) -> 26 and ( 1 2 ) - > 2 then  26 - 2 = 24
# Hint: ( 13 13 ) -> 26 and ( 1 3 ) - > -2 then  26 + -2 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 13 13 ) -> 169 then ( 169 1 ) - > 168 then  168 / 7 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 13 1 ) -> 12 and ( 13 11 ) - > 2 then  12 * 2 = 24
# Hint: ( 13 13 ) -> 1.0 then ( 1.0 1 ) - > 2.0 then  2.0 * 12 = 24
# Sorry, no way to make 24
# Hint: ( 13 13 ) -> 26 and ( 2 1 ) - > 2 then  26 - 2 = 24
# Hint: ( 13 2 ) -> 0.15384615384615385 then ( 0.15384615384615385 2 ) - > 1.8461538461538463 then  1.8461538461538463 * 13 = 24
# Hint: ( 13 2 ) -> 15 and ( 13 3 ) - > 39 then  39 - 15 = 24
# Hint: ( 13 13 ) -> 26 and ( 2 4 ) - > -2 then  26 + -2 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 13 13 ) -> 1.0 then ( 1.0 2 ) - > 3.0 then  3.0 * 8 = 24
# Hint: ( 13 9 ) -> 22 then ( 22 2 ) - > 11.0 then  11.0 + 13 = 24
# Sorry, no way to make 24
# Hint: ( 13 2 ) -> 26 and ( 13 11 ) - > 2 then  26 - 2 = 24
# Hint: ( 13 13 ) -> 0 and ( 2 12 ) - > 24 then  0 + 24 = 24
# Hint: ( 13 13 ) -> 1.0 then ( 1.0 13 ) - > 12.0 then  12.0 * 2 = 24
# Hint: ( 13 13 ) -> 26 and ( 3 1 ) - > 2 then  26 - 2 = 24
# Hint: ( 13 3 ) -> 39 and ( 13 2 ) - > 15 then  39 - 15 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 13 13 ) -> 26 and ( 3 5 ) - > -2 then  26 + -2 = 24
# Hint: ( 13 13 ) -> 26 and ( 3 6 ) - > 2.0 then  26 - 2.0 = 24
# Hint: ( 13 13 ) -> 1.0 then ( 1.0 7 ) - > 8.0 then  8.0 * 3 = 24
# Hint: ( 13 13 ) -> 0 and ( 3 8 ) - > 24 then  0 + 24 = 24
# Hint: ( 13 13 ) -> 1.0 then ( 1.0 9 ) - > 8.0 then  8.0 * 3 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 13 13 ) -> 1.0 then ( 1.0 3 ) - > 2.0 then  2.0 * 12 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 13 13 ) -> 26 and ( 4 2 ) - > 2 then  26 - 2 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 13 13 ) -> 1.0 then ( 1.0 5 ) - > 6.0 then  6.0 * 4 = 24
# Hint: ( 13 13 ) -> 26 and ( 4 6 ) - > -2 then  26 + -2 = 24
# Hint: ( 13 13 ) -> 1.0 then ( 1.0 7 ) - > 6.0 then  6.0 * 4 = 24
# Hint: ( 13 13 ) -> 26 and ( 4 8 ) - > 2.0 then  26 - 2.0 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 13 13 ) -> 26 and ( 5 3 ) - > 2 then  26 - 2 = 24
# Hint: ( 13 13 ) -> 1.0 then ( 1.0 5 ) - > 6.0 then  6.0 * 4 = 24
# Hint: ( 13 13 ) -> 1.0 and ( 5 5 ) - > 25 then  25 - 1.0 = 24
# Hint: ( 13 13 ) -> 1.0 then ( 1.0 5 ) - > 4.0 then  4.0 * 6 = 24
# Hint: ( 13 13 ) -> 26 and ( 5 7 ) - > -2 then  26 + -2 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 13 13 ) -> 26 and ( 5 10 ) - > 50 then  50 - 26 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 13 13 ) -> 26 and ( 6 3 ) - > 2.0 then  26 - 2.0 = 24
# Hint: ( 13 13 ) -> 26 and ( 6 4 ) - > 2 then  26 - 2 = 24
# Hint: ( 13 13 ) -> 1.0 then ( 1.0 5 ) - > 4.0 then  4.0 * 6 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 13 13 ) -> 26 and ( 6 8 ) - > -2 then  26 + -2 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 13 13 ) -> 26 and ( 6 12 ) - > 2.0 then  26 - 2.0 = 24
# Sorry, no way to make 24
# Hint: ( 13 13 ) -> 169 then ( 169 1 ) - > 168 then  168 / 7 = 24
# Sorry, no way to make 24
# Hint: ( 13 13 ) -> 1.0 then ( 1.0 7 ) - > 8.0 then  8.0 * 3 = 24
# Hint: ( 13 13 ) -> 1.0 then ( 1.0 7 ) - > 6.0 then  6.0 * 4 = 24
# Hint: ( 13 13 ) -> 26 and ( 7 5 ) - > 2 then  26 - 2 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 13 13 ) -> 26 and ( 7 9 ) - > -2 then  26 + -2 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 13 13 ) -> 1.0 then ( 1.0 2 ) - > 3.0 then  3.0 * 8 = 24
# Hint: ( 13 13 ) -> 0 and ( 8 3 ) - > 24 then  0 + 24 = 24
# Hint: ( 13 13 ) -> 26 and ( 8 4 ) - > 2.0 then  26 - 2.0 = 24
# Sorry, no way to make 24
# Hint: ( 13 13 ) -> 26 and ( 8 6 ) - > 2 then  26 - 2 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 13 13 ) -> 26 and ( 8 10 ) - > -2 then  26 + -2 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 13 9 ) -> 22 then ( 22 2 ) - > 11.0 then  11.0 + 13 = 24
# Hint: ( 13 13 ) -> 1.0 then ( 1.0 9 ) - > 8.0 then  8.0 * 3 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 13 13 ) -> 26 and ( 9 7 ) - > 2 then  26 - 2 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 13 13 ) -> 26 and ( 9 11 ) - > -2 then  26 + -2 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 13 13 ) -> 26 and ( 10 5 ) - > 50 then  50 - 26 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 13 13 ) -> 26 and ( 10 8 ) - > 2 then  26 - 2 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 13 13 ) -> 26 and ( 10 12 ) - > -2 then  26 + -2 = 24
# Hint: ( 13 13 ) -> 1.0 and ( 10 13 ) - > 23 then  1.0 + 23 = 24
# Hint: ( 13 11 ) -> 2 and ( 13 1 ) - > 12 then  2 * 12 = 24
# Hint: ( 13 11 ) -> 2 and ( 13 2 ) - > 26 then  26 - 2 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 13 13 ) -> 26 and ( 11 9 ) - > 2 then  26 - 2 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 13 13 ) -> 1.0 and ( 11 12 ) - > 23 then  1.0 + 23 = 24
# Hint: ( 13 13 ) -> 26 and ( 11 13 ) - > -2 then  26 + -2 = 24
# Hint: ( 13 13 ) -> 1.0 then ( 1.0 1 ) - > 2.0 then  2.0 * 12 = 24
# Hint: ( 13 13 ) -> 0 and ( 12 2 ) - > 24 then  0 + 24 = 24
# Hint: ( 13 13 ) -> 1.0 then ( 1.0 3 ) - > 2.0 then  2.0 * 12 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 13 13 ) -> 26 and ( 12 6 ) - > 2.0 then  26 - 2.0 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 13 13 ) -> 26 and ( 12 10 ) - > 2 then  26 - 2 = 24
# Hint: ( 13 13 ) -> 1.0 and ( 12 11 ) - > 23 then  1.0 + 23 = 24
# Hint: ( 13 13 ) -> 0 and ( 12 12 ) - > 24 then  0 + 24 = 24
# Hint: ( 13 13 ) -> 26 and ( 12 13 ) - > 0.9230769230769231 then  26 * 0.9230769230769231 = 24
# Sorry, no way to make 24
# Hint: ( 13 13 ) -> 1.0 then ( 1.0 13 ) - > 12.0 then  12.0 * 2 = 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Sorry, no way to make 24
# Hint: ( 13 13 ) -> 1.0 and ( 13 10 ) - > 23 then  1.0 + 23 = 24
# Hint: ( 13 13 ) -> 26 and ( 13 11 ) - > 2 then  26 - 2 = 24
# Hint: ( 13 13 ) -> 26 and ( 13 12 ) - > 1.0833333333333333 then  26 / 1.0833333333333333 = 24
# Sorry, no way to make 24
# 22615 out of 28561 number of combinations can make 24 ratio is 0.7918140121144218

# %%
import pandas as pd
df = pd.DataFrame(index=range(1,101), columns=['possible10','total10','ratio10','possible13','total13','ratio13'])

# %%
for goal in range (1,101):
    lowBound = goal - .001
    highBound = goal + .001
    # for all possible goals between 1 to 256, each set a range to deal with errors during float calculation

    # including J, Q, K, values load to ratio13
    p = 0
    t = 0
    for a in range (1,11):
        for b in range (1,11):
            for c in range (1,11):
                for d in range (1,11):
                    x = Is24(a, b, c, d)
                    t = t+1
                    if x == 1:
                        p = p+1
    df.iloc[goal]['possible10'] = p
    df.iloc[goal]['total10'] = t
    df.iloc[goal]['possible10'] = p/t

    p = 0
    t = 0
    # including J, Q, K, values load to ratio13
    for a in range (1,14):
        for b in range (1,14):
            for c in range (1,14):
                for d in range (1,14):
                    x = Is24(a, b, c, d)
                    t = t+1
                    if x == 1:
                        p = p+1
    df.iloc[goal]['possible13'] = p
    df.iloc[goal]['total13'] = t
    df.iloc[goal]['possible13'] = p/t
# Out:
# Hint: ( 1 1 ) -> 2 and ( 1 1 ) - > 2 then  2 / 2 = 1
# Hint: ( 1 1 ) -> 2 and ( 1 2 ) - > 3 then  3 - 2 = 1
# Hint: ( 1 1 ) -> 2 and ( 1 3 ) - > 2 then  2 / 2 = 1
# Hint: ( 1 1 ) -> 2 and ( 1 4 ) - > 3 then  3 - 2 = 1
# Hint: ( 1 1 ) -> 0 then ( 0 5 ) - > 0 then  0 + 1 = 1
# Hint: ( 1 1 ) -> 0 then ( 0 6 ) - > 0 then  0 + 1 = 1
# Hint: ( 1 1 ) -> 0 then ( 0 7 ) - > 0 then  0 + 1 = 1
# Hint: ( 1 1 ) -> 0 then ( 0 8 ) - > 0 then  0 + 1 = 1
# Hint: ( 1 1 ) -> 0 then ( 0 9 ) - > 0 then  0 + 1 = 1
# Hint: ( 1 1 ) -> 0 then ( 0 10 ) - > 0 then  0 + 1 = 1
# Hint: ( 1 1 ) -> 2 and ( 2 1 ) - > 3 then  3 - 2 = 1
# Hint: ( 1 1 ) -> 2 and ( 2 2 ) - > 1.0 then  2 - 1.0 = 1
# Hint: ( 1 1 ) -> 2 and ( 2 3 ) - > -1 then  2 + -1 = 1
# Hint: ( 1 1 ) -> 2 and ( 2 4 ) - > 2 then  2 / 2 = 1
# Hint: ( 1 1 ) -> 2 and ( 2 5 ) - > 3 then  3 - 2 = 1
# Hint: ( 1 1 ) -> 2 and ( 2 6 ) - > 3.0 then  3.0 - 2 = 1
# Sorry, no way to make 1
# Sorry, no way to make 1
# Sorry, no way to make 1
# Sorry, no way to make 1
# Hint: ( 1 1 ) -> 2 and ( 3 1 ) - > 2 then  2 / 2 = 1
# Hint: ( 1 1 ) -> 2 and ( 3 2 ) - > 1 then  2 - 1 = 1
# Hint: ( 1 1 ) -> 2 and ( 3 3 ) - > 1.0 then  2 - 1.0 = 1
# Hint: ( 1 1 ) -> 2 and ( 3 4 ) - > -1 then  2 + -1 = 1
# Hint: ( 1 1 ) -> 2 and ( 3 5 ) - > 2 then  2 / 2 = 1
# Hint: ( 1 1 ) -> 2 and ( 3 6 ) - > 3 then  3 - 2 = 1
# Hint: ( 1 1 ) -> 2 then ( 2 3 ) - > 6 then  7 - 6 = 1
# Hint: ( 1 1 ) -> 2 then ( 2 8 ) - > 4.0 then  4.0 - 3 = 1
# Hint: ( 1 1 ) -> 2 and ( 3 9 ) - > 3.0 then  3.0 - 2 = 1
# Sorry, no way to make 1
# Hint: ( 1 1 ) -> 2 and ( 4 1 ) - > 3 then  3 - 2 = 1
# Hint: ( 1 1 ) -> 2 and ( 4 2 ) - > 2 then  2 / 2 = 1
# Hint: ( 1 1 ) -> 2 and ( 4 3 ) - > 1 then  2 - 1 = 1
# Hint: ( 1 1 ) -> 2 and ( 4 4 ) - > 1.0 then  2 - 1.0 = 1
# Hint: ( 1 1 ) -> 2 and ( 4 5 ) - > -1 then  2 + -1 = 1
# Hint: ( 1 1 ) -> 2 and ( 4 6 ) - > 2 then  2 / 2 = 1
# Hint: ( 1 1 ) -> 2 and ( 4 7 ) - > 3 then  3 - 2 = 1
# Hint: ( 1 1 ) -> 2 and ( 4 8 ) - > 0.5 then  2 * 0.5 = 1
# Hint: ( 1 1 ) -> 2 then ( 2 4 ) - > 8 then  9 - 8 = 1
# Hint: ( 1 1 ) -> 2 then ( 2 10 ) - > 5.0 then  5.0 - 4 = 1
# Hint: ( 1 1 ) -> 0 then ( 0 5 ) - > 0 then  0 + 1 = 1
# Hint: ( 1 1 ) -> 2 and ( 5 2 ) - > 3 then  3 - 2 = 1
# Hint: ( 1 1 ) -> 2 and ( 5 3 ) - > 2 then  2 / 2 = 1
# Hint: ( 1 1 ) -> 2 and ( 5 4 ) - > 1 then  2 - 1 = 1
# Hint: ( 1 1 ) -> 2 and ( 5 5 ) - > 1.0 then  2 - 1.0 = 1
# Hint: ( 1 1 ) -> 2 and ( 5 6 ) - > -1 then  2 + -1 = 1
# Hint: ( 1 1 ) -> 2 and ( 5 7 ) - > 2 then  2 / 2 = 1
# Hint: ( 1 1 ) -> 2 and ( 5 8 ) - > 3 then  3 - 2 = 1
# Hint: ( 1 1 ) -> 2 then ( 2 5 ) - > 10 then  10 - 9 = 1
# Hint: ( 1 1 ) -> 2 and ( 5 10 ) - > 0.5 then  2 * 0.5 = 1
# Hint: ( 1 1 ) -> 0 then ( 0 6 ) - > 0 then  0 + 1 = 1
# Hint: ( 1 1 ) -> 2 and ( 6 2 ) - > 3.0 then  3.0 - 2 = 1
# Hint: ( 1 1 ) -> 2 and ( 6 3 ) - > 3 then  3 - 2 = 1
# Hint: ( 1 1 ) -> 2 and ( 6 4 ) - > 2 then  2 / 2 = 1
# Hint: ( 1 1 ) -> 2 and ( 6 5 ) - > 1 then  2 - 1 = 1
# Hint: ( 1 1 ) -> 2 and ( 6 6 ) - > 1.0 then  2 - 1.0 = 1
# Hint: ( 1 1 ) -> 2 and ( 6 7 ) - > -1 then  2 + -1 = 1
# Hint: ( 1 1 ) -> 2 and ( 6 8 ) - > 2 then  2 / 2 = 1
# Hint: ( 1 1 ) -> 2 and ( 6 9 ) - > 3 then  3 - 2 = 1
# Hint: ( 1 1 ) -> 2 then ( 2 10 ) - > 5.0 then  6 - 5.0 = 1
# Hint: ( 1 1 ) -> 0 then ( 0 7 ) - > 0 then  0 + 1 = 1
# Sorry, no way to make 1
# Hint: ( 1 1 ) -> 2 then ( 2 3 ) - > 6 then  7 - 6 = 1
# Hint: ( 1 1 ) -> 2 and ( 7 4 ) - > 3 then  3 - 2 = 1
# Hint: ( 1 1 ) -> 2 and ( 7 5 ) - > 2 then  2 / 2 = 1
# Hint: ( 1 1 ) -> 2 and ( 7 6 ) - > 1 then  2 - 1 = 1
# Hint: ( 1 1 ) -> 2 and ( 7 7 ) - > 1.0 then  2 - 1.0 = 1
# Hint: ( 1 1 ) -> 2 and ( 7 8 ) - > -1 then  2 + -1 = 1
# Hint: ( 1 1 ) -> 2 and ( 7 9 ) - > 2 then  2 / 2 = 1
# Hint: ( 1 1 ) -> 2 and ( 7 10 ) - > 3 then  3 - 2 = 1
# Hint: ( 1 1 ) -> 0 then ( 0 8 ) - > 0 then  0 + 1 = 1
# Sorry, no way to make 1
# Hint: ( 1 1 ) -> 2 then ( 2 8 ) - > 4.0 then  4.0 - 3 = 1
# Hint: ( 1 1 ) -> 2 and ( 8 4 ) - > 2.0 then  2 / 2.0 = 1
# Hint: ( 1 1 ) -> 2 and ( 8 5 ) - > 3 then  3 - 2 = 1
# Hint: ( 1 1 ) -> 2 and ( 8 6 ) - > 2 then  2 / 2 = 1
# Hint: ( 1 1 ) -> 2 and ( 8 7 ) - > 1 then  2 - 1 = 1
# Hint: ( 1 1 ) -> 2 and ( 8 8 ) - > 1.0 then  2 - 1.0 = 1
# Hint: ( 1 1 ) -> 2 and ( 8 9 ) - > -1 then  2 + -1 = 1
# Hint: ( 1 1 ) -> 2 and ( 8 10 ) - > 2 then  2 / 2 = 1
# Hint: ( 1 1 ) -> 0 then ( 0 9 ) - > 0 then  0 + 1 = 1
# Sorry, no way to make 1
# Hint: ( 1 1 ) -> 2 and ( 9 3 ) - > 3.0 then  3.0 - 2 = 1
# Hint: ( 1 1 ) -> 2 then ( 2 4 ) - > 8 then  9 - 8 = 1
# Hint: ( 1 1 ) -> 2 then ( 2 5 ) - > 10 then  10 - 9 = 1
# Hint: ( 1 1 ) -> 2 and ( 9 6 ) - > 3 then  3 - 2 = 1
# Hint: ( 1 1 ) -> 2 and ( 9 7 ) - > 2 then  2 / 2 = 1
# Hint: ( 1 1 ) -> 2 and ( 9 8 ) - > 1 then  2 - 1 = 1
# Hint: ( 1 1 ) -> 2 and ( 9 9 ) - > 1.0 then  2 - 1.0 = 1
# Hint: ( 1 1 ) -> 2 and ( 9 10 ) - > -1 then  2 + -1 = 1
# Hint: ( 1 1 ) -> 0 then ( 0 10 ) - > 0 then  0 + 1 = 1
# Sorry, no way to make 1
# Sorry, no way to make 1
# Hint: ( 1 1 ) -> 2 then ( 2 10 ) - > 5.0 then  5.0 - 4 = 1
# Hint: ( 1 1 ) -> 2 and ( 10 5 ) - > 2.0 then  2 / 2.0 = 1
# Hint: ( 1 1 ) -> 2 then ( 2 10 ) - > 5.0 then  6 - 5.0 = 1
# Hint: ( 1 1 ) -> 2 and ( 10 7 ) - > 3 then  3 - 2 = 1
# Hint: ( 1 1 ) -> 2 and ( 10 8 ) - > 2 then  2 / 2 = 1
# Hint: ( 1 1 ) -> 2 and ( 10 9 ) - > 1 then  2 - 1 = 1
# Hint: ( 1 1 ) -> 2 and ( 10 10 ) - > 1.0 then  2 - 1.0 = 1
# Hint: ( 1 2 ) -> 3 and ( 1 1 ) - > 2 then  3 - 2 = 1
# Hint: ( 1 2 ) -> 3 and ( 1 2 ) - > 3 then  3 / 3 = 1
# Hint: ( 1 2 ) -> 3 and ( 1 3 ) - > 4 then  4 - 3 = 1
# Hint: ( 1 2 ) -> 3 and ( 1 4 ) - > 3 then  3 / 3 = 1
# Hint: ( 1 2 ) -> 3 and ( 1 5 ) - > 4 then  4 - 3 = 1
# Hint: ( 1 1 ) -> 2 and ( 2 6 ) - > 3.0 then  3.0 - 2 = 1
# Sorry, no way to make 1
# Sorry, no way to make 1
# Sorry, no way to make 1
# Sorry, no way to make 1
# Hint: ( 1 2 ) -> 3 and ( 2 1 ) - > 3 then  3 / 3 = 1
# Hint: ( 1 2 ) -> 3 and ( 2 2 ) - > 4 then  4 - 3 = 1
# Hint: ( 1 2 ) -> -1 and ( 2 3 ) - > -1 then  -1 * -1 = 1
# Hint: ( 1 2 ) -> 3 and ( 2 4 ) - > -2 then  3 + -2 = 1
# Hint: ( 1 2 ) -> 3 and ( 2 5 ) - > 3 then  3 / 3 = 1
# Hint: ( 1 2 ) -> 3 and ( 2 6 ) - > 4 then  4 - 3 = 1
# Hint: ( 1 2 ) -> 3 then ( 3 2 ) - > 6 then  7 - 6 = 1
# Hint: ( 1 2 ) -> 3 and ( 2 8 ) - > 4.0 then  4.0 - 3 = 1
# Hint: ( 1 2 ) -> 3 then ( 3 9 ) - > 3.0 then  3.0 - 2 = 1
# Hint: ( 2 2 ) -> 0 then ( 0 10 ) - > 0 then  0 + 1 = 1
# Hint: ( 1 2 ) -> 3 and ( 3 1 ) - > 4 then  4 - 3 = 1
# Hint: ( 1 2 ) -> -1 and ( 3 2 ) - > -1 then  -1 * -1 = 1
# Hint: ( 1 2 ) -> -1 and ( 3 3 ) - > 0 then  0 - -1 = 1
# Hint: ( 1 2 ) -> -1 and ( 3 4 ) - > -1 then  -1 * -1 = 1
# Hint: ( 1 2 ) -> 3 and ( 3 5 ) - > -2 then  3 + -2 = 1
# Hint: ( 1 2 ) -> 3 and ( 3 6 ) - > 3 then  3 / 3 = 1
# Hint: ( 1 2 ) -> 3 and ( 3 7 ) - > 4 then  4 - 3 = 1
# Hint: ( 1 3 ) -> 4 and ( 2 8 ) - > 0.25 then  4 * 0.25 = 1
# Hint: ( 1 2 ) -> 3 and ( 3 9 ) - > 0.3333333333333333 then  3 * 0.3333333333333333 = 1
# Hint: ( 1 3 ) -> 4 and ( 2 10 ) - > 5.0 then  5.0 - 4 = 1
# Hint: ( 1 2 ) -> 3 and ( 4 1 ) - > 3 then  3 / 3 = 1
# Hint: ( 1 2 ) -> 3 and ( 4 2 ) - > 2 then  3 - 2 = 1
# Hint: ( 1 2 ) -> -1 and ( 4 3 ) - > -1 then  -1 * -1 = 1
# Hint: ( 1 2 ) -> -1 and ( 4 4 ) - > 0 then  0 - -1 = 1
# Hint: ( 1 2 ) -> -1 and ( 4 5 ) - > -1 then  -1 * -1 = 1
# Hint: ( 1 2 ) -> 3 and ( 4 6 ) - > -2 then  3 + -2 = 1
# Hint: ( 1 2 ) -> 3 and ( 4 7 ) - > 3 then  3 / 3 = 1
# Hint: ( 1 2 ) -> 3 and ( 4 8 ) - > 4 then  4 - 3 = 1
# Hint: ( 1 9 ) -> 8 and ( 2 4 ) - > 8 then  8 / 8 = 1
# Hint: ( 1 4 ) -> 5 and ( 2 10 ) - > 0.2 then  5 * 0.2 = 1
# Hint: ( 1 2 ) -> 3 and ( 5 1 ) - > 4 then  4 - 3 = 1
# Hint: ( 1 2 ) -> 3 and ( 5 2 ) - > 3 then  3 / 3 = 1
# Hint: ( 1 2 ) -> 3 and ( 5 3 ) - > 2 then  3 - 2 = 1
# Hint: ( 1 2 ) -> -1 and ( 5 4 ) - > -1 then  -1 * -1 = 1
# Hint: ( 1 2 ) -> -1 and ( 5 5 ) - > 0 then  0 - -1 = 1
# Hint: ( 1 2 ) -> -1 and ( 5 6 ) - > -1 then  -1 * -1 = 1
# Hint: ( 1 2 ) -> 3 and ( 5 7 ) - > -2 then  3 + -2 = 1
# Hint: ( 1 2 ) -> 3 and ( 5 8 ) - > 3 then  3 / 3 = 1
# Hint: ( 1 2 ) -> 3 and ( 5 9 ) - > 4 then  4 - 3 = 1
# Hint: ( 1 2 ) -> 3 and ( 5 10 ) - > 2.0 then  3 - 2.0 = 1
# Hint: ( 1 1 ) -> 2 and ( 2 6 ) - > 3.0 then  3.0 - 2 = 1
# Hint: ( 1 2 ) -> 3 and ( 6 2 ) - > 4 then  4 - 3 = 1
# Hint: ( 1 2 ) -> 3 and ( 6 3 ) - > 3 then  3 / 3 = 1
# Hint: ( 1 2 ) -> 3 and ( 6 4 ) - > 2 then  3 - 2 = 1
# Hint: ( 1 2 ) -> -1 and ( 6 5 ) - > -1 then  -1 * -1 = 1
# Hint: ( 1 2 ) -> -1 and ( 6 6 ) - > 0 then  0 - -1 = 1
# Hint: ( 1 2 ) -> -1 and ( 6 7 ) - > -1 then  -1 * -1 = 1
# Hint: ( 1 2 ) -> 3 and ( 6 8 ) - > -2 then  3 + -2 = 1
# Hint: ( 1 2 ) -> 3 and ( 6 9 ) - > 3 then  3 / 3 = 1
# Hint: ( 1 2 ) -> 3 and ( 6 10 ) - > 4 then  4 - 3 = 1
# Sorry, no way to make 1
# Hint: ( 1 2 ) -> 3 then ( 3 2 ) - > 6 then  7 - 6 = 1
# Hint: ( 1 2 ) -> 3 and ( 7 3 ) - > 4 then  4 - 3 = 1
# Hint: ( 1 2 ) -> 3 and ( 7 4 ) - > 3 then  3 / 3 = 1
# Hint: ( 1 2 ) -> 3 and ( 7 5 ) - > 2 then  3 - 2 = 1
# Hint: ( 1 2 ) -> -1 and ( 7 6 ) - > -1 then  -1 * -1 = 1
# Hint: ( 1 2 ) -> -1 and ( 7 7 ) - > 0 then  0 - -1 = 1
# Hint: ( 1 2 ) -> -1 and ( 7 8 ) - > -1 then  -1 * -1 = 1
# Hint: ( 1 2 ) -> 3 and ( 7 9 ) - > -2 then  3 + -2 = 1
# Hint: ( 1 2 ) -> 3 and ( 7 10 ) - > 3 then  3 / 3 = 1
# Sorry, no way to make 1
# Hint: ( 1 2 ) -> 3 and ( 8 2 ) - > 4.0 then  4.0 - 3 = 1
# Hint: ( 1 8 ) -> 7 and ( 2 3 ) - > 6 then  7 - 6 = 1
# Hint: ( 1 2 ) -> 3 and ( 8 4 ) - > 4 then  4 - 3 = 1
# Hint: ( 1 2 ) -> 3 and ( 8 5 ) - > 3 then  3 / 3 = 1
# Hint: ( 1 2 ) -> 3 and ( 8 6 ) - > 2 then  3 - 2 = 1
# Hint: ( 1 2 ) -> -1 and ( 8 7 ) - > -1 then  -1 * -1 = 1
# Hint: ( 1 2 ) -> -1 and ( 8 8 ) - > 0 then  0 - -1 = 1
# Hint: ( 1 2 ) -> -1 and ( 8 9 ) - > -1 then  -1 * -1 = 1
# Hint: ( 1 2 ) -> 3 and ( 8 10 ) - > -2 then  3 + -2 = 1
# Sorry, no way to make 1
# Hint: ( 1 2 ) -> 3 then ( 3 9 ) - > 3.0 then  3.0 - 2 = 1
# Hint: ( 1 2 ) -> 3 and ( 9 3 ) - > 3.0 then  3 / 3.0 = 1
# Hint: ( 1 9 ) -> 8 and ( 2 4 ) - > 8 then  8 / 8 = 1
# Hint: ( 1 2 ) -> 3 and ( 9 5 ) - > 4 then  4 - 3 = 1
# Hint: ( 1 2 ) -> 3 and ( 9 6 ) - > 3 then  3 / 3 = 1
# Hint: ( 1 2 ) -> 3 and ( 9 7 ) - > 2 then  3 - 2 = 1
# Hint: ( 1 2 ) -> -1 and ( 9 8 ) - > -1 then  -1 * -1 = 1
# Hint: ( 1 2 ) -> -1 and ( 9 9 ) - > 0 then  0 - -1 = 1
# Hint: ( 1 2 ) -> -1 and ( 9 10 ) - > -1 then  -1 * -1 = 1
# Sorry, no way to make 1
# Hint: ( 2 2 ) -> 0 then ( 0 10 ) - > 0 then  0 + 1 = 1
# Hint: ( 1 3 ) -> 4 and ( 2 10 ) - > 5.0 then  5.0 - 4 = 1
# Hint: ( 1 10 ) -> 9 and ( 2 4 ) - > 8 then  9 - 8 = 1
# Hint: ( 1 2 ) -> 3 and ( 10 5 ) - > 2.0 then  3 - 2.0 = 1
# Hint: ( 1 2 ) -> 3 and ( 10 6 ) - > 4 then  4 - 3 = 1
# Hint: ( 1 2 ) -> 3 and ( 10 7 ) - > 3 then  3 / 3 = 1
# Hint: ( 1 2 ) -> 3 and ( 10 8 ) - > 2 then  3 - 2 = 1
# Hint: ( 1 2 ) -> -1 and ( 10 9 ) - > -1 then  -1 * -1 = 1
# Hint: ( 1 2 ) -> -1 and ( 10 10 ) - > 0 then  0 - -1 = 1
# Hint: ( 1 3 ) -> 2 and ( 1 1 ) - > 2 then  2 / 2 = 1
# Hint: ( 1 3 ) -> 4 and ( 1 2 ) - > 3 then  4 - 3 = 1
# Hint: ( 1 3 ) -> 4 and ( 1 3 ) - > 4 then  4 / 4 = 1
# Hint: ( 1 3 ) -> 4 and ( 1 4 ) - > 5 then  5 - 4 = 1
# Hint: ( 1 3 ) -> 4 and ( 1 5 ) - > 4 then  4 / 4 = 1
# Hint: ( 1 3 ) -> 4 and ( 1 6 ) - > 5 then  5 - 4 = 1
# Hint: ( 1 1 ) -> 2 then ( 2 3 ) - > 6 then  7 - 6 = 1
# Hint: ( 1 3 ) -> 4 then ( 4 8 ) - > 2.0 then  2.0 - 1 = 1
# Hint: ( 1 1 ) -> 2 and ( 3 9 ) - > 3.0 then  3.0 - 2 = 1
# Sorry, no way to make 1
# Hint: ( 1 3 ) -> 4 and ( 2 1 ) - > 3 then  4 - 3 = 1
# Hint: ( 1 3 ) -> 4 and ( 2 2 ) - > 4 then  4 / 4 = 1
# Hint: ( 1 3 ) -> 4 and ( 2 3 ) - > 5 then  5 - 4 = 1
# Hint: ( 1 3 ) -> -2 and ( 2 4 ) - > -2 then  -2 / -2 = 1
# Hint: ( 1 3 ) -> 4 and ( 2 5 ) - > -3 then  4 + -3 = 1
# Hint: ( 1 3 ) -> 4 and ( 2 6 ) - > 4 then  4 / 4 = 1
# Hint: ( 1 3 ) -> 4 and ( 2 7 ) - > 5 then  5 - 4 = 1
# Hint: ( 1 3 ) -> 4 and ( 2 8 ) - > 0.25 then  4 * 0.25 = 1
# Hint: ( 1 2 ) -> 3 and ( 3 9 ) - > 0.3333333333333333 then  3 * 0.3333333333333333 = 1
# Hint: ( 1 3 ) -> 4 and ( 2 10 ) - > 5.0 then  5.0 - 4 = 1
# Hint: ( 1 3 ) -> 4 and ( 3 1 ) - > 4 then  4 / 4 = 1
# Hint: ( 1 3 ) -> 4 and ( 3 2 ) - > 5 then  5 - 4 = 1
# Hint: ( 1 3 ) -> 2 and ( 3 3 ) - > 1.0 then  2 - 1.0 = 1
# Hint: ( 1 3 ) -> -2 and ( 3 4 ) - > -1 then  -1 - -2 = 1
# Hint: ( 1 3 ) -> -2 and ( 3 5 ) - > -2 then  -2 / -2 = 1
# Hint: ( 1 3 ) -> 4 and ( 3 6 ) - > -3 then  4 + -3 = 1
# Hint: ( 1 3 ) -> 4 and ( 3 7 ) - > 4 then  4 / 4 = 1
# Hint: ( 1 3 ) -> 4 and ( 3 8 ) - > 5 then  5 - 4 = 1
# Hint: ( 1 3 ) -> 4 and ( 3 9 ) - > 3.0 then  4 - 3.0 = 1
# Hint: ( 1 10 ) -> 9 and ( 3 3 ) - > 9 then  9 / 9 = 1
# Hint: ( 1 3 ) -> 4 and ( 4 1 ) - > 5 then  5 - 4 = 1
# Hint: ( 1 3 ) -> -2 and ( 4 2 ) - > -2 then  -2 / -2 = 1
# Hint: ( 1 3 ) -> -2 and ( 4 3 ) - > -1 then  -1 - -2 = 1
# Hint: ( 1 3 ) -> 2 and ( 4 4 ) - > 1.0 then  2 - 1.0 = 1
# Hint: ( 1 3 ) -> -2 and ( 4 5 ) - > -1 then  -1 - -2 = 1
# Hint: ( 1 3 ) -> -2 and ( 4 6 ) - > -2 then  -2 / -2 = 1
# Hint: ( 1 3 ) -> 4 and ( 4 7 ) - > -3 then  4 + -3 = 1
# Hint: ( 1 3 ) -> 4 and ( 4 8 ) - > 4 then  4 / 4 = 1
# Hint: ( 1 3 ) -> 4 and ( 4 9 ) - > 5 then  5 - 4 = 1
# Hint: ( 1 10 ) -> 11 and ( 3 4 ) - > 12 then  12 - 11 = 1
# Hint: ( 1 3 ) -> 4 and ( 5 1 ) - > 4 then  4 / 4 = 1
# Hint: ( 1 3 ) -> 4 and ( 5 2 ) - > 3 then  4 - 3 = 1
# Hint: ( 1 3 ) -> -2 and ( 5 3 ) - > -2 then  -2 / -2 = 1
# Hint: ( 1 3 ) -> -2 and ( 5 4 ) - > -1 then  -1 - -2 = 1
# Hint: ( 1 3 ) -> 2 and ( 5 5 ) - > 1.0 then  2 - 1.0 = 1
# Hint: ( 1 3 ) -> -2 and ( 5 6 ) - > -1 then  -1 - -2 = 1
# Hint: ( 1 3 ) -> -2 and ( 5 7 ) - > -2 then  -2 / -2 = 1
# Hint: ( 1 3 ) -> 4 and ( 5 8 ) - > -3 then  4 + -3 = 1
# Hint: ( 1 3 ) -> 4 and ( 5 9 ) - > 4 then  4 / 4 = 1
# Hint: ( 1 3 ) -> 4 and ( 5 10 ) - > 5 then  5 - 4 = 1
# Hint: ( 1 3 ) -> 4 and ( 6 1 ) - > 5 then  5 - 4 = 1
# Hint: ( 1 3 ) -> 4 and ( 6 2 ) - > 4 then  4 / 4 = 1
# Hint: ( 1 3 ) -> 4 and ( 6 3 ) - > 3 then  4 - 3 = 1
# Hint: ( 1 3 ) -> -2 and ( 6 4 ) - > -2 then  -2 / -2 = 1
# Hint: ( 1 3 ) -> -2 and ( 6 5 ) - > -1 then  -1 - -2 = 1
# Hint: ( 1 3 ) -> 2 and ( 6 6 ) - > 1.0 then  2 - 1.0 = 1
# Hint: ( 1 3 ) -> -2 and ( 6 7 ) - > -1 then  -1 - -2 = 1
# Hint: ( 1 3 ) -> -2 and ( 6 8 ) - > -2 then  -2 / -2 = 1
# Hint: ( 1 3 ) -> 4 and ( 6 9 ) - > -3 then  4 + -3 = 1
# Hint: ( 1 3 ) -> 4 and ( 6 10 ) - > 4 then  4 / 4 = 1
# Hint: ( 1 7 ) -> 6 then ( 6 3 ) - > 2.0 then  2.0 - 1 = 1
# Hint: ( 1 3 ) -> 4 and ( 7 2 ) - > 5 then  5 - 4 = 1
# Hint: ( 1 3 ) -> 4 and ( 7 3 ) - > 4 then  4 / 4 = 1
# Hint: ( 1 3 ) -> 4 and ( 7 4 ) - > 3 then  4 - 3 = 1
# Hint: ( 1 3 ) -> -2 and ( 7 5 ) - > -2 then  -2 / -2 = 1
# Hint: ( 1 3 ) -> -2 and ( 7 6 ) - > -1 then  -1 - -2 = 1
# Hint: ( 1 3 ) -> 2 and ( 7 7 ) - > 1.0 then  2 - 1.0 = 1
# Hint: ( 1 3 ) -> -2 and ( 7 8 ) - > -1 then  -1 - -2 = 1
# Hint: ( 1 3 ) -> -2 and ( 7 9 ) - > -2 then  -2 / -2 = 1
# Hint: ( 1 3 ) -> 4 and ( 7 10 ) - > -3 then  4 + -3 = 1
# Hint: ( 1 3 ) -> 4 then ( 4 8 ) - > 2.0 then  2.0 - 1 = 1
# Hint: ( 1 3 ) -> 4 and ( 8 2 ) - > 4.0 then  4 / 4.0 = 1
# Hint: ( 1 3 ) -> 4 and ( 8 3 ) - > 5 then  5 - 4 = 1
# Hint: ( 1 3 ) -> 4 and ( 8 4 ) - > 4 then  4 / 4 = 1
# Hint: ( 1 3 ) -> 4 and ( 8 5 ) - > 3 then  4 - 3 = 1
# Hint: ( 1 3 ) -> -2 and ( 8 6 ) - > -2 then  -2 / -2 = 1
# Hint: ( 1 3 ) -> -2 and ( 8 7 ) - > -1 then  -1 - -2 = 1
# Hint: ( 1 3 ) -> 2 and ( 8 8 ) - > 1.0 then  2 - 1.0 = 1
# Hint: ( 1 3 ) -> -2 and ( 8 9 ) - > -1 then  -1 - -2 = 1
# Hint: ( 1 3 ) -> -2 and ( 8 10 ) - > -2 then  -2 / -2 = 1
# Hint: ( 1 1 ) -> 2 and ( 3 9 ) - > 3.0 then  3.0 - 2 = 1
# Hint: ( 1 2 ) -> 3 and ( 3 9 ) - > 0.3333333333333333 then  3 * 0.3333333333333333 = 1
# Hint: ( 1 3 ) -> 4 and ( 9 3 ) - > 3.0 then  4 - 3.0 = 1
# Hint: ( 1 3 ) -> 4 and ( 9 4 ) - > 5 then  5 - 4 = 1
# Hint: ( 1 3 ) -> 4 and ( 9 5 ) - > 4 then  4 / 4 = 1
# Hint: ( 1 3 ) -> 4 and ( 9 6 ) - > 3 then  4 - 3 = 1
# Hint: ( 1 3 ) -> -2 and ( 9 7 ) - > -2 then  -2 / -2 = 1
# Hint: ( 1 3 ) -> -2 and ( 9 8 ) - > -1 then  -1 - -2 = 1
# Hint: ( 1 3 ) -> 2 and ( 9 9 ) - > 1.0 then  2 - 1.0 = 1
# Hint: ( 1 3 ) -> -2 and ( 9 10 ) - > -1 then  -1 - -2 = 1
# Sorry, no way to make 1
# Hint: ( 1 3 ) -> 4 and ( 10 2 ) - > 5.0 then  5.0 - 4 = 1
# Hint: ( 1 10 ) -> 9 and ( 3 3 ) - > 9 then  9 / 9 = 1
# Hint: ( 1 10 ) -> 11 and ( 3 4 ) - > 12 then  12 - 11 = 1
# Hint: ( 1 3 ) -> 4 and ( 10 5 ) - > 5 then  5 - 4 = 1
# Hint: ( 1 3 ) -> 4 and ( 10 6 ) - > 4 then  4 / 4 = 1
# Hint: ( 1 3 ) -> 4 and ( 10 7 ) - > 3 then  4 - 3 = 1
# Hint: ( 1 3 ) -> -2 and ( 10 8 ) - > -2 then  -2 / -2 = 1
# Hint: ( 1 3 ) -> -2 and ( 10 9 ) - > -1 then  -1 - -2 = 1
# Hint: ( 1 3 ) -> 2 and ( 10 10 ) - > 1.0 then  2 - 1.0 = 1
# Hint: ( 1 4 ) -> 3 and ( 1 1 ) - > 2 then  3 - 2 = 1
# Hint: ( 1 4 ) -> 3 and ( 1 2 ) - > 3 then  3 / 3 = 1
# Hint: ( 1 4 ) -> 5 and ( 1 3 ) - > 4 then  5 - 4 = 1
# Hint: ( 1 4 ) -> 5 and ( 1 4 ) - > 5 then  5 / 5 = 1
# Hint: ( 1 4 ) -> 5 and ( 1 5 ) - > 6 then  6 - 5 = 1
# Hint: ( 1 4 ) -> 5 and ( 1 6 ) - > 5 then  5 / 5 = 1
# Hint: ( 1 4 ) -> 5 and ( 1 7 ) - > 6 then  6 - 5 = 1
# Hint: ( 1 1 ) -> 2 and ( 4 8 ) - > 0.5 then  2 * 0.5 = 1
# Hint: ( 1 1 ) -> 2 then ( 2 4 ) - > 8 then  9 - 8 = 1
# Hint: ( 1 4 ) -> 5 then ( 5 10 ) - > 2.0 then  2.0 - 1 = 1
# Hint: ( 1 4 ) -> 3 and ( 2 1 ) - > 3 then  3 / 3 = 1
# Hint: ( 1 4 ) -> 5 and ( 2 2 ) - > 4 then  5 - 4 = 1
# Hint: ( 1 4 ) -> 5 and ( 2 3 ) - > 5 then  5 / 5 = 1
# Hint: ( 1 4 ) -> 5 and ( 2 4 ) - > 6 then  6 - 5 = 1
# Hint: ( 1 4 ) -> -3 and ( 2 5 ) - > -3 then  -3 / -3 = 1
# Hint: ( 1 4 ) -> 5 and ( 2 6 ) - > -4 then  5 + -4 = 1
# Hint: ( 1 4 ) -> 5 and ( 2 7 ) - > 5 then  5 / 5 = 1
# Hint: ( 1 4 ) -> 5 and ( 2 8 ) - > 6 then  6 - 5 = 1
# Hint: ( 1 9 ) -> 8 and ( 4 2 ) - > 8 then  8 / 8 = 1
# Hint: ( 1 4 ) -> 5 and ( 2 10 ) - > 0.2 then  5 * 0.2 = 1
# Hint: ( 1 4 ) -> 5 and ( 3 1 ) - > 4 then  5 - 4 = 1
# Hint: ( 1 4 ) -> 5 and ( 3 2 ) - > 5 then  5 / 5 = 1
# Hint: ( 1 4 ) -> 5 and ( 3 3 ) - > 6 then  6 - 5 = 1
# Hint: ( 1 4 ) -> 0.25 and ( 3 4 ) - > 0.75 then  0.25 + 0.75 = 1
# Hint: ( 1 4 ) -> -3 and ( 3 5 ) - > -2 then  -2 - -3 = 1
# Hint: ( 1 4 ) -> -3 and ( 3 6 ) - > -3 then  -3 / -3 = 1
# Hint: ( 1 4 ) -> 5 and ( 3 7 ) - > -4 then  5 + -4 = 1
# Hint: ( 1 4 ) -> 5 and ( 3 8 ) - > 5 then  5 / 5 = 1
# Hint: ( 1 4 ) -> 5 and ( 3 9 ) - > 6 then  6 - 5 = 1
# Hint: ( 1 10 ) -> 11 and ( 4 3 ) - > 12 then  12 - 11 = 1
# Hint: ( 1 4 ) -> 5 and ( 4 1 ) - > 5 then  5 / 5 = 1
# Hint: ( 1 4 ) -> 5 and ( 4 2 ) - > 6 then  6 - 5 = 1
# Hint: ( 1 4 ) -> 0.25 and ( 4 3 ) - > 0.75 then  0.25 + 0.75 = 1
# Hint: ( 4 4 ) -> 8 then ( 8 4 ) - > 2.0 then  2.0 - 1 = 1
# Hint: ( 1 4 ) -> 0.25 and ( 4 5 ) - > 1.25 then  1.25 - 0.25 = 1
# Hint: ( 1 4 ) -> -3 and ( 4 6 ) - > -2 then  -2 - -3 = 1
# Hint: ( 1 4 ) -> -3 and ( 4 7 ) - > -3 then  -3 / -3 = 1
# Hint: ( 1 4 ) -> 5 and ( 4 8 ) - > -4 then  5 + -4 = 1
# Hint: ( 1 4 ) -> 5 and ( 4 9 ) - > 5 then  5 / 5 = 1
# Hint: ( 1 4 ) -> 5 and ( 4 10 ) - > 6 then  6 - 5 = 1
# Hint: ( 1 4 ) -> 5 and ( 5 1 ) - > 6 then  6 - 5 = 1
# Hint: ( 1 4 ) -> -3 and ( 5 2 ) - > -3 then  -3 / -3 = 1
# Hint: ( 1 4 ) -> -3 and ( 5 3 ) - > -2 then  -2 - -3 = 1
# Hint: ( 1 4 ) -> 0.25 and ( 5 4 ) - > 1.25 then  1.25 - 0.25 = 1
# Hint: ( 1 5 ) -> 0.2 and ( 4 5 ) - > 0.8 then  0.2 + 0.8 = 1
# Hint: ( 4 6 ) -> 10 then ( 10 5 ) - > 2.0 then  2.0 - 1 = 1
# Hint: ( 1 4 ) -> -3 and ( 5 7 ) - > -2 then  -2 - -3 = 1
# Hint: ( 1 4 ) -> -3 and ( 5 8 ) - > -3 then  -3 / -3 = 1
# Hint: ( 1 4 ) -> 5 and ( 5 9 ) - > -4 then  5 + -4 = 1
# Hint: ( 1 4 ) -> 5 and ( 5 10 ) - > 5 then  5 / 5 = 1
# Hint: ( 1 4 ) -> 5 and ( 6 1 ) - > 5 then  5 / 5 = 1
# Hint: ( 1 4 ) -> 5 and ( 6 2 ) - > 4 then  5 - 4 = 1
# Hint: ( 1 4 ) -> -3 and ( 6 3 ) - > -3 then  -3 / -3 = 1
# Hint: ( 1 4 ) -> -3 and ( 6 4 ) - > -2 then  -2 - -3 = 1
# Hint: ( 4 6 ) -> 10 then ( 10 5 ) - > 2.0 then  2.0 - 1 = 1
# Hint: ( 6 6 ) -> 0 then ( 0 4 ) - > 0 then  0 + 1 = 1
# Hint: ( 4 7 ) -> 3 then ( 3 6 ) - > 2.0 then  2.0 - 1 = 1
# Hint: ( 1 4 ) -> -3 and ( 6 8 ) - > -2 then  -2 - -3 = 1
# Hint: ( 1 4 ) -> -3 and ( 6 9 ) - > -3 then  -3 / -3 = 1
# Hint: ( 1 4 ) -> 5 and ( 6 10 ) - > -4 then  5 + -4 = 1
# Hint: ( 1 4 ) -> 5 and ( 7 1 ) - > 6 then  6 - 5 = 1
# Hint: ( 1 4 ) -> 5 and ( 7 2 ) - > 5 then  5 / 5 = 1
# Hint: ( 1 4 ) -> 5 and ( 7 3 ) - > 4 then  5 - 4 = 1
# Hint: ( 1 4 ) -> -3 and ( 7 4 ) - > -3 then  -3 / -3 = 1
# Hint: ( 1 4 ) -> -3 and ( 7 5 ) - > -2 then  -2 - -3 = 1
# Hint: ( 4 7 ) -> 3 then ( 3 6 ) - > 2.0 then  2.0 - 1 = 1
# Hint: ( 7 7 ) -> 0 then ( 0 4 ) - > 0 then  0 + 1 = 1
# Sorry, no way to make 1
# Hint: ( 1 4 ) -> -3 and ( 7 9 ) - > -2 then  -2 - -3 = 1
# Hint: ( 1 4 ) -> -3 and ( 7 10 ) - > -3 then  -3 / -3 = 1
# Hint: ( 1 1 ) -> 2 and ( 4 8 ) - > 0.5 then  2 * 0.5 = 1
# Hint: ( 1 4 ) -> 5 and ( 8 2 ) - > 6 then  6 - 5 = 1
# Hint: ( 1 4 ) -> 5 and ( 8 3 ) - > 5 then  5 / 5 = 1
# Hint: ( 1 4 ) -> 5 and ( 8 4 ) - > 4 then  5 - 4 = 1
# Hint: ( 1 4 ) -> -3 and ( 8 5 ) - > -3 then  -3 / -3 = 1
# Hint: ( 1 4 ) -> -3 and ( 8 6 ) - > -2 then  -2 - -3 = 1
# Sorry, no way to make 1
# Hint: ( 4 8 ) -> 4 then ( 4 8 ) - > 2.0 then  2.0 - 1 = 1
# Sorry, no way to make 1
# Hint: ( 1 4 ) -> -3 and ( 8 10 ) - > -2 then  -2 - -3 = 1
# Hint: ( 1 9 ) -> 8 then ( 8 4 ) - > 2.0 then  2.0 - 1 = 1
# Hint: ( 1 9 ) -> 8 and ( 4 2 ) - > 8 then  8 / 8 = 1
# Hint: ( 1 4 ) -> 5 and ( 9 3 ) - > 6 then  6 - 5 = 1
# Hint: ( 1 4 ) -> 5 and ( 9 4 ) - > 5 then  5 / 5 = 1
# Hint: ( 1 4 ) -> 5 and ( 9 5 ) - > 4 then  5 - 4 = 1
# Hint: ( 1 4 ) -> -3 and ( 9 6 ) - > -3 then  -3 / -3 = 1
# Hint: ( 1 4 ) -> -3 and ( 9 7 ) - > -2 then  -2 - -3 = 1
# Sorry, no way to make 1
# Hint: ( 9 9 ) -> 0 then ( 0 4 ) - > 0 then  0 + 1 = 1
# Hint: ( 4 9 ) -> 5 then ( 5 10 ) - > 2.0 then  2.0 - 1 = 1
# Hint: ( 1 4 ) -> 5 then ( 5 10 ) - > 2.0 then  2.0 - 1 = 1
# Hint: ( 1 4 ) -> 5 and ( 10 2 ) - > 5.0 then  5 / 5.0 = 1
# Hint: ( 1 10 ) -> 11 and ( 4 3 ) - > 12 then  12 - 11 = 1
# Hint: ( 1 4 ) -> 5 and ( 10 4 ) - > 6 then  6 - 5 = 1
# Hint: ( 1 4 ) -> 5 and ( 10 5 ) - > 5 then  5 / 5 = 1
# Hint: ( 1 4 ) -> 5 and ( 10 6 ) - > 4 then  5 - 4 = 1
# Hint: ( 1 4 ) -> -3 and ( 10 7 ) - > -3 then  -3 / -3 = 1
# Hint: ( 1 4 ) -> -3 and ( 10 8 ) - > -2 then  -2 - -3 = 1
# Hint: ( 4 9 ) -> 5 then ( 5 10 ) - > 2.0 then  2.0 - 1 = 1
# Hint: ( 10 10 ) -> 0 then ( 0 4 ) - > 0 then  0 + 1 = 1
# Hint: ( 1 1 ) -> 0 then ( 0 5 ) - > 0 then  0 + 1 = 1
# Hint: ( 1 5 ) -> 4 and ( 1 2 ) - > 3 then  4 - 3 = 1
# Hint: ( 1 5 ) -> 4 and ( 1 3 ) - > 4 then  4 / 4 = 1
# Hint: ( 1 5 ) -> 6 and ( 1 4 ) - > 5 then  6 - 5 = 1
# Hint: ( 1 5 ) -> 6 and ( 1 5 ) - > 6 then  6 / 6 = 1
# Hint: ( 1 5 ) -> 6 and ( 1 6 ) - > 7 then  7 - 6 = 1
# Hint: ( 1 5 ) -> 6 and ( 1 7 ) - > 6 then  6 / 6 = 1
# Hint: ( 1 5 ) -> 6 and ( 1 8 ) - > 7 then  7 - 6 = 1
# Hint: ( 1 1 ) -> 2 then ( 2 5 ) - > 10 then  10 - 9 = 1
# Hint: ( 1 1 ) -> 2 and ( 5 10 ) - > 0.5 then  2 * 0.5 = 1
# Hint: ( 1 5 ) -> 4 and ( 2 1 ) - > 3 then  4 - 3 = 1
# Hint: ( 1 5 ) -> 4 and ( 2 2 ) - > 4 then  4 / 4 = 1
# Hint: ( 1 5 ) -> 6 and ( 2 3 ) - > 5 then  6 - 5 = 1
# Hint: ( 1 5 ) -> 6 and ( 2 4 ) - > 6 then  6 / 6 = 1
# Hint: ( 1 5 ) -> 6 and ( 2 5 ) - > 7 then  7 - 6 = 1
# Hint: ( 1 5 ) -> -4 and ( 2 6 ) - > -4 then  -4 / -4 = 1
# Hint: ( 1 5 ) -> 6 and ( 2 7 ) - > -5 then  6 + -5 = 1
# Hint: ( 1 5 ) -> 6 and ( 2 8 ) - > 6 then  6 / 6 = 1
# Hint: ( 1 5 ) -> 6 and ( 2 9 ) - > 7 then  7 - 6 = 1
# Hint: ( 1 5 ) -> 6 and ( 2 10 ) - > 5.0 then  6 - 5.0 = 1
# Hint: ( 1 5 ) -> 4 and ( 3 1 ) - > 4 then  4 / 4 = 1
# Hint: ( 1 5 ) -> 6 and ( 3 2 ) - > 5 then  6 - 5 = 1
# Hint: ( 1 5 ) -> 6 and ( 3 3 ) - > 6 then  6 / 6 = 1
# Hint: ( 1 5 ) -> 6 and ( 3 4 ) - > 7 then  7 - 6 = 1
# Hint: ( 1 3 ) -> 2 and ( 5 5 ) - > 1.0 then  2 - 1.0 = 1
# Hint: ( 1 5 ) -> -4 and ( 3 6 ) - > -3 then  -3 - -4 = 1
# Hint: ( 1 5 ) -> -4 and ( 3 7 ) - > -4 then  -4 / -4 = 1
# Hint: ( 1 5 ) -> 6 and ( 3 8 ) - > -5 then  6 + -5 = 1
# Hint: ( 1 5 ) -> 6 and ( 3 9 ) - > 6 then  6 / 6 = 1
# Hint: ( 1 5 ) -> 6 and ( 3 10 ) - > 7 then  7 - 6 = 1
# Hint: ( 1 5 ) -> 6 and ( 4 1 ) - > 5 then  6 - 5 = 1
# Hint: ( 1 5 ) -> 6 and ( 4 2 ) - > 6 then  6 / 6 = 1
# Hint: ( 1 5 ) -> 6 and ( 4 3 ) - > 7 then  7 - 6 = 1
# Hint: ( 1 4 ) -> 0.25 and ( 5 4 ) - > 1.25 then  1.25 - 0.25 = 1
# Hint: ( 1 5 ) -> 0.2 and ( 4 5 ) - > 0.8 then  0.2 + 0.8 = 1
# Hint: ( 4 6 ) -> 10 then ( 10 5 ) - > 2.0 then  2.0 - 1 = 1
# Hint: ( 1 5 ) -> -4 and ( 4 7 ) - > -3 then  -3 - -4 = 1
# Hint: ( 1 5 ) -> -4 and ( 4 8 ) - > -4 then  -4 / -4 = 1
# Hint: ( 1 5 ) -> 6 and ( 4 9 ) - > -5 then  6 + -5 = 1
# Hint: ( 1 5 ) -> 6 and ( 4 10 ) - > 6 then  6 / 6 = 1
# Hint: ( 1 5 ) -> 6 and ( 5 1 ) - > 6 then  6 / 6 = 1
# Hint: ( 1 5 ) -> 6 and ( 5 2 ) - > 7 then  7 - 6 = 1
# Hint: ( 1 3 ) -> 2 and ( 5 5 ) - > 1.0 then  2 - 1.0 = 1
# Hint: ( 1 5 ) -> 0.2 and ( 5 4 ) - > 0.8 then  0.2 + 0.8 = 1
# Hint: ( 5 5 ) -> 10 then ( 10 5 ) - > 2.0 then  2.0 - 1 = 1
# Hint: ( 1 5 ) -> 0.2 and ( 5 6 ) - > 1.2 then  1.2 - 0.2 = 1
# Hint: ( 5 5 ) -> 0 then ( 0 7 ) - > 0 then  0 + 1 = 1
# Hint: ( 1 5 ) -> -4 and ( 5 8 ) - > -3 then  -3 - -4 = 1
# Hint: ( 1 5 ) -> -4 and ( 5 9 ) - > -4 then  -4 / -4 = 1
# Hint: ( 1 5 ) -> 6 and ( 5 10 ) - > -5 then  6 + -5 = 1
# Hint: ( 1 5 ) -> 6 and ( 6 1 ) - > 7 then  7 - 6 = 1
# Hint: ( 1 5 ) -> -4 and ( 6 2 ) - > -4 then  -4 / -4 = 1
# Hint: ( 1 5 ) -> -4 and ( 6 3 ) - > -3 then  -3 - -4 = 1
# Hint: ( 6 4 ) -> 10 then ( 10 5 ) - > 2.0 then  2.0 - 1 = 1
# Hint: ( 1 5 ) -> 0.2 and ( 6 5 ) - > 1.2 then  1.2 - 0.2 = 1
# Hint: ( 1 6 ) -> 0.16666666666666666 and ( 5 6 ) - > 0.8333333333333334 then  0.16666666666666666 + 0.8333333333333334 = 1
# Hint: ( 5 7 ) -> 12 then ( 12 6 ) - > 2.0 then  2.0 - 1 = 1
# Hint: ( 5 8 ) -> 3 then ( 3 6 ) - > 2.0 then  2.0 - 1 = 1
# Hint: ( 1 5 ) -> -4 and ( 6 9 ) - > -3 then  -3 - -4 = 1
# Hint: ( 1 5 ) -> -4 and ( 6 10 ) - > -4 then  -4 / -4 = 1
# Hint: ( 1 5 ) -> 6 and ( 7 1 ) - > 6 then  6 / 6 = 1
# Hint: ( 1 5 ) -> 6 and ( 7 2 ) - > 5 then  6 - 5 = 1
# Hint: ( 1 5 ) -> -4 and ( 7 3 ) - > -4 then  -4 / -4 = 1
# Hint: ( 1 5 ) -> -4 and ( 7 4 ) - > -3 then  -3 - -4 = 1
# Hint: ( 5 5 ) -> 0 then ( 0 7 ) - > 0 then  0 + 1 = 1
# Hint: ( 5 7 ) -> 12 then ( 12 6 ) - > 2.0 then  2.0 - 1 = 1
# Hint: ( 7 7 ) -> 0 then ( 0 5 ) - > 0 then  0 + 1 = 1
# Sorry, no way to make 1
# Hint: ( 5 9 ) -> 14 then ( 14 7 ) - > 2.0 then  2.0 - 1 = 1
# Hint: ( 1 5 ) -> -4 and ( 7 10 ) - > -3 then  -3 - -4 = 1
# Hint: ( 1 5 ) -> 6 and ( 8 1 ) - > 7 then  7 - 6 = 1
# Hint: ( 1 5 ) -> 6 and ( 8 2 ) - > 6 then  6 / 6 = 1
# Hint: ( 1 5 ) -> 6 and ( 8 3 ) - > 5 then  6 - 5 = 1
# Hint: ( 1 5 ) -> -4 and ( 8 4 ) - > -4 then  -4 / -4 = 1
# Hint: ( 1 5 ) -> -4 and ( 8 5 ) - > -3 then  -3 - -4 = 1
# Hint: ( 5 8 ) -> 3 then ( 3 6 ) - > 2.0 then  2.0 - 1 = 1
# Sorry, no way to make 1
# Hint: ( 8 8 ) -> 0 then ( 0 5 ) - > 0 then  0 + 1 = 1
# Hint: ( 5 9 ) -> 4 then ( 4 8 ) - > 2.0 then  2.0 - 1 = 1
# Hint: ( 1 5 ) -> 0.2 and ( 8 10 ) - > 0.8 then  0.2 + 0.8 = 1
# Hint: ( 1 9 ) -> 10 then ( 10 5 ) - > 2.0 then  2.0 - 1 = 1
# Hint: ( 1 5 ) -> 6 and ( 9 2 ) - > 7 then  7 - 6 = 1
# Hint: ( 1 5 ) -> 6 and ( 9 3 ) - > 6 then  6 / 6 = 1
# Hint: ( 1 5 ) -> 6 and ( 9 4 ) - > 5 then  6 - 5 = 1
# Hint: ( 1 5 ) -> -4 and ( 9 5 ) - > -4 then  -4 / -4 = 1
# Hint: ( 1 5 ) -> -4 and ( 9 6 ) - > -3 then  -3 - -4 = 1
# Hint: ( 5 9 ) -> 14 then ( 14 7 ) - > 2.0 then  2.0 - 1 = 1
# Hint: ( 5 9 ) -> 4 then ( 4 8 ) - > 2.0 then  2.0 - 1 = 1
# Hint: ( 9 9 ) -> 0 then ( 0 5 ) - > 0 then  0 + 1 = 1
# Sorry, no way to make 1
# Hint: ( 1 1 ) -> 2 and ( 5 10 ) - > 0.5 then  2 * 0.5 = 1
# Hint: ( 1 5 ) -> 6 and ( 10 2 ) - > 5.0 then  6 - 5.0 = 1
# Hint: ( 1 5 ) -> 6 and ( 10 3 ) - > 7 then  7 - 6 = 1
# Hint: ( 1 5 ) -> 6 and ( 10 4 ) - > 6 then  6 / 6 = 1
# Hint: ( 1 5 ) -> 6 and ( 10 5 ) - > 5 then  6 - 5 = 1
# Hint: ( 1 5 ) -> -4 and ( 10 6 ) - > -4 then  -4 / -4 = 1
# Hint: ( 1 5 ) -> -4 and ( 10 7 ) - > -3 then  -3 - -4 = 1
# Hint: ( 1 5 ) -> 0.2 and ( 10 8 ) - > 0.8 then  0.2 + 0.8 = 1
# Sorry, no way to make 1
# Hint: ( 5 10 ) -> 5 then ( 5 10 ) - > 2.0 then  2.0 - 1 = 1
# Hint: ( 1 1 ) -> 0 then ( 0 6 ) - > 0 then  0 + 1 = 1
# Hint: ( 1 1 ) -> 2 and ( 6 2 ) - > 3.0 then  3.0 - 2 = 1
# Hint: ( 1 6 ) -> 5 and ( 1 3 ) - > 4 then  5 - 4 = 1
# Hint: ( 1 6 ) -> 5 and ( 1 4 ) - > 5 then  5 / 5 = 1
# Hint: ( 1 6 ) -> 7 and ( 1 5 ) - > 6 then  7 - 6 = 1
# Hint: ( 1 6 ) -> 7 and ( 1 6 ) - > 7 then  7 / 7 = 1
# Hint: ( 1 6 ) -> 7 and ( 1 7 ) - > 8 then  8 - 7 = 1
# Hint: ( 1 6 ) -> 7 and ( 1 8 ) - > 7 then  7 / 7 = 1
# Hint: ( 1 6 ) -> 7 and ( 1 9 ) - > 8 then  8 - 7 = 1
# Hint: ( 1 6 ) -> 5 then ( 5 10 ) - > 2.0 then  2.0 - 1 = 1
# Hint: ( 1 1 ) -> 2 and ( 6 2 ) - > 3.0 then  3.0 - 2 = 1
# Hint: ( 1 6 ) -> 5 and ( 2 2 ) - > 4 then  5 - 4 = 1
# Hint: ( 1 6 ) -> 7 and ( 2 3 ) - > 6 then  7 - 6 = 1
# Hint: ( 1 6 ) -> 7 and ( 2 4 ) - > 6 then  7 - 6 = 1
# Hint: ( 1 6 ) -> 7 and ( 2 5 ) - > 7 then  7 / 7 = 1
# Hint: ( 1 6 ) -> 7 and ( 2 6 ) - > 8 then  8 - 7 = 1
# Hint: ( 1 6 ) -> -5 and ( 2 7 ) - > -5 then  -5 / -5 = 1
# Hint: ( 1 6 ) -> 7 and ( 2 8 ) - > -6 then  7 + -6 = 1
# Hint: ( 1 6 ) -> 7 and ( 2 9 ) - > 7 then  7 / 7 = 1
# Hint: ( 1 6 ) -> 7 and ( 2 10 ) - > 8 then  8 - 7 = 1
# Hint: ( 1 6 ) -> 5 and ( 3 1 ) - > 4 then  5 - 4 = 1
# Hint: ( 1 6 ) -> 7 and ( 3 2 ) - > 6 then  7 - 6 = 1
# Hint: ( 1 6 ) -> 7 and ( 3 3 ) - > 6 then  7 - 6 = 1
# Hint: ( 1 6 ) -> 7 and ( 3 4 ) - > 7 then  7 / 7 = 1
# Hint: ( 1 6 ) -> 7 and ( 3 5 ) - > 8 then  8 - 7 = 1
# Hint: ( 1 3 ) -> 2 and ( 6 6 ) - > 1.0 then  2 - 1.0 = 1
# Hint: ( 1 6 ) -> -5 and ( 3 7 ) - > -4 then  -4 - -5 = 1
# Hint: ( 1 6 ) -> -5 and ( 3 8 ) - > -5 then  -5 / -5 = 1
# Hint: ( 1 6 ) -> 7 and ( 3 9 ) - > -6 then  7 + -6 = 1
# Hint: ( 1 6 ) -> 7 and ( 3 10 ) - > 7 then  7 / 7 = 1
# Hint: ( 1 6 ) -> 5 and ( 4 1 ) - > 5 then  5 / 5 = 1
# Hint: ( 1 6 ) -> 7 and ( 4 2 ) - > 6 then  7 - 6 = 1
# Hint: ( 1 6 ) -> 7 and ( 4 3 ) - > 7 then  7 / 7 = 1
# Hint: ( 1 6 ) -> 7 and ( 4 4 ) - > 8 then  8 - 7 = 1
# Hint: ( 6 4 ) -> 10 then ( 10 5 ) - > 2.0 then  2.0 - 1 = 1
# Hint: ( 6 6 ) -> 0 then ( 0 4 ) - > 0 then  0 + 1 = 1
# Hint: ( 4 7 ) -> 3 then ( 3 6 ) - > 2.0 then  2.0 - 1 = 1
# Hint: ( 1 6 ) -> -5 and ( 4 8 ) - > -4 then  -4 - -5 = 1
# Hint: ( 1 6 ) -> -5 and ( 4 9 ) - > -5 then  -5 / -5 = 1
# Hint: ( 1 6 ) -> 7 and ( 4 10 ) - > -6 then  7 + -6 = 1
# Hint: ( 1 6 ) -> 7 and ( 5 1 ) - > 6 then  7 - 6 = 1
# Hint: ( 1 6 ) -> 7 and ( 5 2 ) - > 7 then  7 / 7 = 1
# Hint: ( 1 6 ) -> 7 and ( 5 3 ) - > 8 then  8 - 7 = 1
# Hint: ( 6 4 ) -> 10 then ( 10 5 ) - > 2.0 then  2.0 - 1 = 1
# Hint: ( 1 5 ) -> 0.2 and ( 6 5 ) - > 1.2 then  1.2 - 0.2 = 1
# Hint: ( 1 6 ) -> 0.16666666666666666 and ( 5 6 ) - > 0.8333333333333334 then  0.16666666666666666 + 0.8333333333333334 = 1
# Hint: ( 5 7 ) -> 12 then ( 12 6 ) - > 2.0 then  2.0 - 1 = 1
# Hint: ( 5 8 ) -> 3 then ( 3 6 ) - > 2.0 then  2.0 - 1 = 1
# Hint: ( 1 6 ) -> -5 and ( 5 9 ) - > -4 then  -4 - -5 = 1
# Hint: ( 1 6 ) -> -5 and ( 5 10 ) - > -5 then  -5 / -5 = 1
# Hint: ( 1 6 ) -> 7 and ( 6 1 ) - > 7 then  7 / 7 = 1
# Hint: ( 1 6 ) -> 7 and ( 6 2 ) - > 8 then  8 - 7 = 1
# Hint: ( 1 3 ) -> 2 and ( 6 6 ) - > 1.0 then  2 - 1.0 = 1
# Hint: ( 6 6 ) -> 0 then ( 0 4 ) - > 0 then  0 + 1 = 1
# Hint: ( 1 6 ) -> 0.16666666666666666 and ( 6 5 ) - > 0.8333333333333334 then  0.16666666666666666 + 0.8333333333333334 = 1
# Hint: ( 6 6 ) -> 12 then ( 12 6 ) - > 2.0 then  2.0 - 1 = 1
# Hint: ( 1 6 ) -> 0.16666666666666666 and ( 6 7 ) - > 1.1666666666666667 then  1.1666666666666667 - 0.16666666666666666 = 1
# Hint: ( 6 6 ) -> 0 then ( 0 8 ) - > 0 then  0 + 1 = 1
# Hint: ( 6 6 ) -> 0 then ( 0 9 ) - > 0 then  0 + 1 = 1
# Hint: ( 1 6 ) -> -5 and ( 6 10 ) - > -4 then  -4 - -5 = 1
# Hint: ( 1 6 ) -> 7 and ( 7 1 ) - > 8 then  8 - 7 = 1
# Hint: ( 1 6 ) -> -5 and ( 7 2 ) - > -5 then  -5 / -5 = 1
# Hint: ( 1 6 ) -> -5 and ( 7 3 ) - > -4 then  -4 - -5 = 1
# Hint: ( 7 4 ) -> 3 then ( 3 6 ) - > 2.0 then  2.0 - 1 = 1
# Hint: ( 7 5 ) -> 12 then ( 12 6 ) - > 2.0 then  2.0 - 1 = 1
# Hint: ( 1 6 ) -> 0.16666666666666666 and ( 7 6 ) - > 1.1666666666666667 then  1.1666666666666667 - 0.16666666666666666 = 1
# Hint: ( 1 7 ) -> 0.14285714285714285 and ( 6 7 ) - > 0.8571428571428571 then  0.14285714285714285 + 0.8571428571428571 = 1
# Hint: ( 6 8 ) -> 14 then ( 14 7 ) - > 2.0 then  2.0 - 1 = 1
# Sorry, no way to make 1
# Hint: ( 7 10 ) -> 3 then ( 3 6 ) - > 2.0 then  2.0 - 1 = 1
# Hint: ( 1 6 ) -> 7 and ( 8 1 ) - > 7 then  7 / 7 = 1
# Hint: ( 1 6 ) -> 7 and ( 8 2 ) - > 6 then  7 - 6 = 1
# Hint: ( 1 6 ) -> -5 and ( 8 3 ) - > -5 then  -5 / -5 = 1
# Hint: ( 1 6 ) -> -5 and ( 8 4 ) - > -4 then  -4 - -5 = 1
# Hint: ( 8 5 ) -> 3 then ( 3 6 ) - > 2.0 then  2.0 - 1 = 1
# Hint: ( 6 6 ) -> 0 then ( 0 8 ) - > 0 then  0 + 1 = 1
# Hint: ( 6 8 ) -> 14 then ( 14 7 ) - > 2.0 then  2.0 - 1 = 1
# Hint: ( 8 8 ) -> 0 then ( 0 6 ) - > 0 then  0 + 1 = 1
# Sorry, no way to make 1
# Hint: ( 6 10 ) -> 16 then ( 16 8 ) - > 2.0 then  2.0 - 1 = 1
# Hint: ( 1 6 ) -> 7 and ( 9 1 ) - > 8 then  8 - 7 = 1
# Hint: ( 1 6 ) -> 7 and ( 9 2 ) - > 7 then  7 / 7 = 1
# Hint: ( 1 6 ) -> 7 and ( 9 3 ) - > 6 then  7 - 6 = 1
# Hint: ( 1 6 ) -> -5 and ( 9 4 ) - > -5 then  -5 / -5 = 1
# Hint: ( 1 6 ) -> -5 and ( 9 5 ) - > -4 then  -4 - -5 = 1
# Hint: ( 6 9 ) -> 3 then ( 3 6 ) - > 2.0 then  2.0 - 1 = 1
# Sorry, no way to make 1
# Sorry, no way to make 1
# Hint: ( 9 9 ) -> 0 then ( 0 6 ) - > 0 then  0 + 1 = 1
# Sorry, no way to make 1
# Hint: ( 1 6 ) -> 5 then ( 5 10 ) - > 2.0 then  2.0 - 1 = 1
# Hint: ( 1 6 ) -> 7 and ( 10 2 ) - > 8 then  8 - 7 = 1
# Hint: ( 1 6 ) -> 7 and ( 10 3 ) - > 7 then  7 / 7 = 1
# Hint: ( 1 6 ) -> 7 and ( 10 4 ) - > 6 then  7 - 6 = 1
# Hint: ( 1 6 ) -> -5 and ( 10 5 ) - > -5 then  -5 / -5 = 1
# Hint: ( 1 6 ) -> -5 and ( 10 6 ) - > -4 then  -4 - -5 = 1
# Hint: ( 10 7 ) -> 3 then ( 3 6 ) - > 2.0 then  2.0 - 1 = 1
# Hint: ( 6 10 ) -> 16 then ( 16 8 ) - > 2.0 then  2.0 - 1 = 1
# Sorry, no way to make 1
# Hint: ( 10 10 ) -> 0 then ( 0 6 ) - > 0 then  0 + 1 = 1
# Hint: ( 1 1 ) -> 0 then ( 0 7 ) - > 0 then  0 + 1 = 1
# Sorry, no way to make 1
# Hint: ( 1 7 ) -> 6 then ( 6 3 ) - > 2.0 then  2.0 - 1 = 1
# Hint: ( 1 7 ) -> 6 and ( 1 4 ) - > 5 then  6 - 5 = 1
# Hint: ( 1 7 ) -> 6 and ( 1 5 ) - > 6 then  6 / 6 = 1
# Hint: ( 1 7 ) -> 8 and ( 1 6 ) - > 7 then  8 - 7 = 1
# Hint: ( 1 7 ) -> 8 and ( 1 7 ) - > 8 then  8 / 8 = 1
# Hint: ( 1 7 ) -> 8 and ( 1 8 ) - > 9 then  9 - 8 = 1
# Hint: ( 1 7 ) -> 8 and ( 1 9 ) - > 8 then  8 / 8 = 1
# Hint: ( 1 7 ) -> 8 and ( 1 10 ) - > 9 then  9 - 8 = 1
# Sorry, no way to make 1
# Hint: ( 1 7 ) -> 6 then ( 6 2 ) - > 3.0 then  3.0 - 2 = 1
# Hint: ( 1 7 ) -> 6 and ( 2 3 ) - > 5 then  6 - 5 = 1
# Hint: ( 1 7 ) -> 8 and ( 2 4 ) - > 8 then  8 / 8 = 1
# Hint: ( 1 7 ) -> 8 and ( 2 5 ) - > 7 then  8 - 7 = 1
# Hint: ( 1 7 ) -> 8 and ( 2 6 ) - > 8 then  8 / 8 = 1
# Hint: ( 1 7 ) -> 8 and ( 2 7 ) - > 9 then  9 - 8 = 1
# Hint: ( 1 7 ) -> -6 and ( 2 8 ) - > -6 then  -6 / -6 = 1
# Hint: ( 1 7 ) -> 8 and ( 2 9 ) - > -7 then  8 + -7 = 1
# Hint: ( 1 7 ) -> 8 and ( 2 10 ) - > 8 then  8 / 8 = 1
# Hint: ( 1 7 ) -> 6 then ( 6 3 ) - > 2.0 then  2.0 - 1 = 1
# Hint: ( 1 7 ) -> 6 and ( 3 2 ) - > 5 then  6 - 5 = 1
# Hint: ( 1 7 ) -> 8 and ( 3 3 ) - > 9 then  9 - 8 = 1
# Hint: ( 1 7 ) -> 8 and ( 3 4 ) - > 7 then  8 - 7 = 1
# Hint: ( 1 7 ) -> 8 and ( 3 5 ) - > 8 then  8 / 8 = 1
# Hint: ( 1 7 ) -> 8 and ( 3 6 ) - > 9 then  9 - 8 = 1
# Hint: ( 1 3 ) -> 2 and ( 7 7 ) - > 1.0 then  2 - 1.0 = 1
# Hint: ( 1 7 ) -> -6 and ( 3 8 ) - > -5 then  -5 - -6 = 1
# Hint: ( 1 7 ) -> -6 and ( 3 9 ) - > -6 then  -6 / -6 = 1
# Hint: ( 1 7 ) -> 8 and ( 3 10 ) - > -7 then  8 + -7 = 1
# Hint: ( 1 7 ) -> 6 and ( 4 1 ) - > 5 then  6 - 5 = 1
# Hint: ( 1 7 ) -> 8 and ( 4 2 ) - > 8 then  8 / 8 = 1
# Hint: ( 1 7 ) -> 8 and ( 4 3 ) - > 7 then  8 - 7 = 1
# Hint: ( 1 7 ) -> 8 and ( 4 4 ) - > 8 then  8 / 8 = 1
# Hint: ( 1 7 ) -> 8 and ( 4 5 ) - > 9 then  9 - 8 = 1
# Hint: ( 7 4 ) -> 3 then ( 3 6 ) - > 2.0 then  2.0 - 1 = 1
# Hint: ( 7 7 ) -> 0 then ( 0 4 ) - > 0 then  0 + 1 = 1
# Sorry, no way to make 1
# Hint: ( 1 7 ) -> -6 and ( 4 9 ) - > -5 then  -5 - -6 = 1
# Hint: ( 1 7 ) -> -6 and ( 4 10 ) - > -6 then  -6 / -6 = 1
# Hint: ( 1 7 ) -> 6 and ( 5 1 ) - > 6 then  6 / 6 = 1
# Hint: ( 1 7 ) -> 8 and ( 5 2 ) - > 7 then  8 - 7 = 1
# Hint: ( 1 7 ) -> 8 and ( 5 3 ) - > 8 then  8 / 8 = 1
# Hint: ( 1 7 ) -> 8 and ( 5 4 ) - > 9 then  9 - 8 = 1
# Hint: ( 5 5 ) -> 0 then ( 0 7 ) - > 0 then  0 + 1 = 1
# Hint: ( 7 5 ) -> 12 then ( 12 6 ) - > 2.0 then  2.0 - 1 = 1
# Hint: ( 7 7 ) -> 0 then ( 0 5 ) - > 0 then  0 + 1 = 1
# Sorry, no way to make 1
# Hint: ( 5 9 ) -> 14 then ( 14 7 ) - > 2.0 then  2.0 - 1 = 1
# Hint: ( 1 7 ) -> -6 and ( 5 10 ) - > -5 then  -5 - -6 = 1
# Hint: ( 1 7 ) -> 8 and ( 6 1 ) - > 7 then  8 - 7 = 1
# Hint: ( 1 7 ) -> 8 and ( 6 2 ) - > 8 then  8 / 8 = 1
# Hint: ( 1 7 ) -> 8 and ( 6 3 ) - > 9 then  9 - 8 = 1
# Hint: ( 7 4 ) -> 3 then ( 3 6 ) - > 2.0 then  2.0 - 1 = 1
# Hint: ( 7 5 ) -> 12 then ( 12 6 ) - > 2.0 then  2.0 - 1 = 1
# Hint: ( 1 6 ) -> 0.16666666666666666 and ( 7 6 ) - > 1.1666666666666667 then  1.1666666666666667 - 0.16666666666666666 = 1
# Hint: ( 1 7 ) -> 0.14285714285714285 and ( 6 7 ) - > 0.8571428571428571 then  0.14285714285714285 + 0.8571428571428571 = 1
# Hint: ( 6 8 ) -> 14 then ( 14 7 ) - > 2.0 then  2.0 - 1 = 1
# Sorry, no way to make 1
# Hint: ( 7 10 ) -> 3 then ( 3 6 ) - > 2.0 then  2.0 - 1 = 1
# Hint: ( 1 7 ) -> 8 and ( 7 1 ) - > 8 then  8 / 8 = 1
# Hint: ( 1 7 ) -> 8 and ( 7 2 ) - > 9 then  9 - 8 = 1
# Hint: ( 1 3 ) -> 2 and ( 7 7 ) - > 1.0 then  2 - 1.0 = 1
# Hint: ( 7 7 ) -> 0 then ( 0 4 ) - > 0 then  0 + 1 = 1
# Hint: ( 7 7 ) -> 0 then ( 0 5 ) - > 0 then  0 + 1 = 1
# Hint: ( 1 7 ) -> 0.14285714285714285 and ( 7 6 ) - > 0.8571428571428571 then  0.14285714285714285 + 0.8571428571428571 = 1
# Hint: ( 7 7 ) -> 14 then ( 14 7 ) - > 2.0 then  2.0 - 1 = 1
# Hint: ( 1 7 ) -> 0.14285714285714285 and ( 7 8 ) - > 1.1428571428571428 then  1.1428571428571428 - 0.14285714285714285 = 1
# Hint: ( 7 7 ) -> 0 then ( 0 9 ) - > 0 then  0 + 1 = 1
# Hint: ( 7 7 ) -> 0 then ( 0 10 ) - > 0 then  0 + 1 = 1
# Hint: ( 1 7 ) -> 8 and ( 8 1 ) - > 9 then  9 - 8 = 1
# Hint: ( 1 7 ) -> -6 and ( 8 2 ) - > -6 then  -6 / -6 = 1
# Hint: ( 1 7 ) -> -6 and ( 8 3 ) - > -5 then  -5 - -6 = 1
# Sorry, no way to make 1
# Sorry, no way to make 1
# Hint: ( 8 6 ) -> 14 then ( 14 7 ) - > 2.0 then  2.0 - 1 = 1
# Hint: ( 1 7 ) -> 0.14285714285714285 and ( 8 7 ) - > 1.1428571428571428 then  1.1428571428571428 - 0.14285714285714285 = 1
# Hint: ( 1 8 ) -> 0.125 and ( 7 8 ) - > 0.875 then  0.125 + 0.875 = 1
# Hint: ( 7 9 ) -> 16 then ( 16 8 ) - > 2.0 then  2.0 - 1 = 1
# Sorry, no way to make 1
# Hint: ( 1 7 ) -> 8 and ( 9 1 ) - > 8 then  8 / 8 = 1
# Hint: ( 1 7 ) -> 8 and ( 9 2 ) - > 7 then  8 - 7 = 1
# Hint: ( 1 7 ) -> -6 and ( 9 3 ) - > -6 then  -6 / -6 = 1
# Hint: ( 1 7 ) -> -6 and ( 9 4 ) - > -5 then  -5 - -6 = 1
# Hint: ( 9 5 ) -> 14 then ( 14 7 ) - > 2.0 then  2.0 - 1 = 1
# Sorry, no way to make 1
# Hint: ( 7 7 ) -> 0 then ( 0 9 ) - > 0 then  0 + 1 = 1
# Hint: ( 7 9 ) -> 16 then ( 16 8 ) - > 2.0 then  2.0 - 1 = 1
# Hint: ( 9 9 ) -> 0 then ( 0 7 ) - > 0 then  0 + 1 = 1
# Sorry, no way to make 1
# Hint: ( 1 7 ) -> 8 and ( 10 1 ) - > 9 then  9 - 8 = 1
# Hint: ( 1 7 ) -> 8 and ( 10 2 ) - > 8 then  8 / 8 = 1
# Hint: ( 1 7 ) -> 8 and ( 10 3 ) - > 7 then  8 - 7 = 1
# Hint: ( 1 7 ) -> -6 and ( 10 4 ) - > -6 then  -6 / -6 = 1
# Hint: ( 1 7 ) -> -6 and ( 10 5 ) - > -5 then  -5 - -6 = 1
# Hint: ( 7 10 ) -> 3 then ( 3 6 ) - > 2.0 then  2.0 - 1 = 1
# Hint: ( 7 7 ) -> 0 then ( 0 10 ) - > 0 then  0 + 1 = 1
# Sorry, no way to make 1
# Sorry, no way to make 1
# Hint: ( 10 10 ) -> 0 then ( 0 7 ) - > 0 then  0 + 1 = 1
# Hint: ( 1 1 ) -> 0 then ( 0 8 ) - > 0 then  0 + 1 = 1
# Sorry, no way to make 1
# Hint: ( 1 1 ) -> 2 then ( 2 8 ) - > 4.0 then  4.0 - 3 = 1
# Hint: ( 1 1 ) -> 2 and ( 8 4 ) - > 2.0 then  2 / 2.0 = 1
# Hint: ( 1 8 ) -> 7 and ( 1 5 ) - > 6 then  7 - 6 = 1
# Hint: ( 1 8 ) -> 7 and ( 1 6 ) - > 7 then  7 / 7 = 1
# Hint: ( 1 8 ) -> 9 and ( 1 7 ) - > 8 then  9 - 8 = 1
# Hint: ( 1 8 ) -> 9 and ( 1 8 ) - > 9 then  9 / 9 = 1
# Hint: ( 1 8 ) -> 9 and ( 1 9 ) - > 10 then  10 - 9 = 1
# Hint: ( 1 8 ) -> 9 and ( 1 10 ) - > 9 then  9 / 9 = 1
# Sorry, no way to make 1
# Hint: ( 1 2 ) -> 3 and ( 8 2 ) - > 4.0 then  4.0 - 3 = 1
# Hint: ( 1 8 ) -> 7 and ( 2 3 ) - > 6 then  7 - 6 = 1
# Hint: ( 1 8 ) -> 9 and ( 2 4 ) - > 8 then  9 - 8 = 1
# Hint: ( 1 8 ) -> 9 and ( 2 5 ) - > 10 then  10 - 9 = 1
# Hint: ( 1 8 ) -> 9 and ( 2 6 ) - > 8 then  9 - 8 = 1
# Hint: ( 1 8 ) -> 9 and ( 2 7 ) - > 9 then  9 / 9 = 1
# Hint: ( 1 8 ) -> 9 and ( 2 8 ) - > 10 then  10 - 9 = 1
# Hint: ( 1 8 ) -> -7 and ( 2 9 ) - > -7 then  -7 / -7 = 1
# Hint: ( 1 8 ) -> 9 and ( 2 10 ) - > -8 then  9 + -8 = 1
# Hint: ( 1 3 ) -> 4 then ( 4 8 ) - > 2.0 then  2.0 - 1 = 1
# Hint: ( 1 8 ) -> 7 and ( 3 2 ) - > 6 then  7 - 6 = 1
# Hint: ( 1 8 ) -> 9 and ( 3 3 ) - > 9 then  9 / 9 = 1
# Hint: ( 1 8 ) -> 7 and ( 3 4 ) - > 7 then  7 / 7 = 1
# Hint: ( 1 8 ) -> 9 and ( 3 5 ) - > 8 then  9 - 8 = 1
# Hint: ( 1 8 ) -> 9 and ( 3 6 ) - > 9 then  9 / 9 = 1
# Hint: ( 1 8 ) -> 9 and ( 3 7 ) - > 10 then  10 - 9 = 1
# Hint: ( 1 3 ) -> 2 and ( 8 8 ) - > 1.0 then  2 - 1.0 = 1
# Hint: ( 1 8 ) -> -7 and ( 3 9 ) - > -6 then  -6 - -7 = 1
# Hint: ( 1 8 ) -> -7 and ( 3 10 ) - > -7 then  -7 / -7 = 1
# Hint: ( 1 1 ) -> 2 and ( 8 4 ) - > 2.0 then  2 / 2.0 = 1
# Hint: ( 1 8 ) -> 9 and ( 4 2 ) - > 8 then  9 - 8 = 1
# Hint: ( 1 8 ) -> 7 and ( 4 3 ) - > 7 then  7 / 7 = 1
# Hint: ( 1 8 ) -> 9 and ( 4 4 ) - > 8 then  9 - 8 = 1
# Hint: ( 1 8 ) -> 9 and ( 4 5 ) - > 9 then  9 / 9 = 1
# Hint: ( 1 8 ) -> 9 and ( 4 6 ) - > 10 then  10 - 9 = 1
# Sorry, no way to make 1
# Hint: ( 8 4 ) -> 4 then ( 4 8 ) - > 2.0 then  2.0 - 1 = 1
# Sorry, no way to make 1
# Hint: ( 1 8 ) -> -7 and ( 4 10 ) - > -6 then  -6 - -7 = 1
# Hint: ( 1 8 ) -> 7 and ( 5 1 ) - > 6 then  7 - 6 = 1
# Hint: ( 1 8 ) -> 9 and ( 5 2 ) - > 10 then  10 - 9 = 1
# Hint: ( 1 8 ) -> 9 and ( 5 3 ) - > 8 then  9 - 8 = 1
# Hint: ( 1 8 ) -> 9 and ( 5 4 ) - > 9 then  9 / 9 = 1
# Hint: ( 1 8 ) -> 9 and ( 5 5 ) - > 10 then  10 - 9 = 1
# Hint: ( 8 5 ) -> 3 then ( 3 6 ) - > 2.0 then  2.0 - 1 = 1
# Sorry, no way to make 1
# Hint: ( 8 8 ) -> 0 then ( 0 5 ) - > 0 then  0 + 1 = 1
# Hint: ( 5 9 ) -> 4 then ( 4 8 ) - > 2.0 then  2.0 - 1 = 1
# Hint: ( 1 5 ) -> 0.2 and ( 8 10 ) - > 0.8 then  0.2 + 0.8 = 1
# Hint: ( 1 8 ) -> 7 and ( 6 1 ) - > 7 then  7 / 7 = 1
# Hint: ( 1 8 ) -> 9 and ( 6 2 ) - > 8 then  9 - 8 = 1
# Hint: ( 1 8 ) -> 9 and ( 6 3 ) - > 9 then  9 / 9 = 1
# Hint: ( 1 8 ) -> 9 and ( 6 4 ) - > 10 then  10 - 9 = 1
# Hint: ( 8 5 ) -> 3 then ( 3 6 ) - > 2.0 then  2.0 - 1 = 1
# Hint: ( 6 6 ) -> 0 then ( 0 8 ) - > 0 then  0 + 1 = 1
# Hint: ( 8 6 ) -> 14 then ( 14 7 ) - > 2.0 then  2.0 - 1 = 1
# Hint: ( 8 8 ) -> 0 then ( 0 6 ) - > 0 then  0 + 1 = 1
# Sorry, no way to make 1
# Hint: ( 6 10 ) -> 16 then ( 16 8 ) - > 2.0 then  2.0 - 1 = 1
# Hint: ( 1 8 ) -> 9 and ( 7 1 ) - > 8 then  9 - 8 = 1
# Hint: ( 1 8 ) -> 9 and ( 7 2 ) - > 9 then  9 / 9 = 1
# Hint: ( 1 8 ) -> 9 and ( 7 3 ) - > 10 then  10 - 9 = 1
# Sorry, no way to make 1
# Sorry, no way to make 1
# Hint: ( 8 6 ) -> 14 then ( 14 7 ) - > 2.0 then  2.0 - 1 = 1
# Hint: ( 1 7 ) -> 0.14285714285714285 and ( 8 7 ) - > 1.1428571428571428 then  1.1428571428571428 - 0.14285714285714285 = 1
# Hint: ( 1 8 ) -> 0.125 and ( 7 8 ) - > 0.875 then  0.125 + 0.875 = 1
# Hint: ( 7 9 ) -> 16 then ( 16 8 ) - > 2.0 then  2.0 - 1 = 1
# Sorry, no way to make 1
# Hint: ( 1 8 ) -> 9 and ( 8 1 ) - > 9 then  9 / 9 = 1
# Hint: ( 1 8 ) -> 9 and ( 8 2 ) - > 10 then  10 - 9 = 1
# Hint: ( 1 3 ) -> 2 and ( 8 8 ) - > 1.0 then  2 - 1.0 = 1
# Hint: ( 8 8 ) -> 0 then ( 0 4 ) - > 0 then  0 + 1 = 1
# Hint: ( 8 8 ) -> 0 then ( 0 5 ) - > 0 then  0 + 1 = 1
# Hint: ( 8 8 ) -> 0 then ( 0 6 ) - > 0 then  0 + 1 = 1
# Hint: ( 1 8 ) -> 0.125 and ( 8 7 ) - > 0.875 then  0.125 + 0.875 = 1
# Hint: ( 8 8 ) -> 16 then ( 16 8 ) - > 2.0 then  2.0 - 1 = 1
# Hint: ( 1 8 ) -> 0.125 and ( 8 9 ) - > 1.125 then  1.125 - 0.125 = 1
# Hint: ( 8 8 ) -> 0 then ( 0 10 ) - > 0 then  0 + 1 = 1
# Hint: ( 1 8 ) -> 9 and ( 9 1 ) - > 10 then  10 - 9 = 1
# Hint: ( 1 8 ) -> -7 and ( 9 2 ) - > -7 then  -7 / -7 = 1
# Hint: ( 1 8 ) -> -7 and ( 9 3 ) - > -6 then  -6 - -7 = 1
# Sorry, no way to make 1
# Hint: ( 9 5 ) -> 4 then ( 4 8 ) - > 2.0 then  2.0 - 1 = 1
# Sorry, no way to make 1
# Hint: ( 9 7 ) -> 16 then ( 16 8 ) - > 2.0 then  2.0 - 1 = 1
# Hint: ( 1 8 ) -> 0.125 and ( 9 8 ) - > 1.125 then  1.125 - 0.125 = 1
# Hint: ( 1 9 ) -> 0.1111111111111111 and ( 8 9 ) - > 0.8888888888888888 then  0.1111111111111111 + 0.8888888888888888 = 1
# Hint: ( 8 10 ) -> 18 then ( 18 9 ) - > 2.0 then  2.0 - 1 = 1
# Hint: ( 1 8 ) -> 9 and ( 10 1 ) - > 9 then  9 / 9 = 1
# Hint: ( 1 8 ) -> 9 and ( 10 2 ) - > 8 then  9 - 8 = 1
# Hint: ( 1 8 ) -> -7 and ( 10 3 ) - > -7 then  -7 / -7 = 1
# Hint: ( 1 8 ) -> -7 and ( 10 4 ) - > -6 then  -6 - -7 = 1
# Hint: ( 1 5 ) -> 0.2 and ( 8 10 ) - > 0.8 then  0.2 + 0.8 = 1
# Hint: ( 10 6 ) -> 16 then ( 16 8 ) - > 2.0 then  2.0 - 1 = 1
# Sorry, no way to make 1
# Hint: ( 8 8 ) -> 0 then ( 0 10 ) - > 0 then  0 + 1 = 1
# Hint: ( 8 10 ) -> 18 then ( 18 9 ) - > 2.0 then  2.0 - 1 = 1
# Hint: ( 10 10 ) -> 0 then ( 0 8 ) - > 0 then  0 + 1 = 1
# Hint: ( 1 1 ) -> 0 then ( 0 9 ) - > 0 then  0 + 1 = 1
# Sorry, no way to make 1
# Hint: ( 1 1 ) -> 2 and ( 9 3 ) - > 3.0 then  3.0 - 2 = 1
# Hint: ( 1 9 ) -> 8 then ( 8 4 ) - > 2.0 then  2.0 - 1 = 1
# Hint: ( 1 9 ) -> 10 then ( 10 5 ) - > 2.0 then  2.0 - 1 = 1
# Hint: ( 1 9 ) -> 8 and ( 1 6 ) - > 7 then  8 - 7 = 1
# Hint: ( 1 9 ) -> 8 and ( 1 7 ) - > 8 then  8 / 8 = 1
# Hint: ( 1 9 ) -> 10 and ( 1 8 ) - > 9 then  10 - 9 = 1
# Hint: ( 1 9 ) -> 10 and ( 1 9 ) - > 10 then  10 / 10 = 1
# Hint: ( 1 9 ) -> 10 and ( 1 10 ) - > 11 then  11 - 10 = 1
# Sorry, no way to make 1
# Hint: ( 1 2 ) -> 3 then ( 3 9 ) - > 3.0 then  3.0 - 2 = 1
# Hint: ( 1 2 ) -> 3 and ( 9 3 ) - > 3.0 then  3 / 3.0 = 1
# Hint: ( 1 9 ) -> 8 and ( 2 4 ) - > 8 then  8 / 8 = 1
# Hint: ( 1 9 ) -> 10 and ( 2 5 ) - > 10 then  10 / 10 = 1
# Hint: ( 1 9 ) -> 8 and ( 2 6 ) - > 8 then  8 / 8 = 1
# Hint: ( 1 9 ) -> 10 and ( 2 7 ) - > 9 then  10 - 9 = 1
# Hint: ( 1 9 ) -> 10 and ( 2 8 ) - > 10 then  10 / 10 = 1
# Hint: ( 1 9 ) -> 10 and ( 2 9 ) - > 11 then  11 - 10 = 1
# Hint: ( 1 9 ) -> -8 and ( 2 10 ) - > -8 then  -8 / -8 = 1
# Hint: ( 1 1 ) -> 2 and ( 9 3 ) - > 3.0 then  3.0 - 2 = 1
# Hint: ( 1 2 ) -> 3 and ( 9 3 ) - > 3.0 then  3 / 3.0 = 1
# Hint: ( 1 9 ) -> 10 and ( 3 3 ) - > 9 then  10 - 9 = 1
# Hint: ( 1 9 ) -> 8 and ( 3 4 ) - > 7 then  8 - 7 = 1
# Hint: ( 1 9 ) -> 8 and ( 3 5 ) - > 8 then  8 / 8 = 1
# Hint: ( 1 9 ) -> 10 and ( 3 6 ) - > 9 then  10 - 9 = 1
# Hint: ( 1 9 ) -> 10 and ( 3 7 ) - > 10 then  10 / 10 = 1
# Hint: ( 1 9 ) -> 10 and ( 3 8 ) - > 11 then  11 - 10 = 1
# Hint: ( 1 3 ) -> 2 and ( 9 9 ) - > 1.0 then  2 - 1.0 = 1
# Hint: ( 1 9 ) -> -8 and ( 3 10 ) - > -7 then  -7 - -8 = 1
# Hint: ( 1 9 ) -> 8 then ( 8 4 ) - > 2.0 then  2.0 - 1 = 1
# Hint: ( 1 9 ) -> 8 and ( 4 2 ) - > 8 then  8 / 8 = 1
# Hint: ( 1 9 ) -> 8 and ( 4 3 ) - > 7 then  8 - 7 = 1
# Hint: ( 1 9 ) -> 8 and ( 4 4 ) - > 8 then  8 / 8 = 1
# Hint: ( 1 9 ) -> 10 and ( 4 5 ) - > 9 then  10 - 9 = 1
# Hint: ( 1 9 ) -> 10 and ( 4 6 ) - > 10 then  10 / 10 = 1
# Hint: ( 1 9 ) -> 10 and ( 4 7 ) - > 11 then  11 - 10 = 1
# Sorry, no way to make 1
# Hint: ( 9 9 ) -> 0 then ( 0 4 ) - > 0 then  0 + 1 = 1
# Hint: ( 9 4 ) -> 5 then ( 5 10 ) - > 2.0 then  2.0 - 1 = 1
# Hint: ( 1 9 ) -> 10 then ( 10 5 ) - > 2.0 then  2.0 - 1 = 1
# Hint: ( 1 9 ) -> 10 and ( 5 2 ) - > 10 then  10 / 10 = 1
# Hint: ( 1 9 ) -> 8 and ( 5 3 ) - > 8 then  8 / 8 = 1
# Hint: ( 1 9 ) -> 10 and ( 5 4 ) - > 9 then  10 - 9 = 1
# Hint: ( 1 9 ) -> 10 and ( 5 5 ) - > 10 then  10 / 10 = 1
# Hint: ( 1 9 ) -> 10 and ( 5 6 ) - > 11 then  11 - 10 = 1
# Hint: ( 9 5 ) -> 14 then ( 14 7 ) - > 2.0 then  2.0 - 1 = 1
# Hint: ( 9 5 ) -> 4 then ( 4 8 ) - > 2.0 then  2.0 - 1 = 1
# Hint: ( 9 9 ) -> 0 then ( 0 5 ) - > 0 then  0 + 1 = 1
# Sorry, no way to make 1
# Hint: ( 1 9 ) -> 8 and ( 6 1 ) - > 7 then  8 - 7 = 1
# Hint: ( 1 9 ) -> 8 and ( 6 2 ) - > 8 then  8 / 8 = 1
# Hint: ( 1 9 ) -> 10 and ( 6 3 ) - > 9 then  10 - 9 = 1
# Hint: ( 1 9 ) -> 10 and ( 6 4 ) - > 10 then  10 / 10 = 1
# Hint: ( 1 9 ) -> 10 and ( 6 5 ) - > 11 then  11 - 10 = 1
# Hint: ( 9 6 ) -> 3 then ( 3 6 ) - > 2.0 then  2.0 - 1 = 1
# Sorry, no way to make 1
# Sorry, no way to make 1
# Hint: ( 9 9 ) -> 0 then ( 0 6 ) - > 0 then  0 + 1 = 1
# Sorry, no way to make 1
# Hint: ( 1 9 ) -> 8 and ( 7 1 ) - > 8 then  8 / 8 = 1
# Hint: ( 1 9 ) -> 10 and ( 7 2 ) - > 9 then  10 - 9 = 1
# Hint: ( 1 9 ) -> 10 and ( 7 3 ) - > 10 then  10 / 10 = 1
# Hint: ( 1 9 ) -> 10 and ( 7 4 ) - > 11 then  11 - 10 = 1
# Hint: ( 9 5 ) -> 14 then ( 14 7 ) - > 2.0 then  2.0 - 1 = 1
# Sorry, no way to make 1
# Hint: ( 7 7 ) -> 0 then ( 0 9 ) - > 0 then  0 + 1 = 1
# Hint: ( 9 7 ) -> 16 then ( 16 8 ) - > 2.0 then  2.0 - 1 = 1
# Hint: ( 9 9 ) -> 0 then ( 0 7 ) - > 0 then  0 + 1 = 1
# Sorry, no way to make 1
# Hint: ( 1 9 ) -> 10 and ( 8 1 ) - > 9 then  10 - 9 = 1
# Hint: ( 1 9 ) -> 10 and ( 8 2 ) - > 10 then  10 / 10 = 1
# Hint: ( 1 9 ) -> 10 and ( 8 3 ) - > 11 then  11 - 10 = 1
# Sorry, no way to make 1
# Hint: ( 9 5 ) -> 4 then ( 4 8 ) - > 2.0 then  2.0 - 1 = 1
# Sorry, no way to make 1
# Hint: ( 9 7 ) -> 16 then ( 16 8 ) - > 2.0 then  2.0 - 1 = 1
# Hint: ( 1 8 ) -> 0.125 and ( 9 8 ) - > 1.125 then  1.125 - 0.125 = 1
# Hint: ( 1 9 ) -> 0.1111111111111111 and ( 8 9 ) - > 0.8888888888888888 then  0.1111111111111111 + 0.8888888888888888 = 1
# Hint: ( 8 10 ) -> 18 then ( 18 9 ) - > 2.0 then  2.0 - 1 = 1
# Hint: ( 1 9 ) -> 10 and ( 9 1 ) - > 10 then  10 / 10 = 1
# Hint: ( 1 9 ) -> 10 and ( 9 2 ) - > 11 then  11 - 10 = 1
# Hint: ( 1 3 ) -> 2 and ( 9 9 ) - > 1.0 then  2 - 1.0 = 1
# Hint: ( 9 9 ) -> 0 then ( 0 4 ) - > 0 then  0 + 1 = 1
# ...
# Hint: ( 3 13 ) -> 16 and ( 2 13 ) - > 15 then  16 - 15 = 1
# Hint: ( 3 3 ) -> 0 then ( 0 13 ) - > 0 then  0 + 1 = 1
# Hint: ( 3 3 ) -> 6 then ( 6 2 ) - > 12 then  13 - 12 = 1
# Hint: ( 3 13 ) -> 10 and ( 3 3 ) - > 9 then  10 - 9 = 1
# Hint: ( 3 3 ) -> 9 and ( 13 4 ) - > 9 then  9 / 9 = 1
# Hint: ( 3 13 ) -> 16 and ( 3 5 ) - > 15 then  16 - 15 = 1
# Hint: ( 3 13 ) -> 10 and ( 3 6 ) - > 9 then  10 - 9 = 1
# Hint: ( 3 13 ) -> 10 and ( 3 7 ) - > 10 then  10 / 10 = 1
# Hint: ( 3 13 ) -> -10 and ( 3 8 ) - > 11 then  -10 + 11 = 1
# Sorry, no way to make 1
# Hint: ( 3 13 ) -> 4.333333333333333 and ( 3 10 ) - > 3.3333333333333335 then  4.333333333333333 - 3.3333333333333335 = 1
# Hint: ( 3 3 ) -> 1.0 and ( 13 11 ) - > 2 then  2 - 1.0 = 1
# Hint: ( 3 13 ) -> 16 and ( 3 12 ) - > 15 then  16 - 15 = 1
# Hint: ( 3 13 ) -> 16 and ( 3 13 ) - > 16 then  16 / 16 = 1
# Hint: ( 3 4 ) -> 12 and ( 13 1 ) - > 12 then  12 / 12 = 1
# Hint: ( 3 4 ) -> 12 and ( 13 2 ) - > 11 then  12 - 11 = 1
# Hint: ( 3 3 ) -> 9 and ( 13 4 ) - > 9 then  9 / 9 = 1
# Hint: ( 3 13 ) -> 16 and ( 4 4 ) - > 16 then  16 / 16 = 1
# Hint: ( 3 13 ) -> 10 and ( 4 5 ) - > 9 then  10 - 9 = 1
# Hint: ( 3 13 ) -> 10 and ( 4 6 ) - > 10 then  10 / 10 = 1
# Hint: ( 3 13 ) -> -10 and ( 4 7 ) - > 11 then  -10 + 11 = 1
# Hint: ( 4 8 ) -> -4 then ( -4 3 ) - > -12 then  -12 + 13 = 1
# Hint: ( 3 4 ) -> 0.75 then ( 0.75 9 ) - > 12.0 then  13 - 12.0 = 1
# Hint: ( 3 13 ) -> 39 and ( 4 10 ) - > 40 then  40 - 39 = 1
# Hint: ( 3 13 ) -> 16 and ( 4 11 ) - > 15 then  16 - 15 = 1
# Hint: ( 3 13 ) -> 16 and ( 4 12 ) - > 16 then  16 / 16 = 1
# Hint: ( 3 13 ) -> 16 and ( 4 13 ) - > 17 then  17 - 16 = 1
# Hint: ( 3 5 ) -> 15 and ( 13 1 ) - > 14 then  15 - 14 = 1
# Hint: ( 3 13 ) -> 10 and ( 5 2 ) - > 10 then  10 / 10 = 1
# Hint: ( 3 13 ) -> 16 and ( 5 3 ) - > 15 then  16 - 15 = 1
# Hint: ( 3 13 ) -> 10 and ( 5 4 ) - > 9 then  10 - 9 = 1
# Hint: ( 3 13 ) -> 10 and ( 5 5 ) - > 10 then  10 / 10 = 1
# Hint: ( 3 13 ) -> -10 and ( 5 6 ) - > 11 then  -10 + 11 = 1
# Hint: ( 3 5 ) -> 2 then ( 2 7 ) - > 14 then  14 - 13 = 1
# Hint: ( 3 13 ) -> 39 and ( 5 8 ) - > 40 then  40 - 39 = 1
# Hint: ( 13 5 ) -> 18 then ( 18 9 ) - > 2.0 then  3 - 2.0 = 1
# Hint: ( 3 13 ) -> 16 and ( 5 10 ) - > 15 then  16 - 15 = 1
# Hint: ( 3 13 ) -> 16 and ( 5 11 ) - > 16 then  16 / 16 = 1
# Hint: ( 3 13 ) -> 16 and ( 5 12 ) - > 17 then  17 - 16 = 1
# Hint: ( 3 5 ) -> 2 and ( 13 13 ) - > 1.0 then  2 - 1.0 = 1
# Hint: ( 3 1 ) -> 2 then ( 2 6 ) - > 12 then  13 - 12 = 1
# Hint: ( 3 2 ) -> 6 and ( 13 6 ) - > 7 then  7 - 6 = 1
# Hint: ( 3 13 ) -> 10 and ( 6 3 ) - > 9 then  10 - 9 = 1
# Hint: ( 3 13 ) -> 10 and ( 6 4 ) - > 10 then  10 / 10 = 1
# Hint: ( 3 13 ) -> -10 and ( 6 5 ) - > 11 then  -10 + 11 = 1
# Hint: ( 3 6 ) -> 18 and ( 13 6 ) - > 19 then  19 - 18 = 1
# Hint: ( 3 6 ) -> 0.5 then ( 0.5 7 ) - > 14.0 then  14.0 - 13 = 1
# Hint: ( 13 8 ) -> 21 then ( 21 3 ) - > 7.0 then  7.0 - 6 = 1
# Hint: ( 3 13 ) -> 16 and ( 6 9 ) - > 15 then  16 - 15 = 1
# Hint: ( 3 13 ) -> 16 and ( 6 10 ) - > 16 then  16 / 16 = 1
# Hint: ( 3 13 ) -> 16 and ( 6 11 ) - > 17 then  17 - 16 = 1
# Hint: ( 3 6 ) -> 2.0 and ( 13 12 ) - > 1 then  2.0 - 1 = 1
# Hint: ( 3 6 ) -> 2.0 and ( 13 13 ) - > 1.0 then  2.0 - 1.0 = 1
# Hint: ( 3 1 ) -> 2 then ( 2 7 ) - > 14 then  14 - 13 = 1
# Hint: ( 3 13 ) -> 10 and ( 7 2 ) - > 9 then  10 - 9 = 1
# Hint: ( 3 13 ) -> 10 and ( 7 3 ) - > 10 then  10 / 10 = 1
# Hint: ( 3 13 ) -> -10 and ( 7 4 ) - > 11 then  -10 + 11 = 1
# Hint: ( 3 5 ) -> 2 then ( 2 7 ) - > 14 then  14 - 13 = 1
# Hint: ( 3 7 ) -> 0.42857142857142855 then ( 0.42857142857142855 6 ) - > 14.0 then  14.0 - 13 = 1
# Hint: ( 3 7 ) -> 21 and ( 13 7 ) - > 20 then  21 - 20 = 1
# Hint: ( 3 13 ) -> 16 and ( 7 8 ) - > 15 then  16 - 15 = 1
# Hint: ( 3 13 ) -> 16 and ( 7 9 ) - > 16 then  16 / 16 = 1
# Hint: ( 3 13 ) -> 16 and ( 7 10 ) - > 17 then  17 - 16 = 1
# Hint: ( 13 11 ) -> 24 then ( 24 3 ) - > 8.0 then  8.0 - 7 = 1
# Hint: ( 13 7 ) -> 6 then ( 6 12 ) - > 2.0 then  3 - 2.0 = 1
# Sorry, no way to make 1
# Hint: ( 3 13 ) -> 10 and ( 8 1 ) - > 9 then  10 - 9 = 1
# Hint: ( 3 13 ) -> 16 and ( 8 2 ) - > 16 then  16 / 16 = 1
# Hint: ( 3 13 ) -> -10 and ( 8 3 ) - > 11 then  -10 + 11 = 1
# Hint: ( 8 4 ) -> 4 then ( 4 3 ) - > 12 then  13 - 12 = 1
# Hint: ( 3 13 ) -> 39 and ( 8 5 ) - > 40 then  40 - 39 = 1
# Hint: ( 13 8 ) -> 21 then ( 21 3 ) - > 7.0 then  7.0 - 6 = 1
# Hint: ( 3 13 ) -> 16 and ( 8 7 ) - > 15 then  16 - 15 = 1
# Hint: ( 3 13 ) -> 16 and ( 8 8 ) - > 16 then  16 / 16 = 1
# Hint: ( 3 13 ) -> 16 and ( 8 9 ) - > 17 then  17 - 16 = 1
# Hint: ( 3 8 ) -> 24 and ( 13 10 ) - > 23 then  24 - 23 = 1
# Hint: ( 3 8 ) -> 24 and ( 13 11 ) - > 24 then  24 / 24 = 1
# Hint: ( 3 8 ) -> 24 and ( 13 12 ) - > 25 then  25 - 24 = 1
# Sorry, no way to make 1
# Hint: ( 3 13 ) -> 10 and ( 9 1 ) - > 10 then  10 / 10 = 1
# Hint: ( 3 13 ) -> -10 and ( 9 2 ) - > 11 then  -10 + 11 = 1
# Sorry, no way to make 1
# Hint: ( 3 9 ) -> 0.3333333333333333 then ( 0.3333333333333333 4 ) - > 12.0 then  13 - 12.0 = 1
# Hint: ( 13 5 ) -> 18 then ( 18 9 ) - > 2.0 then  3 - 2.0 = 1
# Hint: ( 3 13 ) -> 16 and ( 9 6 ) - > 15 then  16 - 15 = 1
# Hint: ( 3 13 ) -> 16 and ( 9 7 ) - > 16 then  16 / 16 = 1
# Hint: ( 3 13 ) -> 16 and ( 9 8 ) - > 17 then  17 - 16 = 1
# Hint: ( 3 9 ) -> 3.0 and ( 13 9 ) - > 4 then  4 - 3.0 = 1
# Hint: ( 3 9 ) -> 0.3333333333333333 and ( 13 10 ) - > 3 then  0.3333333333333333 * 3 = 1
# Hint: ( 3 9 ) -> 3.0 and ( 13 11 ) - > 2 then  3.0 - 2 = 1
# Hint: ( 3 12 ) -> 0.25 and ( 13 9 ) - > 4 then  0.25 * 4 = 1
# Hint: ( 3 9 ) -> 27 and ( 13 13 ) - > 26 then  27 - 26 = 1
# Hint: ( 3 13 ) -> -10 and ( 10 1 ) - > 11 then  -10 + 11 = 1
# Hint: ( 3 13 ) -> -10 then ( -10 10 ) - > -1.0 then  -1.0 + 2 = 1
# Hint: ( 3 13 ) -> 4.333333333333333 and ( 10 3 ) - > 3.3333333333333335 then  4.333333333333333 - 3.3333333333333335 = 1
# Hint: ( 3 13 ) -> 39 and ( 10 4 ) - > 40 then  40 - 39 = 1
# Hint: ( 3 13 ) -> 16 and ( 10 5 ) - > 15 then  16 - 15 = 1
# Hint: ( 3 13 ) -> 16 and ( 10 6 ) - > 16 then  16 / 16 = 1
# Hint: ( 3 13 ) -> 16 and ( 10 7 ) - > 17 then  17 - 16 = 1
# Hint: ( 3 8 ) -> 24 and ( 13 10 ) - > 23 then  24 - 23 = 1
# Hint: ( 3 9 ) -> 0.3333333333333333 and ( 13 10 ) - > 3 then  0.3333333333333333 * 3 = 1
# Hint: ( 3 10 ) -> 0.3 and ( 13 10 ) - > 1.3 then  1.3 - 0.3 = 1
# Sorry, no way to make 1
# Hint: ( 3 12 ) -> 4.0 and ( 13 10 ) - > 3 then  4.0 - 3 = 1
# Hint: ( 3 13 ) -> 0.23076923076923078 and ( 10 13 ) - > 0.7692307692307693 then  0.23076923076923078 + 0.7692307692307693 = 1
# Hint: ( 3 13 ) -> -10 and ( 11 1 ) - > -10 then  -10 / -10 = 1
# Hint: ( 3 13 ) -> -10 and ( 11 2 ) - > -9 then  -9 - -10 = 1
# Hint: ( 3 3 ) -> 1.0 and ( 13 11 ) - > 2 then  2 - 1.0 = 1
# Hint: ( 3 13 ) -> 16 and ( 11 4 ) - > 15 then  16 - 15 = 1
# Hint: ( 3 13 ) -> 16 and ( 11 5 ) - > 16 then  16 / 16 = 1
# Hint: ( 3 13 ) -> 16 and ( 11 6 ) - > 17 then  17 - 16 = 1
# Hint: ( 13 11 ) -> 24 then ( 24 3 ) - > 8.0 then  8.0 - 7 = 1
# Hint: ( 3 8 ) -> 24 and ( 13 11 ) - > 24 then  24 / 24 = 1
# Hint: ( 3 9 ) -> 3.0 and ( 13 11 ) - > 2 then  3.0 - 2 = 1
# Sorry, no way to make 1
# Sorry, no way to make 1
# Hint: ( 13 11 ) -> 24 then ( 24 12 ) - > 2.0 then  3 - 2.0 = 1
# Sorry, no way to make 1
# Hint: ( 3 13 ) -> -10 and ( 12 1 ) - > 11 then  -10 + 11 = 1
# Hint: ( 3 13 ) -> -10 and ( 12 2 ) - > -10 then  -10 / -10 = 1
# Hint: ( 3 13 ) -> 16 and ( 12 3 ) - > 15 then  16 - 15 = 1
# Hint: ( 3 13 ) -> 16 and ( 12 4 ) - > 16 then  16 / 16 = 1
# Hint: ( 3 13 ) -> 16 and ( 12 5 ) - > 17 then  17 - 16 = 1
# Hint: ( 3 6 ) -> 2.0 and ( 13 12 ) - > 1 then  2.0 - 1 = 1
# Hint: ( 13 7 ) -> 6 then ( 6 12 ) - > 2.0 then  3 - 2.0 = 1
# Hint: ( 3 12 ) -> 4.0 and ( 13 8 ) - > 5 then  5 - 4.0 = 1
# Hint: ( 3 12 ) -> 0.25 and ( 13 9 ) - > 4 then  0.25 * 4 = 1
# Hint: ( 3 12 ) -> 4.0 and ( 13 10 ) - > 3 then  4.0 - 3 = 1
# Hint: ( 13 11 ) -> 24 then ( 24 12 ) - > 2.0 then  3 - 2.0 = 1
# Sorry, no way to make 1
# Sorry, no way to make 1
# Hint: ( 3 1 ) -> 2 and ( 13 13 ) - > 1.0 then  2 - 1.0 = 1
# Hint: ( 3 13 ) -> 16 and ( 13 2 ) - > 15 then  16 - 15 = 1
# Hint: ( 3 13 ) -> 16 and ( 13 3 ) - > 16 then  16 / 16 = 1
# Hint: ( 3 13 ) -> 16 and ( 13 4 ) - > 17 then  17 - 16 = 1
# Hint: ( 3 5 ) -> 2 and ( 13 13 ) - > 1.0 then  2 - 1.0 = 1
# Hint: ( 3 6 ) -> 2.0 and ( 13 13 ) - > 1.0 then  2.0 - 1.0 = 1
# Sorry, no way to make 1
# Sorry, no way to make 1
# Hint: ( 3 9 ) -> 27 and ( 13 13 ) - > 26 then  27 - 26 = 1
# Hint: ( 3 13 ) -> 0.23076923076923078 and ( 13 10 ) - > 0.7692307692307693 then  0.23076923076923078 + 0.7692307692307693 = 1
# Sorry, no way to make 1
# Sorry, no way to make 1
# Hint: ( 13 13 ) -> 26 then ( 26 13 ) - > 2.0 then  3 - 2.0 = 1
# Hint: ( 4 1 ) -> 3 and ( 1 1 ) - > 2 then  3 - 2 = 1
# Hint: ( 4 1 ) -> 3 and ( 1 2 ) - > 3 then  3 / 3 = 1
# Hint: ( 4 1 ) -> 5 and ( 1 3 ) - > 4 then  5 - 4 = 1
# Hint: ( 4 1 ) -> 5 and ( 1 4 ) - > 5 then  5 / 5 = 1
# Hint: ( 4 1 ) -> 5 and ( 1 5 ) - > 6 then  6 - 5 = 1
# Hint: ( 4 1 ) -> 5 and ( 1 6 ) - > 5 then  5 / 5 = 1
# Hint: ( 4 1 ) -> 5 and ( 1 7 ) - > 6 then  6 - 5 = 1
# Hint: ( 4 8 ) -> 0.5 and ( 1 1 ) - > 2 then  0.5 * 2 = 1
# Hint: ( 1 1 ) -> 2 then ( 2 4 ) - > 8 then  9 - 8 = 1
# Hint: ( 4 1 ) -> 5 then ( 5 10 ) - > 2.0 then  2.0 - 1 = 1
# Sorry, no way to make 1
# Hint: ( 4 12 ) -> 3.0 and ( 1 1 ) - > 2 then  3.0 - 2 = 1
# Sorry, no way to make 1
# Hint: ( 4 1 ) -> 3 and ( 2 1 ) - > 3 then  3 / 3 = 1
# Hint: ( 4 1 ) -> 5 and ( 2 2 ) - > 4 then  5 - 4 = 1
# Hint: ( 4 1 ) -> 5 and ( 2 3 ) - > 5 then  5 / 5 = 1
# Hint: ( 4 1 ) -> 5 and ( 2 4 ) - > 6 then  6 - 5 = 1
# Hint: ( 4 1 ) -> 3 and ( 2 5 ) - > 3 then  3 / 3 = 1
# Hint: ( 4 1 ) -> 5 and ( 2 6 ) - > -4 then  5 + -4 = 1
# Hint: ( 4 1 ) -> 5 and ( 2 7 ) - > 5 then  5 / 5 = 1
# Hint: ( 4 1 ) -> 5 and ( 2 8 ) - > 6 then  6 - 5 = 1
# Hint: ( 4 2 ) -> 8 and ( 1 9 ) - > 8 then  8 / 8 = 1
# Hint: ( 4 1 ) -> 5 and ( 2 10 ) - > 0.2 then  5 * 0.2 = 1
# Hint: ( 4 1 ) -> 5 then ( 5 2 ) - > 10 then  11 - 10 = 1
# Hint: ( 4 1 ) -> 5 and ( 2 12 ) - > 6.0 then  6.0 - 5 = 1
# Hint: ( 1 2 ) -> 3 then ( 3 4 ) - > 12 then  13 - 12 = 1
# Hint: ( 4 1 ) -> 5 and ( 3 1 ) - > 4 then  5 - 4 = 1
# Hint: ( 4 1 ) -> 5 and ( 3 2 ) - > 5 then  5 / 5 = 1
# Hint: ( 4 1 ) -> 5 and ( 3 3 ) - > 6 then  6 - 5 = 1
# Hint: ( 4 1 ) -> 0.25 and ( 3 4 ) - > 0.75 then  0.25 + 0.75 = 1
# Hint: ( 4 1 ) -> 3 and ( 3 5 ) - > -2 then  3 + -2 = 1
# Hint: ( 4 1 ) -> 3 and ( 3 6 ) - > 3 then  3 / 3 = 1
# Hint: ( 4 1 ) -> 5 and ( 3 7 ) - > -4 then  5 + -4 = 1
# Hint: ( 4 1 ) -> 5 and ( 3 8 ) - > 5 then  5 / 5 = 1
# Hint: ( 4 1 ) -> 5 and ( 3 9 ) - > 6 then  6 - 5 = 1
# Hint: ( 4 3 ) -> 12 and ( 1 10 ) - > 11 then  12 - 11 = 1
# Hint: ( 4 3 ) -> 12 and ( 1 11 ) - > 12 then  12 / 12 = 1
# Hint: ( 4 1 ) -> 5 and ( 3 12 ) - > 4.0 then  5 - 4.0 = 1
# Hint: ( 4 3 ) -> 12 and ( 1 13 ) - > 12 then  12 / 12 = 1
# Hint: ( 4 1 ) -> 5 and ( 4 1 ) - > 5 then  5 / 5 = 1
# Hint: ( 4 1 ) -> 5 and ( 4 2 ) - > 6 then  6 - 5 = 1
# Hint: ( 4 1 ) -> 0.25 and ( 4 3 ) - > 0.75 then  0.25 + 0.75 = 1
# Hint: ( 4 4 ) -> 8 then ( 8 4 ) - > 2.0 then  2.0 - 1 = 1
# Hint: ( 4 1 ) -> 0.25 and ( 4 5 ) - > 1.25 then  1.25 - 0.25 = 1
# Hint: ( 4 1 ) -> 3 and ( 4 6 ) - > -2 then  3 + -2 = 1
# Hint: ( 4 1 ) -> 3 and ( 4 7 ) - > 3 then  3 / 3 = 1
# Hint: ( 4 1 ) -> 5 and ( 4 8 ) - > -4 then  5 + -4 = 1
# Hint: ( 4 1 ) -> 5 and ( 4 9 ) - > 5 then  5 / 5 = 1
# Hint: ( 4 1 ) -> 5 and ( 4 10 ) - > 6 then  6 - 5 = 1
# Hint: ( 4 1 ) -> 3 then ( 3 4 ) - > 12 then  12 - 11 = 1
# Hint: ( 4 1 ) -> 3 and ( 4 12 ) - > 0.3333333333333333 then  3 * 0.3333333333333333 = 1
# Hint: ( 4 1 ) -> 3 then ( 3 4 ) - > 12 then  13 - 12 = 1
# Hint: ( 4 1 ) -> 5 and ( 5 1 ) - > 6 then  6 - 5 = 1
# Hint: ( 4 1 ) -> 3 and ( 5 2 ) - > 3 then  3 / 3 = 1
# Hint: ( 4 1 ) -> 3 and ( 5 3 ) - > 2 then  3 - 2 = 1
# Hint: ( 4 1 ) -> 0.25 and ( 5 4 ) - > 1.25 then  1.25 - 0.25 = 1
# Hint: ( 4 5 ) -> 0.8 and ( 1 5 ) - > 0.2 then  0.8 + 0.2 = 1
# Hint: ( 4 6 ) -> 10 then ( 10 5 ) - > 2.0 then  2.0 - 1 = 1
# Hint: ( 4 1 ) -> 3 and ( 5 7 ) - > -2 then  3 + -2 = 1
# Hint: ( 4 1 ) -> 3 and ( 5 8 ) - > 3 then  3 / 3 = 1
# Hint: ( 4 1 ) -> 5 and ( 5 9 ) - > -4 then  5 + -4 = 1
# Hint: ( 4 1 ) -> 5 and ( 5 10 ) - > 5 then  5 / 5 = 1
# Hint: ( 4 1 ) -> 5 and ( 5 11 ) - > 6 then  6 - 5 = 1
# Hint: ( 4 12 ) -> 3.0 and ( 1 5 ) - > 4 then  4 - 3.0 = 1
# Hint: ( 5 13 ) -> 8 then ( 8 4 ) - > 2.0 then  2.0 - 1 = 1
# Hint: ( 4 1 ) -> 5 and ( 6 1 ) - > 5 then  5 / 5 = 1
# Hint: ( 4 1 ) -> 5 and ( 6 2 ) - > 4 then  5 - 4 = 1
# Hint: ( 4 1 ) -> 3 and ( 6 3 ) - > 3 then  3 / 3 = 1
# Hint: ( 4 1 ) -> 3 and ( 6 4 ) - > 2 then  3 - 2 = 1
# Hint: ( 4 6 ) -> 10 then ( 10 5 ) - > 2.0 then  2.0 - 1 = 1
# Hint: ( 6 6 ) -> 0 then ( 0 4 ) - > 0 then  0 + 1 = 1
# Hint: ( 4 7 ) -> 3 then ( 3 6 ) - > 2.0 then  2.0 - 1 = 1
# Hint: ( 4 1 ) -> 3 and ( 6 8 ) - > -2 then  3 + -2 = 1
# Hint: ( 4 1 ) -> 3 and ( 6 9 ) - > 3 then  3 / 3 = 1
# Hint: ( 4 1 ) -> 5 and ( 6 10 ) - > -4 then  5 + -4 = 1
# Hint: ( 4 1 ) -> 5 and ( 6 11 ) - > 5 then  5 / 5 = 1
# Hint: ( 4 1 ) -> 5 and ( 6 12 ) - > 6 then  6 - 5 = 1
# Sorry, no way to make 1
# Hint: ( 4 1 ) -> 5 and ( 7 1 ) - > 6 then  6 - 5 = 1
# Hint: ( 4 1 ) -> 5 and ( 7 2 ) - > 5 then  5 / 5 = 1
# Hint: ( 4 1 ) -> 5 and ( 7 3 ) - > 4 then  5 - 4 = 1
# Hint: ( 4 1 ) -> 3 and ( 7 4 ) - > 3 then  3 / 3 = 1
# Hint: ( 4 1 ) -> 3 and ( 7 5 ) - > 2 then  3 - 2 = 1
# Hint: ( 4 7 ) -> 3 then ( 3 6 ) - > 2.0 then  2.0 - 1 = 1
# Hint: ( 7 7 ) -> 0 then ( 0 4 ) - > 0 then  0 + 1 = 1
# Sorry, no way to make 1
# Hint: ( 4 1 ) -> 3 and ( 7 9 ) - > -2 then  3 + -2 = 1
# Hint: ( 4 1 ) -> 3 and ( 7 10 ) - > 3 then  3 / 3 = 1
# Hint: ( 4 1 ) -> 5 and ( 7 11 ) - > -4 then  5 + -4 = 1
# Hint: ( 4 1 ) -> 5 and ( 7 12 ) - > 5 then  5 / 5 = 1
# Hint: ( 4 1 ) -> 5 and ( 7 13 ) - > 6 then  6 - 5 = 1
# Hint: ( 4 8 ) -> 0.5 and ( 1 1 ) - > 2 then  0.5 * 2 = 1
# Hint: ( 4 1 ) -> 5 and ( 8 2 ) - > 6 then  6 - 5 = 1
# Hint: ( 4 1 ) -> 5 and ( 8 3 ) - > 5 then  5 / 5 = 1
# Hint: ( 4 1 ) -> 5 and ( 8 4 ) - > 4 then  5 - 4 = 1
# Hint: ( 4 1 ) -> 3 and ( 8 5 ) - > 3 then  3 / 3 = 1
# Hint: ( 4 1 ) -> 3 and ( 8 6 ) - > 2 then  3 - 2 = 1
# Sorry, no way to make 1
# Hint: ( 4 8 ) -> 4 then ( 4 8 ) - > 2.0 then  2.0 - 1 = 1
# Sorry, no way to make 1
# Hint: ( 4 1 ) -> 3 and ( 8 10 ) - > -2 then  3 + -2 = 1
# Hint: ( 4 1 ) -> 3 and ( 8 11 ) - > 3 then  3 / 3 = 1
# Hint: ( 4 1 ) -> 5 and ( 8 12 ) - > -4 then  5 + -4 = 1
# Hint: ( 4 1 ) -> 5 and ( 8 13 ) - > 5 then  5 / 5 = 1
# Hint: ( 1 9 ) -> 8 then ( 8 4 ) - > 2.0 then  2.0 - 1 = 1
# Hint: ( 4 2 ) -> 8 and ( 1 9 ) - > 8 then  8 / 8 = 1
# Hint: ( 4 1 ) -> 5 and ( 9 3 ) - > 6 then  6 - 5 = 1
# Hint: ( 4 1 ) -> 5 and ( 9 4 ) - > 5 then  5 / 5 = 1
# Hint: ( 4 1 ) -> 5 and ( 9 5 ) - > 4 then  5 - 4 = 1
# Hint: ( 4 1 ) -> 3 and ( 9 6 ) - > 3 then  3 / 3 = 1
# Hint: ( 4 1 ) -> 3 and ( 9 7 ) - > 2 then  3 - 2 = 1
# Sorry, no way to make 1
# Hint: ( 9 9 ) -> 0 then ( 0 4 ) - > 0 then  0 + 1 = 1
# Hint: ( 4 9 ) -> 5 then ( 5 10 ) - > 2.0 then  2.0 - 1 = 1
# Hint: ( 4 1 ) -> 3 and ( 9 11 ) - > -2 then  3 + -2 = 1
# Hint: ( 4 1 ) -> 3 and ( 9 12 ) - > 3 then  3 / 3 = 1
# Hint: ( 4 1 ) -> 5 and ( 9 13 ) - > -4 then  5 + -4 = 1
# Hint: ( 4 1 ) -> 5 then ( 5 10 ) - > 2.0 then  2.0 - 1 = 1
# Hint: ( 4 1 ) -> 5 and ( 10 2 ) - > 5.0 then  5 / 5.0 = 1
# Hint: ( 4 3 ) -> 12 and ( 1 10 ) - > 11 then  12 - 11 = 1
# Hint: ( 4 1 ) -> 5 and ( 10 4 ) - > 6 then  6 - 5 = 1
# Hint: ( 4 1 ) -> 5 and ( 10 5 ) - > 5 then  5 / 5 = 1
# Hint: ( 4 1 ) -> 5 and ( 10 6 ) - > 4 then  5 - 4 = 1
# Hint: ( 4 1 ) -> 3 and ( 10 7 ) - > 3 then  3 / 3 = 1
# Hint: ( 4 1 ) -> 3 and ( 10 8 ) - > 2 then  3 - 2 = 1
# Hint: ( 4 9 ) -> 5 then ( 5 10 ) - > 2.0 then  2.0 - 1 = 1
# Hint: ( 10 10 ) -> 0 then ( 0 4 ) - > 0 then  0 + 1 = 1
# Sorry, no way to make 1
# Hint: ( 4 1 ) -> 3 and ( 10 12 ) - > -2 then  3 + -2 = 1
# Hint: ( 4 1 ) -> 3 and ( 10 13 ) - > 3 then  3 / 3 = 1
# Sorry, no way to make 1
# Hint: ( 4 1 ) -> 5 then ( 5 2 ) - > 10 then  11 - 10 = 1
# Hint: ( 4 3 ) -> 12 and ( 1 11 ) - > 12 then  12 / 12 = 1
# Hint: ( 4 1 ) -> 3 then ( 3 4 ) - > 12 then  12 - 11 = 1
# Hint: ( 4 1 ) -> 5 and ( 11 5 ) - > 6 then  6 - 5 = 1
# Hint: ( 4 1 ) -> 5 and ( 11 6 ) - > 5 then  5 / 5 = 1
# Hint: ( 4 1 ) -> 5 and ( 11 7 ) - > 4 then  5 - 4 = 1
# Hint: ( 4 1 ) -> 3 and ( 11 8 ) - > 3 then  3 / 3 = 1
# Hint: ( 4 1 ) -> 3 and ( 11 9 ) - > 2 then  3 - 2 = 1
# Sorry, no way to make 1
# Hint: ( 11 11 ) -> 0 then ( 0 4 ) - > 0 then  0 + 1 = 1
# Sorry, no way to make 1
# Hint: ( 4 1 ) -> 3 and ( 11 13 ) - > -2 then  3 + -2 = 1

# %%
df
